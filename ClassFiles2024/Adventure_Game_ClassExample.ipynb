# %% [markdown]
# Welcome to the Santa Cruz Mountain Adventure Game
# **************************************************************
# You are visiting Santa Cruz, California.
#
# You go on an evening hike alone in the mountains.
#
# You can pick one item to take with you -
#
# map (m), flashlight (f), chocolate (c), rope (r), or sticks (s):
#
# What do you choose?: c
#
# You hear a humming sound.
#
# Do you follow the sound? Enter y or n: n
#
# Good idea. You are not taking risks.
#
# You start walking back to the starting point.
#
# You realize you are LOST!
#
# The sound is behind you and is getting louder. You panic!
#
# Do you start running (r) or stop to make a call (c)?: c
#
# The call does not go through.
#
# Do you want to run (r) or try calling again (c)?: r
#
# You are running fast. The sound gets really loud.
#
# A woman on an electric scooter comes up behind you.
#
# She asks, “Name my favorite computer programming language.”: PYTHON
#
# She says, “Yes, Python is my favorite programming language. If you have some
# chocolate, I
# can help you.”
#
# Luckily, you did choose correctly!
#
# You give her the chocolate.
#
# She helps you get home.
#
# CONGRATULATIONS! You got out safely. You won the game.
#
# ---------------------------------------------------------
# Sorry, was just putting in adventure game text to make it easier to copy into the code.

# %%
import time
from IPython.display import clear_output
#Well, they say it's easier the second time
#And doing this is miles easier than figuring out classes, I might not even have this turned in by the end of the day if I tried to finish that first
print("Welcome to the Santa Cruz Mountain Adventure game.")
time.sleep(2)
password = input("Please write a password: ")
clear_output() #Stop the user from reading the password after submitting it. No retries, so this doesn't see use outside of this line
print("***********************************************************")
time.sleep(2)
print("You are visiting Santa Cruz, California.")
time.sleep(2)
print("You go on an evening hike alone in the mountains.")
time.sleep(2)
print("You can pick one item to take with you:")
time.sleep(2)
print("A map (m), flashlight (f), chocolate (c), rope (r), or sticks (s).")
time.sleep(2)
while True:
  onlyitem = input("What do you choose? ") #Ask the player for an option
  if onlyitem.upper() not in ("M", "F", "C", "R", "S"): #Tried and true
     print("Please enter a valid option.") #If invalid
     continue #Loop
  else: #If valid
     break #Don't loop
print("You hear a humming sound.")
time.sleep(2)
while True:
  followme = input("Do you follow the sound? (Y/N) ")
  if followme.upper() not in ("Y", "N"):
    print("Please enter a valid option.")
    continue
  else:
    break
if followme.upper() in ("Y"):
  print("You keep moving closer to the sound.")
  time.sleep(2)
  print("The sound suddenly stops.")
  time.sleep(2)
  print("You are now LOST!")
  time.sleep(2)
  print("You try to call on your phone, but there is no signal!")
  time.sleep(2)
  while True:
    direction = input("Which way do you want to go? Left, right, forward, back, down, or northeast? (L/R/F/B/D/N) ") #I'll admit, I was tempted to make a second input instead of having this mess
    if direction.upper() not in ("L", "R", "F", "B", "D", "N"): #Not *that* tempted though
      print("Please enter a valid option.")
      continue
    else:
      break
  if direction.upper() in ("L"):
    print("You reach an abandoned cabin.")
    time.sleep(2)
    if onlyitem.upper() in ("M"):
      print("You use the map and find your way home.")
      time.sleep(2)
      print("CONGRATULATIONS! You won the game")
    else:
      print("If you had a map, you could find your way from here.")
      time.sleep(2)
      print("---You are still lost. You lost the game.---")
  elif direction.upper() in ("R"):
    print("You reach a river with a broken bridge.")
    time.sleep(2)
    if onlyitem.upper() in ("R", "S"):
      print("You have an object that can fix the bridge.")
      time.sleep(2)
      print("You fix the bridge, cross over, and find your way home.")
      time.sleep(2)
      print("CONGRATULATIONS! You won the game!")
    else:
      print("If you had a rope or a stick, you could fix the bridge.")
      time.sleep(2)
      print("---You are still lost. You lost the game.---")
  elif direction.upper() in ("F"):
    print("You are walking and trip over a fallen log.")
    time.sleep(2)
    print("You have hurt your foot.")
    time.sleep(2)
    print("You sit down and wait for help.")
    time.sleep(2)
    print("This could be a long time.")
    time.sleep(2)
    print("---You are still lost. You lost the game.---")
  elif direction.upper() in ("B"):
    print("You reach the side of the highway. It is dark.")
    time.sleep(2)
    if onlyitem.upper() in ("F"):
      print("You use the flashlight to signal.")
      time.sleep(2)
      print("A car stops and gives you a ride home.")
      time.sleep(2)
      print("CONGRATULATIONS! You got out safely. You won the game.")
    else:
      print("If you had a flashlight, you could signal for help.")
      time.sleep(1)
      print("---You are still lost. You lost the game.---")
  elif direction.upper() in ("D"):
    print("You go downwards into a strange stairway.")
    time.sleep(2)
    print("You find a strange lockbox.")
    time.sleep(2)
    while True:
      userschoice = input("What could the password be? ")
      if userschoice == password:
        print("You opened the lockbox.")
        break
      else:
        print("The lockbox doesn't open.")
        continue
    print("The lockbox reveals a set of keys!")
    time.sleep(2)
    print("You walk up a different flight of stairs.")
    time.sleep(2)
    print("You find an empty car on the road.")
    time.sleep(2)
    print("The keys opened the car!")
    time.sleep(2)
    print("You drive off.")
    time.sleep(2)
    print("CONGRATULATIONS! You got out safely. You won the game.")
  elif direction.upper() in ("N"):
    print("You find a strange machine.")
    time.sleep(2)
    print("The screen reads...")
    while True:
      animal = input("Is it a dog or a cat? ")
      if animal.lower() not in ("dog", "cat"):
        print("Please reenter your selection.")
        continue
      else:
        break
    while True:
      age = input("How many years old is it? ")
      if age.isdigit() != True:
        print("Please input a valid number.")
        continue
      else:
        break
    if animal.upper() in ("DOG"): #There's no good place for this
      if int(age) == 1: #The power move would be to say that the player character checks their phone and uses the calculator
        print("Your dog is 12 years old in human years.") #Which could be done at ANY if else statement, having it's own function and string to check
      elif int(age) == 2: #If the player writes in the corresponding letter, the calculator function runs
        print("Your dog is 24 years old in human years.") #That would be pretty useless though, unless I set up some kind of puzzle (Which would be hard to make well)
      elif int(age) > 2: #At least it's a half-decent gag here
        print("Your dog is", 24 + ((int(age) - 2) * 4), "years old in human years.") #The best puzzle would probably be seeing a number on the lockbox and plugging that number into the calculator
      else:                                                                        #To get the combination
        print("There is no months to human years calculator here.")                #Even then, it would trespass on the lockbox function being set by the player
    elif animal.upper() in ("CAT"):                                                #Though that's probably not required it would have little payoff to combine these two
      if int(age) == 1:                                                            #And the code's already written
        print("Your cat is 15 years old in human years.")
      elif int(age) == 2:
        print("Your cat is 24 years old in human years.")
      elif int(age) > 2:
        print("Your cat is", 24 + ((int(age) - 2) * 4), "years old in human years.")
      else:
        print("There is no months to human years calculator here.")
    print("Well, that was weird.")
    time.sleep(2)
    print("You're still lost.")
    time.sleep(2)
    print("To make things worse, you didn't actually know which way was northeast earlier.")
    time.sleep(2)
    print("[LOST]")
    print("You lost the game.")


else:
  print("Good idea. You are not taking risks.")
  time.sleep(2)
  print("You start walking back to the starting point.")
  time.sleep(2)
  print("You realize you are LOST!")
  time.sleep(2)
  print("The sound is behind you and is getting louder. You panic!")
  time.sleep(2)
  while True:
    runorcall = input("Do you start running (r) or stop to make a call (c)? ")
    if runorcall.upper() not in ("R", "C"):
      print("Please enter a valid option.")
      continue
    else:
      break
  if runorcall.upper() in ("C"):
    while True:
      print("The call does not go through.")
      time.sleep(2)
      runorcall = input("Do you want to run (r) or try calling again (c)? ")
      if runorcall.upper() not in ("R", "C"):
        print("Please enter a valid option.")
        continue
      elif runorcall.upper() in ("C"):
        continue
      else:
        break
  print("You are running fast. The sound gets really loud.")
  time.sleep(2)
  print("A woman on an electric scooter comes up behind you.")
  time.sleep(2)
  programmar = input("She asks, “Name my favorite computer programming language!” ")
  if programmar.lower() in ("python"): #The player isn't choosing out of a list of options, so only the right answer is recognized. Otherwise they're given the failure results
    print("She says, “Yes, Python is my favorite programming language.”")
    time.sleep(2)
    print("\"If you have some chocolate, I can help you.\"")
    time.sleep(2)
    if onlyitem.upper() in ("C"):
      print("Luckily, you choose correctly earlier!")
      time.sleep(2)
      print("You give her the chocolate.")
      time.sleep(2)
      print("She helps you get home.")
      time.sleep(2)
      print("CONGRATULATIONS! You got out safely. You won the game.")
    else:
      print("You should have chosen that chocolate.")
      time.sleep(2)
      print("She rides away, leaving you alone and lost.")
      time.sleep(2)
      print("You lost the game.")
  else:
    print("She did not like your answer.")
    time.sleep(2)
    print("She rides away, leaving you lost.")
    time.sleep(2)
    print("You lost the game.")
# Out:
# ***********************************************************
# You are visiting Santa Cruz, California.
# You go on an evening hike alone in the mountains.
# You can pick one item to take with you:
# A map (m), flashlight (f), chocolate (c), rope (r), or sticks (s).
# What do you choose?
# Please enter a valid option.
# What do you choose? f
# You hear a humming sound.
# Do you follow the sound? (Y/N) y
# You keep moving closer to the sound.
# The sound suddenly stops.
# You are now LOST!
# You try to call on your phone, but there is no signal!
# Which way do you want to go? Left, right, forward, back, down, or northeast? (L/R/F/B/D/N) d
# You go downwards into a strange stairway.
# You find a strange lockbox.
# What could the password be? n
# You opened the lockbox.
# The lockbox reveals a set of keys!
# You walk up a different flight of stairs.
# You find an empty car on the road.
# The keys opened the car!
# You drive off.
# CONGRATULATIONS! You got out safely. You won the game.

# %%
#Password
while True:
  password = input("You set the password as: ") #Instructions say to let the user choose the password
  userschoice = input("What was the password again? ") #Well, I move the password to the start of the function in the actual adventure game anyways
  if userschoice == password: #Pretty straight forward
    print("You opened the lockbox.")
    break #Break if right
  else:
    print("The lockbox doesn't open.")
    continue #Loop if wrong
# Out:
# You set the password as: awesome2
# What was the password again? awesome2
# You opened the lockbox.

# %%
#Cats, Dogs, Jerry
#What's the difference?
while True:
  animal = input("Is it a dog or a cat? ")
  if animal.lower() not in ("dog", "cat"):
    print("Please reenter your selection.")
    continue
  else:
    break
while True:
  age = input("How many years old is it? ")
  if age.isdigit() != True: #Stops the user from not putting in a positive number
    print("Please input a valid number.")
    continue
  else:
    break
if animal.upper() in ("DOG"):
  if int(age) == 1: #No equation until 3+ years, so just print the age
    print("Your dog is 12 years old in human years.")
  elif int(age) == 2:
    print("Your dog is 24 years old in human years.")
  elif int(age) > 2: #Now we do an equation
    print("Your dog is", 24 + ((int(age) - 2) * 4), "years old in human years.")
  else:
    print("There is no months to human years calculator here.") #If the user inputs 0
elif animal.upper() in ("CAT"):
  if int(age) == 1:
    print("Your cat is 15 years old in human years.")
  elif int(age) == 2:
    print("Your cat is 24 years old in human years.")
  elif int(age) > 2:
    print("Your cat is", 24 + ((int(age) - 2) * 4), "years old in human years.")
  else:
    print("There is no months to human years calculator here.")
# Out:
# Is it a dog or a cat? cat
# How many years old is it? 9
# Your cat is 52 years old in human years.
