# %%
# !pip3 install ColabTurtle
import ColabTurtle.Turtle as shelly 
shelly.initializeTurtle(initial_speed=13)
import time   


go = {'yes', 'no'}

def person(go):
  if go == 'yes':
    print("Good Luck")
  if go == 'no':
    print("Welp too late lets go")

print("You hear a huge blast")
go_outside = input("Do you go outside (Yes or No): ") 

person(go_outside)

name = input("What is your name: ")

print(name)
print("Welcome to World War Z", name)
time.sleep(2)
print("The world has been attacked by zombies")
time.sleep(2)
print("Task, Will You SURVIVE")
time.sleep(2)
x = input("Would you stay in a group (a) or by yourself (b): " )
if x == 'a': print("You have found 10 cans of food and 5 bottles of water")
if x == 'b': print("You have found 5 cans of food and 3 bottles of water")

time.sleep(2)
print("Which location will you go?")
y = input("Army Base (a), Community Underground Bunker (b), Isolated Desert Island (c): ")
if y == 'a': print("You have received a pistol, 15 bullets, and a sleeping bag")
if y == 'b': print("You have received 10 more cans of food, however an infected has entered the bunker and has infected everyone, Try Again")
if y == 'c': print("You have run out of your water and have died of thrist, Try Again")

if y == 'a' :
  time.sleep(2)
  z = input("Do you decide to stay at the Army Base(a) or leave (b): ")
  if z == 'a': print("A horde of zombies have attacked the base, however the soldiers were able to defend the area")
  if z == 'b': print("A horde of zombies have attacked, however with no aid from the soldiers, you are eatten, Try Again")

if (y == 'a' and z == 'a') :
  time.sleep(2)
  print("The base is starting to become too large")
  time.sleep(2)
  print("The soldiers have requested half of the survivers to board a plane and leave to the second base")
  l = input("Do you board the plane (a) or stay (b): ")
  if l == 'a': print("You have escaped the coming demise of the original base")
  if l == 'b': print("The base did not have the resources to defend and supply the people with protection, thus the zombie horde was able to destory the base")

if (y == 'a' and z == 'a' and l == 'a') :
  time.sleep(2)
  print("You arrive at the second base")
  time.sleep(2)
  print("You are given the choice of deciding you next location ")
  time.sleep(2)
  j = input("Hawii (a), Canada (b), or California (c): ")
  if j == 'a': print("You arrive in Hawii and have a quick day on the beach, however zombies have learned to how swim and have quickly destoryed the islands, Try Again")
  if j == 'b': print("You have arrived in Canada, due to the icey weather, zombies have frozen to death causing life to restart, Good Job, you have survived WWZ")
  if j == 'c': print("You arrived in California, due to your lack of awareness, California is the center of the zombie apocalypse, you are then eatten alive, Try Again")

if (y == 'a' and z == 'a' and l == 'a' and j == 'b') :
  time.sleep(2)
  print("Thank you for playing", name)
  time.sleep(2)
  print("This simulator has been made by Noah Im")
  shelly.penup()
  shelly.forward(200)
  shelly.pendown()
  shelly.right(90)
  shelly.forward(180)
  shelly.color("red")
  shelly.forward(170)
  shelly.right(90)
  shelly.forward(375)
  shelly.right(90)
  shelly.forward(170)
  shelly.color("white")
  shelly.forward(180)
  shelly.forward(180)
  shelly.color("red")
  shelly.forward(170)
  shelly.right(90)
  shelly.forward(375)
  shelly.right(90)
  shelly.forward(170)
  shelly.color("white")
  shelly.forward(180)


  shelly.forward(180)
  shelly.right(90)
  shelly.color("red")
  shelly.forward(375)
  shelly.penup()
  shelly.right(180)
  shelly.forward(375)
  shelly.left(90)
  shelly.forward(360)
  shelly.left(90)
  shelly.pendown()
  shelly.forward(375)

  shelly.penup()
  shelly.left(90)
  shelly.forward(180)
  shelly.left(90)
  shelly.forward(30)
  shelly.right(90)
  shelly.pendown()
  shelly.forward(20)
  shelly.left(90)
  shelly.left(8)
  shelly.forward(60)
  shelly.left(180)
  shelly.forward(60)
  shelly.right(98)
  shelly.forward(40)
  shelly.right(90)
  shelly.right(8)
  shelly.forward(60)

  shelly.left(105)
  shelly.forward(70)
  shelly.right(130)
  shelly.forward(60)


  shelly.left(98)
  shelly.forward(100)
  shelly.right(98)
  shelly.forward(30)
  shelly.left(79)
  shelly.forward(50)
  shelly.right(180)
  shelly.left(29)
  shelly.forward(50)
  shelly.left(79)
  shelly.forward(30)
  shelly.right(98)
  shelly.forward(75)


  shelly.right(180)
  shelly.right(50)
  shelly.forward(100)
  shelly.right(98)
  shelly.forward(30)
  shelly.left(79)
  shelly.forward(50)
  shelly.right(180)
  shelly.left(29)
  shelly.forward(50)
  shelly.left(79)
  shelly.forward(30)
  shelly.right(98)
  shelly.forward(100)

  shelly.right(180)
  shelly.right(50)
  shelly.forward(75)
  shelly.right(98)
  shelly.forward(30)
  shelly.left(79)
  shelly.forward(50)
  shelly.right(180)
  shelly.left(29)
  shelly.forward(50)
  shelly.left(79)
  shelly.forward(30)
  shelly.right(98)
  shelly.forward(100)



  shelly.left(101)
  shelly.forward(70)
  shelly.right(138)
  shelly.forward(85)
  shelly.hideturtle()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
# !pip3 install ColabTurtle
import ColabTurtle.Turtle as shelly 
shelly.initializeTurtle(initial_speed=13)
import time   


go = {'yes', 'no'}

def person(go):
  if go == 'yes':
    print("Good Luck")
  if go == 'no':
    print("Welp too late lets go")

print("You hear a huge blast")
go_outside = input("Do you go outside (Yes or No): ") 

person(go_outside)

name = input("What is your name: ")

print(name)
print("Welcome to World War Z", name)
time.sleep(2)
print("The world has been attacked by zombies")
time.sleep(2)
print("Task, Will You SURVIVE")
time.sleep(2)
x = input("Would you stay in a group (a) or by yourself (b): " )
if x == 'a': print("You have found 10 cans of food and 5 bottles of water")
if x == 'b': print("You have found 5 cans of food and 3 bottles of water")

time.sleep(2)
print("Which location will you go?")
y = input("Army Base (a), Community Underground Bunker (b), Isolated Desert Island (c): ")
if y == 'a': print("You have received a pistol, 15 bullets, and a sleeping bag")
if y == 'b': print("You have received 10 more cans of food, however an infected has entered the bunker and has infected everyone, Try Again")
if y == 'c': print("You have run out of your water and have died of thrist, Try Again")

if y == 'a' : #This is here because for some reason if you were to choose C or B in the previous input, the code would still go on. However this acts like a stopper, so only someone who chooses the right answer goes on
  time.sleep(2)
  z = input("Do you decide to stay at the Army Base(a) or leave (b): ")
  if z == 'a': print("A horde of zombies have attacked the base, however the soldiers were able to defend the area")
  if z == 'b': print("A horde of zombies have attacked, however with no aid from the soldiers, you are eatten, Try Again")

if (y == 'a' and z == 'a') :
  time.sleep(2)
  print("The base is starting to become too large")
  time.sleep(2)
  print("The soldiers have requested half of the survivers to board a plane and leave to the second base")
  l = input("Do you board the plane (a) or stay (b): ")
  if l == 'a': print("You have escaped the coming demise of the original base")
  if l == 'b': print("The base did not have the resources to defend and supply the people with protection, thus the zombie horde was able to destory the base")

if (y == 'a' and z == 'a' and l == 'a') :
  time.sleep(2)
  print("You arrive at the second base")
  time.sleep(2)
  print("You are given the choice of deciding you next location ")
  time.sleep(2)
  j = input("Hawii (a), Canada (b), or California (c): ")
  if j == 'a': print("You arrive in Hawii and have a quick day on the beach, however zombies have learned to how swim and have quickly destoryed the islands, Try Again")
  if j == 'b': print("You have arrived in Canada, due to the icey weather, zombies have frozen to death causing life to restart, Good Job, you have survived WWZ")
  if j == 'c': print("You arrived in California, due to your lack of awareness, California is the center of the zombie apocalypse, you are then eatten alive, Try Again")

if (y == 'a' and z == 'a' and l == 'a' and j == 'b') :
  time.sleep(2)
  print("Thank you for playing", name)
  time.sleep(2)
  print("This simulator has been made by Noah Im")
  shelly.penup()
  shelly.forward(200)
  shelly.pendown()
  shelly.right(90)
  shelly.forward(180)
  shelly.color("red")
  shelly.forward(170)
  shelly.right(90)
  shelly.forward(375)
  shelly.right(90)
  shelly.forward(170)
  shelly.color("white")
  shelly.forward(180)
  shelly.forward(180)
  shelly.color("red")
  shelly.forward(170)
  shelly.right(90)
  shelly.forward(375)
  shelly.right(90)
  shelly.forward(170)
  shelly.color("white")
  shelly.forward(180)


  shelly.forward(180)
  shelly.right(90)
  shelly.color("red")
  shelly.forward(375)
  shelly.penup()
  shelly.right(180)
  shelly.forward(375)
  shelly.left(90)
  shelly.forward(360)
  shelly.left(90)
  shelly.pendown()
  shelly.forward(375)

  shelly.penup()
  shelly.left(90)
  shelly.forward(180)
  shelly.left(90)
  shelly.forward(30)
  shelly.right(90)
  shelly.pendown()
  shelly.forward(20)
  shelly.left(90)
  shelly.left(8)
  shelly.forward(60)
  shelly.left(180)
  shelly.forward(60)
  shelly.right(98)
  shelly.forward(40)
  shelly.right(90)
  shelly.right(8)
  shelly.forward(60)

  shelly.left(105)
  shelly.forward(70)
  shelly.right(130)
  shelly.forward(60)


  shelly.left(98)
  shelly.forward(100)
  shelly.right(98)
  shelly.forward(30)
  shelly.left(79)
  shelly.forward(50)
  shelly.right(180)
  shelly.left(29)
  shelly.forward(50)
  shelly.left(79)
  shelly.forward(30)
  shelly.right(98)
  shelly.forward(75)


  shelly.right(180)
  shelly.right(50)
  shelly.forward(100)
  shelly.right(98)
  shelly.forward(30)
  shelly.left(79)
  shelly.forward(50)
  shelly.right(180)
  shelly.left(29)
  shelly.forward(50)
  shelly.left(79)
  shelly.forward(30)
  shelly.right(98)
  shelly.forward(100)

  shelly.right(180)
  shelly.right(50)
  shelly.forward(75)
  shelly.right(98)
  shelly.forward(30)
  shelly.left(79)
  shelly.forward(50)
  shelly.right(180)
  shelly.left(29)
  shelly.forward(50)
  shelly.left(79)
  shelly.forward(30)
  shelly.right(98)
  shelly.forward(100)


# This entire code here is the right, bottem leaf of the maple leaf. 
# However if you look closly it does not match the bottem left leaf. 
#For some reason even though I had the same measurements, they would not link up together. So I just eye balled it
  shelly.left(101)
  shelly.forward(70)
  shelly.right(138)
  shelly.forward(85)
  shelly.hideturtle()
