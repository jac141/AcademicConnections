# %% [markdown]
# My name is Ryan Davis. I am going to a be a senior this coming year. I love math and science classes in general so I was thinking that I am going to want to be some sort of engeneering major in college. I also enjoy playing chess and walking my dog in my free time.

# %% [markdown]
# I chose my program because I really enjoyed the adventure game and a couple days ago I watched Jurassic Park so I was thinking about it and thought it would be fun to make a Jurassic Park themed advneture game.

# %% [markdown]
# Other than making a new theme, I changed the code significantly from my adventure game to this game. I added more inputs and ways to make mistakes, to make the game more challenging and also more fun. I made two more passwords. For the first password, I made it so that the program would generate a random name and then the user would have to input this to survive. In addition, I. made a spam function so that the user could not just scroll up and see the answer to the password. I also made another knowledge password where the user must know that Owen Grady is Chris Pratt. In the end, I also added confetti with random colors to make a much better turtle graphic to congratulate the user after they win the game.

# %% [markdown]
# Two of the problems I had to fix were that my user could just scroll up and see the answer to the password. To fix this I originally attempted to make the text erase after it had been printed. I experimented with this for a while but then concluded I could instead just make a loop to print a phrase many times to hide the response so the user could no longer access it. This was the purpose of my spam function. I would say that this was simpler because all I needed was a for loop instead of more complicated programming that would have needed to be imported to erase the text.
#
# Another problem that I  had was trying to get the program to randomly select a name from a list and then be able to use that as a password. I eventually figured it out got it running after researching the random function. I was coding it correctly but my syntax was off making it so that it was not running properly and the generated name variable was not returned.

# %%
**Here is the output of the program**. (I attached the graphic in canvas)


welcome to jurassic park
you are walking it and the power goes out, you are now on your own.
But wait, two dinosaurs approach you, a velocirpator and a T Rex
which do you choose to trust(v) or (t) t
T rex are stronger
Unfortunately, it eats you, try again
which do you choose to trust(v) or (t) v
great choice
You two are a team
you only carry one item: night vision goggles, a tent, or a bike
which do you choose(g, t, b) t
while setting up your tent, you hear a mysterious sound
do you pack the tent (p) or run (r) p
The T Rex finds you packing and eats you, luckily your velociraptor got away. The  tent was not a good choice, try again
you only carry one item: night vision goggles, a tent, or a bike
which do you choose(g, t, b)t
while setting up your tent, you hear a mysterious sound
do you pack the tent (p) or run (r) r
you think you got away
Unfortunately, the dinosaur finds you defenseless an hour later. The  tent was not a good choice, try again
you only carry one item: night vision goggles, a tent, or a bike
which do you choose(g, t, b)b
a spinosauras darts in front you when you are riding your bike
do you pack the swerve out of the way (s) or keep moving forward (f) s
you go into the wilderness
Unfortunately, your tire pops on a rock, alerting predators
do you run (r) or keep riding the bike (b) r
the dinosaurs catch you. Try again, the bike was not a good choice. 
you only carry one item: night vision goggles, a tent, or a bike
which do you choose(g, t, b)b
a spinosauras darts in front you when you are riding your bike
do you pack the swerve out of the way (s) or keep moving forward (f) s
you go into the wilderness
Unfortunately, your tire pops on a rock, alerting predators
do you run (r) or keep riding the bike (b) b
You fall off and get eaten. Try again, the bike was not a good choice. 
you only carry one item: night vision goggles, a tent, or a bike
which do you choose(g, t, b)b
a spinosauras darts in front you when you are riding your bike
do you pack the swerve out of the way (s) or keep moving forward (f) f
you fall into the mouth of a T Rex. Trya again bike was not the correct choice
you only carry one item: night vision goggles, a tent, or a bike
which do you choose(g, t, b)g
your goggles allow you to see a mysterious shape about 800 feet away
The velociraptor starts to run, do you follow (y) or (n) n
never abandon your velocripator, it is better fit for survival than you
The velociraptor starts to run, do you follow (y) or (n) y
It was smart to trust your animal, the T rex lost your track
wow, velociraptors is smart and fast
we need to give it a  name, Ill pick its first name, you pick the last name 
what do you choose Davis
You are going to have to remember that 
it's first name is:
Tom
Please type in the name again to make sure you have it Tom
hide name
hide name
hide name
hide name
hide name (many more times)
how old do you think it is 4
the velociraptors human age is 44
how old do you think it is4
the velociraptors human age is 44
You see sirens and humans north, but also dinosaurs, do you go north(n) or south(s) s
You are hunted down, try again. 
You see sirens and humans north, but also dinosaurs, do you go north(n) or south(s) n
your night vision goggles show you there are many dinosaurs this way. Are you sure you want to proceed (y or n) n
trust your instincts, try again. 
your night vision goggles show you there are many dinosaurs this way. Are you sure you want to proceed (y or n) y

 hide age
 hide age
 hide age
 hide age
 hide age (many more times)
please enter the age 44
That is correct
Now time for the second password 
please enter your velociraptor's first name Tom
please enter your velociraptor's last name Davis
That is correct
The guard opens the gate for you
Congratulations, you have survived!
Here is your trophy:
V for Victory! 
Here is your confetti too: 
To save your velociraptor, you must show knowledge of the movie of which this game was based 
what actor plays Owen Grady in the most recent Jurassic Park films (first and last name) Chris Pratt
You have won!
Thank you playing, this was game was made by Ryan Davis

# %%
#Here is the actual program, made to run in Replit(outputs shown above)
import time
import random
import turtle, random
greeny = turtle
def confetti(): #this function makes my confetti image in turtle graphics at the end
  colors=["red","green","blue","orange","purple","yellow"] #colors to be randomly selected
  turtle.bgcolor("black")
  for x in range(10): #for
    for x in  range (30):
      greeny.pendown()
      color = random.choice(colors)
      turtle.color(color) 
      greeny.forward(10)
      greeny.penup() #spaces in between confetti
      greeny.forward(10) #making each piece of confetti
    greeny.right(90) #turning confetti in lines
    greeny.forward(10)
    greeny.right(90)
    for x in  range (30): #making the lines of confetti #for loop
      greeny.pendown()
      color = random.choice(colors) #random colors are fun
      turtle.color(color) 
      greeny.forward(10)
      greeny.penup()
      greeny.forward(10)
    greeny.left(90)
    greeny.forward(10)
    greeny.left(90)

def trophy():  #making the trophy 
  turtle.color("blue")
  for x in range(7):
      greeny.forward(100) #star
      greeny.right(144)
  greeny.right(72) #making base
  greeny.forward(63)
  greeny.right(90)
  greeny.forward(200)
  greeny.right(90)
  greeny.forward(63)
  greeny.right(90)
  greeny.forward(200)
  greeny.penup()
  greeny.forward(300)
  greeny.right(180)
  greeny.forward(50)
  greeny.left(30)
  greeny.pendown()
  greeny.forward(50)
  greeny.right(240)
  greeny.forward(50)
  greeny.right(180)
def random_name():
  names=['Ryan', 'Tom', 'John', 'Jim'] #choosing random selection of first name to be used as passcode later #list
  randomm=random.choice(names)
  print("it's first name is:") # print
  print(randomm) #telling the player the name that was chosen by the game
  return randomm
def hidenamespam(): #function #make it so user cannot see the passcode when they need to enter it again as password
  for x in range(1000):
    print(" hide name") #message shown and printed 
def hideagespam():
  for x in range(1000): #making it so they cannot see age when it is used as a password
    print(" hide age") #message shown and printed
print("welcome to jurassic park")
print("you are walking it and the power goes out, you are now on your own.") #start of the game
print("But wait, two dinosaurs approach you, a velocirpator and a T Rex")
while True:
  needraptor = input("which do you choose to trust(v) or (t) ") #have to choose velocirator #input
  if needraptor == "t":
    print("T rex are stronger")
    time.sleep(1) #suspense #time
    print("Unfortunately, it eats you, try again") #if/elif/else #makes user try again where they went wrong 
  elif needraptor == "v":
    time.sleep(1) #suspense
    print("great choice")
    break #user can move to next challenge now
  else:
    print("invalid response") #need valid response to move on
print("You two are a team")
time.sleep(3) #suspense
while True: #while
  print("you only carry one item: night vision goggles, a tent, or a bike") #have to choose goggles
  item = input("which do you choose(g, t, b) ") 
  time.sleep(2) #suspense
  time.sleep(2)
  if item == "b":
    print("a spinosauras darts in front you when you are riding your bike")
    hopee = input("do you pack the swerve out of the way (s) or keep moving forward (f) ") #doomed to fail if this is chosen
    if hopee == "f":
      time.sleep(2)
      print("you fall into the mouth of a T Rex. Try again bike was not the correct choice") #makes user start again 
    if hopee == "s":
      time.sleep(2) #suspense
      print("you go into the wilderness")
      print("Unfortunately, your tire pops on a rock, alerting predators")
      tryy = input("do you run (r) or keep riding the bike (b) ") #either way they will have to restart, bike was not correct
      if tryy == "r":
        time.sleep(2)
        print("the dinosaurs catch you. Try again, the bike was not a good choice. ") 
      elif tryy == "b": 
        time.sleep(2)
        print("You fall off and get eaten. Try again, the bike was not a good choice. ")
    if hopee == "p":
      time.sleep(2)
      print("The lion finds you packing and eats you, luckily your velocirator gets revenge. The tent was not a good choice, try again")
  if item == "t":
    time.sleep(2)
    print("while setting up your tent, you hear a mysterious sound")
    time.sleep(2)
    hopee = input("do you pack the tent (p) or run (r) ") #either way will have to restart, tent is not correct either
    if hopee == "r":
      time.sleep(2)
      print("you think you got away") #good try
      print("Unfortunately, the dinosaur finds you defenseless an hour later. The  tent was not a good choice, try again")
    if hopee == "p":
      time.sleep(2)
      print("The T Rex finds you packing and eats you, luckily your velociraptor got away. The  tent was not a good choice, try again")
  if item == "g":
    print("your goggles allow you to see a mysterious shape about 800 feet away") #correct answer
    while True:
      time.sleep(2)
      hope = input("The velociraptor starts to run, do you follow (y) or (n) ") # must follow, if you fail, it will ask again where you went wrong
      if hope == "n":
        time.sleep(2)
        print("never abandon your velocripator, it is better fit for survival than you")
      elif hope == "no": #no and n work
        time.sleep(2)
        print("never abandon your animal")
      if hope == "y": #yes and y work
        time.sleep(2)
        print("It was smart to trust your animal, the T rex lost your track")
        break
      elif hope == "yes":
        time.sleep(2)
        print("It was smart to trust your animal, the T  rex lost your track")
        break # allows user to advance
#       #else:
#         #print("try again")
    break #break
time.sleep(2)
print("wow, velociraptors is smart and fast")
print("we need to give it a  name, I'll pick its first name, you pick the last name ")
lastname = input("what do you choose ")

print("You are going to have to remember that ")
random_name() #calling random name generator function
randomm = input("Please type in the name again to make sure you have it ")
time.sleep(2)

hidenamespam() #calling name spam function

agee = int(input("how old do you think it is " )) #integer
if agee == 0:
  human = 0
  humannn = str(human) #string
  time.sleep(2)
  print("the velociraptors's human age is 0") #velocripator age calculator
elif agee == 1:
  human = 12
  humannn = str(human) #string
  time.sleep(2)
  print("the velociraptors's human age is 12")
elif agee == 2:
  time.sleep(2)
  human = 24
  humannn = str(human)
  print("the velociraptors's human age is 24")
elif agee > 2: #need to older or age is different
  time.sleep(2)
  human = 24 + (agee)*5
  humannn = str(human) #string
  print("the velociraptors human age is " + humannn)

while True:
  direction = input("You see sirens and humans north, but also dinosaurs, do you go north(n) or south(s) ")
  if direction == "s":
    print("You are hunted down, try again. ")
  else:
    break
if direction == "n":
  while True:
    suree = input("your night vision goggles show you there are many dinosaurs this way. Are you sure you want to proceed (y or n) ") #need to trust instinct
    if suree == "y": #yes and y work
      print("you have arrived at the human gate")
      break
    elif suree == "yes":
      print("you have arrived at the human gate")
      break
    if suree == "n": #no and n are both accepted
      print("trust your instincts, try again. ")
    elif suree == "no":
      print("trust your instincts, try again. ")
print("at the human gate, the guard asks for the code ")
print("what is your velociraptor age in human years ") #asking for code
hideagespam() #call the age

while True:
  x = input("please enter the age ") #checking if age entered is correct
  time.sleep(2)
  if x == humannn:
    break #allows user to move on
  else:
    time.sleep(2)
    print("that is incorrect")
print("That is correct")
print("Now time for the second password ")
while True:
  x = input("please enter your velociraptor's first name ") #checking if name entered is correct
  time.sleep(2)
  if x == randomm:
    break  #allows user to move on
  else:
    time.sleep(2)
    print("that is incorrect ")
while True:
  x = input("please enter your velociraptor's last name ") #checking if last name entered is correct
  time.sleep(2)
  if x == lastname:
    break #allows user to move on
  else:
    time.sleep(2)
#print("Now time for the final password")
print("That is correct")
print("The guard opens the gate for you")
print("Congratulations, you have survived!")
print("Here is your trophy:")
print("V for Victory! ")
time.sleep(2)
print("Here is your confetti too: ")

#trophy
trophy()#calling. trophy maker function
# #confetti
confetti() #calling confetti making function
print("To save your velociraptor, you must show knowledge of the movie of which this game was based ")
while True:
  actor = input("what actor plays Owen Grady in the most recent Jurassic Park films (first and last name) ")
  actorr = actor.lower() #accept all sort of capitalizations
  if actorr == "chris pratt": #need to answer chris pratt
    break 
  else:
    print("that is incorrect ")
    time.sleep(2)
print("You have won the game!") #congrats
print("Thank you playing, this was game was made by Ryan Davis") #telling name
greeny.hideturtle() #hides turtle

# %% [markdown]
# Many of elements of code I used in this project I learned in class for example: print, inputs, integers, strings, time, turtle graphics(colors), if/elif/else, functions, lists. Without all of these tools, I definetely would not have been able to create such an interactive game!
