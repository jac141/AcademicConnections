# %% [markdown]
# My name is Christian Cavadi. I mostly just play games and browse the internet.
#
# I chose to make a text adventure since it seemed like a fun idea. Unfortunately, I'm not too creative, so I took an old flash game and did my best to adapt it into a text adventure. The game over dialogues were taken as they were, and everything else was interpreted by myself.
#
# The original game is called Escaping the Prison, and it was made by Puffballs United.
#
# It can be found [here](https://www.newgrounds.com/portal/view/533001).

# %%
import time
import random
from IPython.display import clear_output
#Last one is just to clear the screen because wow, theres a lot of text
#Importing os and os.system('cls') or clear don't work

#To-Dos
#1. Get the fail functions to loop when an incorrect option is given - Done
#2. Find a way to reassign item on retry (probably the same answer as the first one) - Done
#3. Timer code to allow for QTE - No dice
#4.5. RNG for Legal route - Done
#4. After everything's written add timer.sleep - Done



def delivery(): #Since it's a function the loop at the end can allow the player to restart
#Reset variables to prevent sequence breaking via failures after restarts (Beat the game -> Restart -> Fail on the second choice selection-> Retry sends you to a choice selection that leads to an ending)
  global call
  call = 0
  global dodge
  dodge = 0
  global chase
  chase = 0
  global showdown
  showdown = 0
  global coolitem
  coolitem = 0
  global bathroom
  bathroom = 0
  global classic
  classic = 0
  global broomcloset
  broomcloset = 0
  global bigbox
  bigbox = 0
  clear_output() #To get rid of leftover text on a restart
  print("After that horribly failed bank robbery, you found yourself sitting on a cold bed in jail.") #Print to show text to the player
  time.sleep(1) #Stops the print statements from being near instantaneous
  print("Weeks passed, until one day...") #Separate sentences into different print statements so that they are written on new lines rather than a single line
  time.sleep(2) #Give the player more or less time to read depending on the sentence length
  print("\"Oi, you!\"") #As an extra comment, this game is a sequel, and thus references the previous game in a few places
  time.sleep(1)
  print("\"You're free to go.\"") #Forward slashes (\) put in the right places will activate a ritual to allow for a set of quotation marks to be printed
  time.sleep(1)
  print("You start to look up, and a smile begins to form on your face.")
  time.sleep(3)
  print("The guard laughs at you. \"Not really, but you've got a package.\"") #There can be characters inbetween the first forward slash and the quotation marks 
  time.sleep(2)
  print("A box is tossed onto the floor of your cell.")
  time.sleep(2)
  print("Inside the box, seems to be a cake...")
  time.sleep(1)
  print("Oh, scratch that. A machine disguised as a cake. The top of it retracts into the sides.")
  time.sleep(3)
  print("You reach inside to find:") #: is used to signify a choice selection
  while True: #Start a loop
    global item #So that the next function, firstchoice, can refer to this
    item = input("A (F)ile, an (N)rG drink, a (T)eleporter, a (R)ocket Launcher, a (C)ellphone, or a (D)rill. ") #The player's options are in parentheses
    if item.upper() not in ("F", "N", "T", "R", "C", "D"): #By writing "not in" entering anything other than one of the options shown will return with
      print("Please enter a valid option.") #This.
      continue #Then it loops
    else:
      break #When a valid option is chosen, break and start the next function

#Retry = R is checked to run everything (at the end), setting it to this outside of a function is necessary
retry = "R"
#Functions to run previous sections again when the player fails or wins
def earlyfail(restart): #If a wrong choice is made in the first selection
  while True: #This will loop until break is run
    global retry #Global retry makes sure that the while loop is affected by what the player chooses here
    retry = input("Do you want to (R)estart from the beginning? ") #The player can restart or stop
    if retry.upper() not in ("R", "N"): #If neither option is given, 
      print("Please enter a valid option.") #Print this
      continue #And loop
    else: #If an option is given
      return retry #Return the variable
      break #And break the loop
      #The rest repeats in the while loop at the very end
def fail(reset): #For wrong choices made in selections after the first
  while True: #Mostly the same, but with one difference
    global retry #Affect the retry variable used in the while loop
    retry = input("Do you want to retry the last section (Y/N) or (R)estart from the beginning? ") #The player can continue from the section that contained their previous decision, on top of the previous options
    if retry.upper() not in ("R", "N", "Y"): #The while loop at the end sends them to a section based on the variable set to 1
      print("Please enter a valid option.") #Again, the player is told no if an invaild option is given
      continue #And the loop continues
    else: #If a valid option is given
      return retry #Return the variable
      break #End the function

def win(rekindle): #For when the player reaches any the 3 endings
  while True: #Again, almost the same as the last function, but with one difference
    global retry #Affect the retry variable used in the while loop
    retry = input("Do you want to retry the last section (Y/N) or (R)estart from the beginning? ") #The same options as the fail function
    if retry.upper() not in ("R", "N", "Y"): #Invalid option tells the player 
      print("Please enter a valid option.")  #No
      continue #And loops
    elif retry.upper() in ("N"): #If N is given, a line is printed telling the player that the program is ending
      print("Ending program...") #The while loop at the end reads that retry = N and the variable in the next line
      time.sleep(2) #So the player can read the print
      global winner #Force the main loop to break early with this variable
      winner = "You" #This prevents the finished() function from being used twice with one playthrough, as with the previous two functions setting retry to n would run the else statement at the end of the loop 
      break #So there are two ways for the program to end
    else: #One being the credits
      return retry #And the other being ending program
      break

failc = 0 #Used for the fail counter

def failcounter(n): #This function increments a variable, failc, by one every time a wrong choice is made
  global failc #Refer to the variable on the outermost layer rather than making a local one
               #This way the fail count won't be reset whenever this function runs  
  failc = failc + 1 #Add one to failc
  print("Fail Count:", failc) #The current fail count is printed

#Donut want """achievement"""
#Assigning the variables for the three donut functions
firstdonut = 0 #First choice, NrG Drink
donutbox = 0 #Second choice, Drill then Opacitator
threedonuts = 0 #Fourth choice, File, File Door, Chair, and finally Left

def firstchoice(): #Well, the results of your first choice, anyways
  clear_output() #Clear the screen so I can scroll up sooner
#Check which item the player chose and give the correlating event
#Because of the restrictions in the choice selection the player couldn't have input a character that doesn't trigger one of these
  if item in ("N","n"): #Check for both the uppercase and lowercase versions, as that's the only variation possible
    print("You down the whole bottle, and the world around you") #Print the result of the player's choice
    time.sleep(2)
    print("slows") 
    time.sleep(0.25) #Create variation in the time.sleep function to simulate slowing down
    print("down")
    time.sleep(0.5) #Each print takes a little longer to run than the last
    print("to")
    time.sleep(0.75)
    print("a")
    time.sleep(1)
    print("halt.")
    time.sleep(4) #Pause for a bit
    print("You check the bars of your cell.")
    time.sleep(2)
    print("*Creak*")
    time.sleep(2)
    print("Just by poking it, the bar's been bent enough to let you move though!")
    time.sleep(4)
    print("You casually walk out of your cell.")
    time.sleep(2)
    print("You walk by the guard who mocked you. He gets a free trip to the trash can.")
    time.sleep(4)
    print("Upon entering the main lobby, you see a (D)ount.") #(D) is written to tell the player what the valid option is
    #The donut function (1/3)
    #Along with the cool route and sneaky route, these functions
    #would have the input timeout if I could find out how to code it
    #The function just checks whether or not the player typed in d or D, rather than forcing the player into a valid option with a loop
    def donut(): #Not entering the input in time would result in missing the donut(s)
      food = input("Maybe... ") #And not changing the variable too I guess
      if food.upper() not in ("D"): 
        print("No, you'll ruin your appetite.") #If the player types anything else, this is printed instead
      else: print("Delicious.") #Otherwise, the player character enjoys delicious donut
      global firstdonut #Change the variable assigned outside of a function earlier
      firstdonut = 1
      if firstdonut + donutbox + threedonuts == 3: #When all variables are assigned 1 by these functions, print the achievement text
        time.sleep(2) #Wait a little so that this is printed after delicious is outputted
        print("DONUT WANT!")
        print("100 Points")
        print("...or do you?")
        time.sleep(5) #So the player can take in the donuts
                      #and the achievement
      return firstdonut #Return so the other donut functions can respond
    donut() #Remember to actually run the function
    time.sleep(2) #After, wait a couple of seconds and continue printing the choice result
    print("You walk outside, into the welcoming sun.")
    time.sleep(2)
    print("You take a deep breath...")
    time.sleep(7) #Long sleep to add value to the next print line
    print("And stop.")
    time.sleep(1.5)
    print("[FAIL]") #Not a unique function but still signifies the end of the game
    print("NRG - Side Effects include: Nausea, Headaches, Rapid Heartbeat and possibilities of Stroke and/or Heart Attack.") #Text written under [FAIL] is ripped from the original game
    print("Hmm... Well that's good to know.") #With a few exceptions that have comments elaborating why
    #[FAIL] and the lines that go with it have no time.sleep since I want them to be printed at the same time
    failcounter(failc) #Increment the fail counter
    earlyfail(retry) #Give the player the option to restart
    #Function ends here
  elif item in ("R", "r"): #Same as previous, but it looks for a different letter and has a different result
    print("You take out a short tube with a handle, and it extends into a rocket launcher!") #Print the result of the player's choice
    time.sleep(2)
    print("Without missing a beat, you fire it at the bars of your cell!")
    time.sleep(2)
    print("The rocket-")
    time.sleep(3) #Creating variation in the time.sleep function to simulate confusion
    print("...goes...")
    time.sleep(2)
    print("...Straight though them.")
    time.sleep(4)
    print("That's an awfully strangely shaped pipe in its path.")
    time.sleep(2)
    print("The repairman bends down to grab something at just the right time...")
    time.sleep(2)
    print("And the rocket slides through the pipe, and is coming right back to you!")
    time.sleep(2)
    print("Uh o-")
    time.sleep(0.5) #A very short time is paused to give the impression that the thought is being cut off
    print("*BOOM*")
    time.sleep(1)
    print("[FAIL]")
    print("Uh... Way to aim buddy...") #[FAIL] lines are separated into print statements for each sentence
    failcounter(failc) #Increment the fail counter
    earlyfail(retry) #Let the player restart
  elif item in ("T", "t"): #Check for a different letter
    print("You grab a teleportation remote.") #If True, give the corresponding result
    time.sleep(1)
    print("Without the instructions, you can only press a few buttons and close your eyes.")
    time.sleep(2)
    print("*VWOOOP*")
    time.sleep(1)
    print("\"Ready...\"")
    time.sleep(2)
    print("*VWOERM*")
    print("You open your eyes.")
    time.sleep(1)
    print("You appear to be on the wrong side of a-")
    time.sleep(1)
    print("\"Fire!\"")
    time.sleep(0.25) #Less time is given to show the thought being cut off
    print("*BANG*")
    time.sleep(1)
    print("\"Oh, dear.\"")
    print("\"Oh, man.\"")
    time.sleep(5) #More time is given to let the previous events sink in
    print("...Shooting range.") #Finish the thought
    time.sleep(2)
    print("[FAIL]")
    print("You just can't seem to get the hang of that thing can you?") #The previous game also had the teleportation device as an option
    failcounter(failc) #Increment the fail counter
    earlyfail(retry) #Allow the player to restart
  elif item in ("C", "c"): #Check for the phone
    print("You pick up the flip phone.") #The original game was released in 2010
    time.sleep(2) #Give the player time to read inbetween each print
    print("Looks like it has service...") #Give the player the result
    time.sleep(2)
    print("And a large contact list.")
    time.sleep(2)
    print("That's a lot of attorneys.")
    time.sleep(2)
    print("You should probably call one sooner rather than later.")
    time.sleep(2)
    global call #No choice here, so just assign call to 1 for the next function to check
    call = 1    
    return call #Return so the value can be read by the while loop and the legalroute function
    #The function ends and the while loop moves on to the next function
  elif item in ("D", "d"): #Check if the player chose the drill
    global bathroom #Assign and return a global variable
    bathroom = 1 #1 is used for simplicity
    print("You lift up some kind of motorized drill out of the cake.") #Then print the actual results
    time.sleep(2) #Give a bit of time between prints
    print("You stick the pointy part in the ground, and pull the cord a few times.")
    time.sleep(2)
    #DISCLAIMER:
    #The onomatopoeias portrayed in this production are fictitious. No identification with actual noises (living or decreased) is intended or should be inferred.
    print("*VRM*")
    time.sleep(1)
    print("*VRM*")
    time.sleep(1)
    print("*VROOOM*")
    time.sleep(2)
    print("*VROOOOO-*")
    time.sleep(2)
    print("*CRASH*")
    time.sleep(2)
    print("Ouch, not your best landing...")
    time.sleep(2)
    print("But aside from a few bruises, you seem fine.")
    time.sleep(2)
    print("The same can't be said for the drill...") #So no one wonders why it can't be used
    time.sleep(2)
    print("You find yourself one floor lower, in a boarded up bathroom.")
    time.sleep(2)
    print("Luckily, the boards are on the inside.") #That's just how the room was drawn in the original game
    time.sleep(2)
    print("There's also a grate on the floor.")
    time.sleep(2) 
    return bathroom #The function ends here
  elif item in ("F", "f"): #Finally, check for the file
    print("You pick up the file.") #Tell the player the result of that
    time.sleep(2) #Wait a little
    print("Well, this is as classic as it gets.") #Arbitrary statement before moving on to the next function
    time.sleep(5) #This will be erased when the next function is run, so have it on screen for a little longer than normal. Also it signifies a pause.
    global classic #Arbitrarily named variable assigned before moving on to the next function
    classic = 1 #For the if and elif statements looking for this
    return classic #The function ends here


def sneakyroute(): #Most things are in their own separate functions to allow for restarts and retrying the previous choice
  global classic
  if classic == 1: #If the correlating variable isn't flipped to 1 then skip to the next function
    clear_output() #Clean the output so that the print statements aren't displayed on the screen permanently 
    while True: #Start another choice loop
      escape = input("You can file through either the Cell (D)oor or your (W)indow. ")
      if escape.upper() not in ("D", "W"): #If the player doesn't input a valid option
        print("Please enter a valid option.") #Tell them no
        continue #And loop
      else: #If a valid option is given, 
        break #Break the loop,
    if escape.upper() in ("W"): #Check the input, and give the corresponding option
      print("You saw off one of the bars on your window.") #Print the events that happen
      time.sleep(2) #Not all at once
      print("The opening is now large enough to fit through!")
      time.sleep(2)
      print("You practically jump to the other side!")
      time.sleep(2)
      print("Unfortunately, your cell wasn't on the first floor.")
      time.sleep(2)
      print("Or the second.")
      time.sleep(2)
      print("Or any of the first five, really.") #The jetpack fail animation shows that the player character's cell is on the 10th floor
      time.sleep(2)
      print("[FAIL]") #If the player has been unlucky, [FAIL] should immediately notify them that they have to go back
      print("Protip: Look before you leap.")
      failcounter(failc) #Increment the fail counter
      fail(retry) #Give the nonearly version of the fail function, allowing them to start at the beginning of sneakyroute instead of resetting to delivery
    if escape.upper() in ("D"): #Since there are only two things the player can choose, this might also work as an else: statement
      print("You saw off a bar from your cell door.") #Print the result
      time.sleep(2) #Wait a bit between each print
      print("Hey, this might work as a weapon.")
      time.sleep(2)
      print("An opportunity to test this theory pops up, as a guard heard you leave your cell.")
      time.sleep(2)
      print("You stand your ground.") #No delay between a print and input so the player can write an option earlier
      counter = input("The guard runs right in (F)ront of you! ") #Assign a variable the input value
      if counter.upper() in ("F"): #Check if that value when made uppercase equals F
        print("You use the cell bar to knock the guard away!") #Give the results
        time.sleep(2) #Time inbetween prints
        print("*Tap* *Tap* *Tap*")
        time.sleep(2)
        sneakattack = input("Did you hear something (B)ehind you? ") #Assign another variable to the input value
        if sneakattack.upper() in ("B"): #Check if the player inputted b or B
          print("You swing the other end of the bar upwards!") #If they did, continue to the next section
          time.sleep(2)
          print("The guard behind you is sent flying!") #But first give the results
          time.sleep(2) #Time inbetween prints
          print("His taser goes into the air...")
          time.sleep(2)
          print("And lands right on him.")
          time.sleep(2)
          print("Ouch.")
          time.sleep(1)
          print("With two guards taken down, you start to look at your surroundings-")
          time.sleep(4) #Signify the player character getting their bearings before being interrupted
          print("Only to hear the elevator at the end of the corridor open!") 
          time.sleep(3)
          print("The two guards inside see you and stop their conversation.")
          time.sleep(2)
          print("\"Hey! He's escaping!\"")
          time.sleep(2)
          print("You run into the nearest door and quickly search for something to use.") #Wasn't sure which print statement should be used at the end here, 
          time.sleep(2) #Since the one right after is in the next function, after clear_output is run
          global broomcloset #Assign a global variable
          broomcloset = 1
          return broomcloset #Return so it can be read
        else: #If sneak attack is given an invalid option, assume incompetence and give the results for a failure
          print("You hear a voice behind you yell \"Ha!\"")
          time.sleep(0.75) #A bit less time to show the player character being caught off guard
          print("Before you can react, you get hit with a taser!")
          time.sleep(2)
          print("[FAIL]") 
          print("Oh yeah, I forgot to tell you!")
          print("There's another guard coming!") #Instead, I heavily implied that another guard was coming.
          failcounter(failc) #Increment the fail counter
          fail(retry) #Give the player the option to retry or restart
      else: #If counter is given an invalid option then give failure results
        print("The guard moves within strike range and gives you a mouthful of boot!")
        time.sleep(1)
        print("You're knocked to the ground, disarmed.")
        time.sleep(2)
        print("[FAIL]")
        print("You've got the reflexes of a statue...")
        print("Hint: You can defend yourself by typing in the letter in the parenthesis.") #Had to change the hint for the difference in game type
        failcounter(failc) #Increment the fail counter
        fail(retry) #Give the player the option to retry or restart

def vents():
  clear_output() #Get rid of previous text
  global broomcloset 
  if broomcloset == 1: #Check the value of the variable
    while True: #Choice loop
      print("The only other exit in this room is the ventilation shaft above you.")
      time.sleep(2)
      print("The only objects of note in this room are:")
      stacking = input("A belt of (G)renades and a (C)hair. ") #Two options in parentheses
      if stacking.upper() not in ("G", "C"): #Loop if the player gives an invalid option
        print("Please enter a valid option.")
        continue
      else: #With a valid option, break the loop
        break
    if stacking.upper() in ("G"): #Check which option the player chose
      print("You stand next to the door and grab one of the grenades.") #Run the commands for the corresponding result
      time.sleep(2)
      print("You pull the pin, throw it, and close the door!")
      time.sleep(2)
      print("One of the guards yell out:")
      time.sleep(1)
      print("\"Woah!\"")
      time.sleep(2)
      print("You shut your eyes and cover your ears.")
      time.sleep(2)
      print("Something's off.")
      time.sleep(2)
      print("You open one eye, and notice the live grenade sitting next to the belt.")
      time.sleep(2)
      print("It seems you missed the grenade bouncing off the wall back towards you.")
      time.sleep(2)
      print("\"What the-\"")
      print("*BOOM*") #No time.sleep to show the low amount of time between the statement and the explosion
      time.sleep(2)
      print("[FAIL]")
      print("Uhh... I don't even know what to say about that one...")
      failcounter(failc) #Increment the fail counter
      fail(retry) #Give the player the option to retry the section or restart to the first section
    elif stacking.upper() in ("C"): #If the player didn't choose the other option
      print("You stand on the chair and take off the vent cover.") #Run the results
      time.sleep(2)
      print("You crawl into the vent.")
      while True: #Loop
        ventmove = input("Do you want to go (L)eft or (R)ight? ") #Accept the player's input as the value of a variable
        if ventmove.upper() not in ("L", "R"): #Loop if the player gives an invalid option
          print("Please enter a valid option.")
          continue
        else: #With a valid option, break the loop
          break
      if ventmove.upper() in ("L"): #Check the player's choice
        print("It's quite dark in here.") #Give the corresponding result
        time.sleep(2) #Space the prints
        print("You overhear a conversation happening below you.") #There's more than one
        time.sleep(2)
        print("\"Now, all in favor of more donuts in the break room, say aye.\"")
        time.sleep(2)
        print("\"Aye.\"", "\"Aye.\"", "\"Aye.\"", "\"Aye.\"", "\"Nay.\"")
        time.sleep(2)
        print("\"Shut up, janitor. You don't count.\"")
        time.sleep(2)
        print("\"Now, the next-\"")
        time.sleep(2)
        print("*Creak*")
        time.sleep(1)
        print("The vent breaks under you, and you fall directly onto a large table.")
        time.sleep(2)
        print("Before anyone can come to their senses, you notice something.")
        time.sleep(2)
        print("That table over there has three (D)onuts on a plate.") #The second donut function
        def tripledonut(): #Mostly the same as the last one
          food = input("Maybe... ")
          if food.upper() not in ("D"):
            print("No, you have other things to worry about.")
          else: print("Dangerous, yet delicious.") #Different print statement for different situation
          global threedonuts #Change the variable outside the function
          threedonuts = 1
          if firstdonut + donutbox + threedonuts == 3: #Check if the achievement is triggered
            time.sleep(2)
            print("DONUT WANT!")
            print("100 Points")
            print("...or do you?")
            time.sleep(5)
          return threedonuts
        tripledonut() #Remember to run the function
        print("\"Get him!\"") #Continue where we left off
        time.sleep(2)
        print("All of the guards get up and/or pull out a weapon.")
        time.sleep(2)
        print("Except for one, who jumps at you.")
        time.sleep(2)
        print("[FAIL]")
        print("Fatty.")
        failcounter(failc) #Increment the fail counter
        fail(retry) #Give the player the choice to retry the current section or restart at the first section
      elif ventmove.upper() in ("R"): #Check the player's choice
        print("You find yourself moving upwards, and as the vents come to an end you break the nearest cover to get out.")
        time.sleep(3) #Give the player time to read the text before it gets cleared in the next function
        global bigbox #Assign a global variable to run the next function
        bigbox = 1
        return bigbox

def rooftop():
  global bigbox #Check the variable
  if bigbox == 1: #If it's not 1, move on to the next function
    clear_output() #Clear the text from a previous section or after a reset
    print("You find yourself on top of the prison.") #Print the results of the previous choice
    time.sleep(2) #Space between prints
    print("There's a large crate nearby.")
    time.sleep(2)
    print("Inside, you can use:")
    while True: #Choice loop
      decending = input("A (H)arpoon gun, (P)lungers, a parachute (B), or a (J)etpack. ")
      if decending.upper() not in ("H", "P", "B", "J"): #No valid options?
        print("Please enter a valid option.") #Loop and tell the player to give a valid option
        continue
      else: 
        break
    if decending.upper() in ("B"): #Check the player's choice
      print("You put on the parachute.") #Run the results
      time.sleep(2)
      print("With one foot over the edge you lean forward.")
      time.sleep(2)
      print("You start to fall down along the side of the prison.")
      time.sleep(2)
      print("You pull on the cord.")
      time.sleep(2)
      print("Out of the parachute comes...")
      time.sleep(2)
      print("A frying pan, a bowling ball, a wrench, a soda, and a book.") #At least, I'm pretty sure that's what those were
      time.sleep(2)
      print("Uh oh.")
      time.sleep(2)
      print("*THUD*") #Strong impact
      time.sleep(2)
      print("*Ding* *Puff* *Shatter*") #The pan, book, and soda each respectively hitting the ground and making a noise
      time.sleep(1) #The rest either wouldn't make a sound or I didn't know what onomatopoeia to use
      print("[FAIL]")
      print("I think that was just a regular backpack.") #Regular (B)ackpack
      print("See what happens when you assume?")
      failcounter(failc) #Increment the fail count
      fail(retry) #Give the player the option to retry or go back to the beginning
    elif decending.upper() in ("P"): #Check the player's choice
      print("You grab the two plungers.") #If it's p or P, they win
      time.sleep(2)
      print("You push one into your face.") #But there's a bunch of text that has to print first
      time.sleep(2)
      print("*Pop*")
      time.sleep(2)
      print("Yep, it sticks.")
      time.sleep(2)
      print("Moving one plunger at a time, you start to climb down the prison.")
      time.sleep(2)
      print("*Pop*")
      time.sleep(2)
      print("Just one...")
      time.sleep(2)
      print("*Pop*")
      time.sleep(2)
      print("At a time...")
      time.sleep(2)
      print("*Pop*")
      time.sleep(2)
      print("You use the cell windows as temporary footholds to rest on the way.") #This wasn't shown in the game, I just added that in for a bit of realism
      time.sleep(2)
      print("Eventually, you make it to the bottom.")
      time.sleep(2)
      print("You drop off the plungers.")
      time.sleep(1)
      print("*Thump*") #Soft impact
      time.sleep(2)
      print("You run off into the distance.")
      time.sleep(2)
      print("You win: [S]neaky Ending.")
      finished() #Thank the player and tell them who made the program
      win(retry) #Run the alternate retry function to circumvent the else statement in the while loop
    elif decending.upper() in ("H"): #The actual game calls it a rope, but... it's not.
      print("You set up the harpoon gun.") #Check the player's input and if it's h or H run the commands here
      time.sleep(2) 
      print("*Pew*")
      time.sleep(2)
      print("Just like that, you now have a fast way down.")
      time.sleep(2)
      print("You grab on to the rope and sliding down.")
      time.sleep(2)
      print("*Sssssss*")
      time.sleep(2)
      print("Ow.")
      time.sleep(1) #Less time between these to show the event happening rapidly
      print("OW.")
      time.sleep(1)
      print("HOT!")
      time.sleep(0.5)
      print("TOO HOT!")
      time.sleep(2) #Pause for suspense
      print("You let go.")
      time.sleep(2)
      print("*THUD*") #Hard impact
      time.sleep(2)
      print("That might be your worst landing yet.")
      time.sleep(2)
      print("You slowly get up.")
      time.sleep(2)
      print("You don't look so good, but nothing seems broken.")
      time.sleep(2)
      print("You raise your arms in triumph.")
      time.sleep(2)
      print("And get hit by the bank van driving down the road.") #Two unreasonable events conflict to make one reasonable event
      time.sleep(2)
      print("[FAIL]")
      print("This seems awfully familiar...") #Reference to the previous game
      failcounter(failc) #Increment the fail counter
      fail(retry) #Allow the player to retry the section or restart from the beginning
    elif decending.upper() in ("J"): #Check if the player's choice corresponds to this
      print("You put on the jetpack.") #If so, run the commands
      time.sleep(2)
      print("*Vrrr....*")
      time.sleep(2)
      print("*Poof*")
      time.sleep(1)
      print("[FAIL]")
      print("Wow... That was the lamest thing I've ever seen.")
      print("The animator must have gotten REALLY lazy or something.") #Didn't change it to writer since the player shouldn't have time to read most of this
      print("I mean honestly that was probably the dumbest FAIL I've seen in this entire movie!") #Didn't change this either
      print("So anyway, what do you think about the movie so far?")
      print("Enjoying it?")
      print("It's taken quite a while, and as I'm typing this it has yet to be completed.")
      print("I doubt you'll be able to read this far down unless you figure out a way to pause or do some other sneaky thing.")
      print("Laaaammmeee!")
      time.sleep(2.5) #Just enough time to recognize the [FAIL] but nowhere near enough to fully read it
      clear_output() #The main reason why the player won't have time to read this
      print("?!") #To show something happening
      print("The jetpack blasts off with you being able to do little more than weigh it down.")
      time.sleep(2)
      print("Of course, this also changes which angle it's pointed in.")
      time.sleep(2)
      print("Not that you can easily control it.")
      time.sleep(2)
      print("You tumble through the air, nearly crashing into the ground.")
      time.sleep(2)
      print("Fortunately, you twist your body with all your might to redirect it...") #In the original game it just moves around randomly before crashing 
      time.sleep(2)
      print("*CRASH*")
      time.sleep(2)
      print("And end up making an accidental early landing on the 10th floor of the prison.") 
      time.sleep(2)
      print("The guard in front of your cell says, \"Oh, look. You're back.\"") #You end up in the same cell, and the original game shows that the bar was fixed too (it got dropped after hitting the guards)
      time.sleep(2)
      print("[FAIL]")
      print("It takes many hours of jetpack training before you're able to operate one.")
      failcounter(failc) #Increment the fail counter
      fail(retry) #Allow the player to retry the current section or restart from the beginning


def legalroute():
  global call #Check for variable to run the function
  if call == 1: #Otherwise skip to the next one
    clear_output() #Clear output text
    while True: #Choice loop
      bettercall = 0 #Set the random variable to 0 in case of a replay
      print("Do you want to...")
      phone = input("Call an (A)ttorney, or browse the (I)nternet? ") #Change the variable to what the player inputs
      if phone.upper() not in ("A", "I"): #If it's an invalid option loop and ask the player to set it again
        print("Please enter a valid option.")
        continue
      else: #Otherwise break the loop and check the result in 
        break
    if phone.upper() in ("A"):
      print("You decide to call an attorney at random.")
      print("...") #Signify time passing
      bettercall = random.randint(1, 2) #Roll either 1 or 2
      if bettercall > 1: #If you get a number higher than 1, you win
        print("You excitedly walk out of the courtroom.") #Success results
        time.sleep(2)
        print("Apparently, tying that bag from the inside was an impossible feat for other people.")
        time.sleep(2)
        print("The van driver who thought the bag you hid in belonged to the bank was \"caught\" for attempted murder.")
        time.sleep(2)
        print("A free man once again, you take a breath of fresh air.")
        time.sleep(2)
        print("And see a van belonging to a very familiar bank.")
        time.sleep(2)
        print("You win: [L]egal Ending.")
        finished() #Thank the player and tell them who made the program
        win(retry) #Run the alternate retry function to circumvent the else statement in the while loop
      else:
        print("In retrospect, you should've expected this.") #Failure results
        time.sleep(2)
        print("Guilty")
        print("What kind of third-rate lawyer did you hire?") 
        #Originally, the game had you choose from six options of evidence and gave the same response for a wrong choice
        #But I wanted to shove in the random chance function, so here it is
        failcounter(failc) #Increment the fail counter
        fail(retry) #Allow the player to reset to the start of the current section or restart at the first section
    if phone.upper() in ("I"): #If the second option was chosen
      print("You decide to do your research before hiring anyone to defend you.")
      print("...")
#Roll 1-10
#If the number is higher than 1, you win
      bettercall = random.randint(1, 10) #Much better chances
      if bettercall > 1: 
        print("You excitedly walk out of the courtroom.") #Success results
        time.sleep(2)
        print("Looking into each of the attorneys on that contact list seems to have worked in your favor.")
        time.sleep(2)
        print("Apparently, tying that bag from the inside was an impossible feat for other people.")
        time.sleep(2)
        print("The guy who thought the bag you hid in belonged to the bank was \"caught\" for attempted murder.")
        time.sleep(2)
        print("A free man once again, you take a breath of fresh air.")
        time.sleep(2)
        print("And see a van belonging to a very familiar bank.")
        time.sleep(2)
        print("You win: [L]egal Ending.")
        finished() #Thank the player and tell them who made the program
        win(retry) #Run the alternate retry function to circumvent the else statement in the while loop
      else:
        print("In retrospect, you should've expected this.") #Failure results
        time.sleep(2)
        print("Guilty")
        print("Maybe you were just a bit unlucky?") #Failure line not taken from the game, written like that to hint the player into retrying until they succeed
        failcounter(failc) #Increment the fail counter
        fail(retry) #Allow the player to retry the current section or restart to the first section


def coolroute():
#Separate functions to make retrying faster
  global bathroom
  if bathroom == 1:
    while True: #Choice loop
      global coolitem #Global so that this value can be accessed later
      coolitem = 0
      print("Searching through the room, you find that the only things you can use are...")
      coolitem = input("The (O)pacitator and the (C)rowbar. ") #Only two options
      if coolitem.upper() not in ("O", "C"): #Tell the player no and loop if they don't give one of them
        print("Please enter a valid option.")
        continue
      else: #Otherwise break and check the variable
        break
    if coolitem.upper() in ("O"): #Check the player's choice
      clear_output() #Clear previous text
      print("You grab the Opacitator.")
      time.sleep(2)
      print("The back of it reads:") #The next lines were taken from the original game
      time.sleep(2)
      print("Opacitator")
      time.sleep(1)
      print("\"You'll walk through walls!\"")
      print("-Gadget Gabe (2009)")
      time.sleep(2)
      print("Just move the blue slider to the right and you'll become as opaque (That means 'see-through' for all you uneducated folks) as you want!") 
      print("Not only that, but the more opaque you get, the easier it will be for you to pass through solid object!!") 
      time.sleep(10)
      print("You move the slider all the way to the right.") #Back to adapting the animations to text
      time.sleep(2)
      print("Immediately after, the device falls through your hands.")
      time.sleep(2)
      print("You start sinking into and through the floor.")
      time.sleep(2)
      print("Several floors.")
      time.sleep(1)
      print("Oh, there's a box of (D)onuts on that desk.")
      def boxodonuts(): #Another donut command, same as the last except for the name and variable affected
        food = input("Maybe... ")
        if food.upper() not in ("D"): #Check if the player wrote D or d
          print("No, you'll ruin your appetite.") #If not, they don't eat
        else: print("Delicious.") #If so, they do
        global donutbox #Global so the other donut functions can read this
        donutbox = 1 
        if firstdonut + donutbox + threedonuts == 3: #If the other donut functions are flipped to 1
          time.sleep(2) #Trigger the print statements giving the achievement to the player
          print("DONUT WANT!") #The only time in-game when you could see this achievement was when you clicked on the last donut
          print("100 Points") #So ignoring the fact that the achievement could be read on the website just below where the game is
          print("...or do you?") #This is faithfully recreated
          time.sleep(5)
        return donutbox #Return the variable
      boxodonuts() #Remember to run the function
      print("You reach the ground floor.") #Continue where we left off
      time.sleep(2)
      print("And keep going down.")
      time.sleep(1)
      print("[FAIL]")
      print("You'd think something like that would come up in the Beta Testing.")
      failcounter(failc) #Increment the fail counter
      fail(retry) #Give the player the option to retry or restart
    elif coolitem in ("C", "c"): #Check the player's choice
      clear_output() #Clear the text onscreen
      print("You take the crowbar and remove the nearby drain cover.") #Give the results for this option
      time.sleep(2)
      print("You slide down the drain.")
      time.sleep(2)
      print("After a while, you find yourself at the bottom.")
      time.sleep(2)
      input("The pipes only go in one direction, (F)orward. ")
      time.sleep(2)
      print("*Creak*")
      time.sleep(2)
      print("You barely make it 5 feet before the pipe breaks under you.")
      time.sleep(2)
      print("Well, you can see why that bathroom was abandoned now.")
      time.sleep(2)
      print("With a hard landing on the floor, the first thing you notice are two guards staring right at you!")
      time.sleep(2)
      print("While they're shocked by your sudden appearance, you make a run for it!")
      time.sleep(2)
      print("The guards are taken out of their stupor and call for backup as they give chase!")
      time.sleep(3) #A bit more time is given since the text will be cleared in the next function
      global dodge #Assign a global variable to be read by the next function
      dodge = 1
      return dodge #Return the variable

def maddash():
  clear_output() #Clear the text
  global dodge #Check for the unique variable
  if dodge == 1:
  #The sections from here on would be heavily improved by interrupting the player's inputs with a timer, but I can't find any code that works here
    running = input("They're firing at you! Dodge to the (L)eft or (R)ight! ") #No loop here, an invalid input is the same as failing so an else statement is used instead
    if running.upper() in ("R"): #Check if the player was w(R)ong
      print("You run into a pillar face first.") #Give the results
      time.sleep(1)
      print("[FAIL]")
      print("Don't worry. I heard the prison dentists are great!")
      failcounter(failc) #Increment the fail counter
      fail(retry) #Restart from the beginning, retry this section, or stop the game
    elif running.upper() in ("L"): #Check if the player is a(L)right
      global chase #Assign a global variable for the next function
      chase = 1
      print("You duck to the left, but the guards are catching up!") #Give the results
      time.sleep(2)
      print("One's on your tail, and the other's to your right!")
      time.sleep(2)
      print("Ahead of you is a solid wall and some kind of path on the left.") 
      time.sleep(2)
      return chase #Return the variable and run the next function
    else:
      print("The guards get too close, and in your confusion your body hits the ground before you can react.") #Invalid input is given
      time.sleep(3)
      print("[FAIL]")
      print("Try dodging the bullets, n00b.")
      failcounter(failc) #Increment the fail counter
      fail(retry) #Give the player the option to retry or restart

def notimelimit():
  global chase #Check for a unique variable
  if chase == 1: #If it's set to 1, run the function
    clear_output() #Clear the text
    evade = input("Do you want to go to the (L)eft, or straight (F)orward? ") #No choice loop, instead failing the player for an invalid option
    if evade.upper() in ("L"): #Check the player's given option
      print("As you try to turn, you trip over yourself!") #Give the result
      time.sleep(2)
      print("[FAIL]")
      print("lol Brawl reference!") #The original game was released in 2010
      print(":D")
      failcounter(failc) #Increment the fail counter
      fail(retry) #Give the player the option to retry, restart, or end the program
    elif evade.upper() in ("F"): #Check the player's choice
      print("Dashing towards the wall, you run onto it and flip over the guard behind you!") #Print the result
      time.sleep(2)
      print("He comes to a sudden stop to avoid slamming into the wall, allowing you to make some distance!") #Transition to the next function
      time.sleep(5) #Text will be cleared, so give a bit of time to read
      global showdown #Assign a global variable
      showdown = 1
      return showdown #Return the variable
    else: #If an invalid option is given
      print("With all the blood rushing downwards, you can barely think.") #Give the results for that
      time.sleep(2)
      print("You try to keep your eyes on the guards to dodge at a moment's notice.")
      time.sleep(2)
      print("Sadly, you failed to take into account the wall in front of you.")
      time.sleep(2)
      print("You crash into the wall, making a dent.")
      time.sleep(2)
      print("[FAIL]")
      print("It's always a good idea to watch where you're going.")
      print("Especially if you're running away from the cops...")
      failcounter(failc) #Increment the fail counter
      fail(retry) #Retry, restart, or stop

def drawwhenyouwant():
  global showdown #Check for a specific variable
  if showdown == 1: #If it's been changed to 1, run the function
    clear_output() #Clear the text on screen
    print("You run into a wide room.") #Continued from the previous function
    time.sleep(2)
    print("The lobby!")
    time.sleep(1)
    print("Unfortunately, it seems you weren't the first one here.")
    time.sleep(2)
    print("You're surrounded.")
    time.sleep(2)
    print("It looks like the one with the black hat is the one in charge.")
    time.sleep(3)
    print("And as well as the one blocking the door.")
    time.sleep(2)
    print("The first one to react wins.")
    time.sleep(2)
    print("Get Ready...")
    time.sleep(6) #Wait for a relatively long time to add suspense
    duel = input("(D)raw! ")
    if duel.upper() in ("D"): #If the only valid option is given, the player wins
      print("Time seems to slow down...") #Run the results
      time.sleep(2)
      print("The guard in the black hat starts firing!")
      time.sleep(2)
      print("You can just barely see each bullet flying towards you!")
      time.sleep(3)
      print("You dodge one!")
      time.sleep(2)
      print("Then two!")
      time.sleep(2)
      print("And several more!")
      time.sleep(2)
      print("You catch the last one.")
      time.sleep(5)
      print("Return to sender!")
      time.sleep(3)
      print("The guard's gun is hit, and breaks in two!")
      time.sleep(5) #A lot of time to add value to the next print line
      print("Everyone in the room stares at you, too shocked to move.")
      time.sleep(2)
      print("Any guards that still have their hands holding their weapons can't lift them high enough to point at your toes.")
      time.sleep(5) #A lot of time so you can read that
      print("You walk across the room in stride.")
      time.sleep(2)
      print("Giving a mean look to one of the guards makes them put their hands in the air.")
      time.sleep(2)
      print("You leave the prison.")
      time.sleep(2)
      print("There's a police cruiser nearby.")
      time.sleep(2)
      print("Still has the keys in, too.")
      time.sleep(2)
      print("The smile on your face widens a little.")
      time.sleep(2)
      print("You drive off under the bright blue sky.")
      time.sleep(2)
      print("You win: [C]ool Ending.")
      finished() #Thank the player and tell them who made the program
      win(retry) #Run the alternate retry function to circumvent the else statement in the while loop
    else: #But if an invalid option is given, the player fails and can retry
      print("As soon as you start to move, the guard in the black hat starts firing at you.")
      time.sleep(1)
      print("[FAIL]")
      print("Come on. You were so close!")
      failcounter(failc) #Increment the fail counter
      fail(retry) #Allow the player to retry the current section or restart to the very first function

def finished(): #When the player gets one of the three endings
  print("Thanks for playing!") #Say thanks
  time.sleep(2)
  print("The original game was created by Puffballs United.") #Tell the player who made the original game
  time.sleep(2)
  print("Text adventure adaption written by Christian Cavadi.") #Say that I made this program
  time.sleep(2)
  print("And the commands were written by you!") #Have the And You! at the end
  time.sleep(2) #Function ends

#Here is the giant while loop powering the entire program
while True:
  if retry in ("N", "n"): #If the player doesn't want to continue play finished() (defined above)
    if winner in ("You"): #Unless they won. Then the loop breaks here and ends the program
      break
  elif retry in ("R", "r"): #Full restart
    delivery()
    firstchoice()
    legalroute()
    coolroute()
    maddash()
    notimelimit()
    drawwhenyouwant()
    sneakyroute()
    vents()
    rooftop()
#If Y is selected, then global variables are checked to determine which section the player is in
  elif call == 1: #Variables are assigned right before the function that checks for them is run
    legalroute()    
  elif showdown == 1:
    drawwhenyouwant()
#If there are multiple sections left in the route the player is in, run each one before looping
  elif chase == 1:
    notimelimit()
    drawwhenyouwant()
  elif dodge == 1:
    maddash()   
    notimelimit()
    drawwhenyouwant()
  elif bathroom == 1:
    coolroute()
    maddash()   
    notimelimit()
    drawwhenyouwant()
  elif bigbox == 1:
    rooftop()
  elif broomcloset == 1:
    vents()
    rooftop()
  elif classic == 1:
    sneakyroute()
    vents()
    rooftop()
#retry in y might not need to be here
#firstchoice and earlyfail only end the program or go back to delivery, which resets everything except for the donut variables
#And if a variable = 1 then this shouldnt run to start with
#Well, it can work as a failsafe incase none of the variables are set to 1
#Firstchoice will either immediately fail the player sending them to earlyretry, which forces them to stop or reset  
#Or will send them down one of the routes, potentially reassigning the value (unless the issue is with the code rather than the hardware)
  elif retry in ("Y", "y"):
    firstchoice()
    coolroute()
    maddash()
    notimelimit()
    drawwhenyouwant()
    legalroute()
    sneakyroute()
    vents()
    rooftop()
  else:
      finished()
      break #End the program

#retry = y works in
#legalroute() +
#sneakyroute() +
#vents() +
#rooftop() +
#coolroute() +
#maddash() +
#notimelimit() +
#drawwhenyouwant() +
# Out:
# You run into a wide room.
# The lobby!
# Unfortunately, it seems you weren't the first one here.
# You're surrounded.
# It looks like the one with the black hat is the one in charge.
# And as well as the one blocking the door.
# The first one to react wins.
# Get Ready...
# (D)raw! d
# Time seems to slow down...
# The guard in the black hat starts firing!
# You can just barely see each bullet flying towards you!
# You dodge one!
# Then two!
# And several more!
# You catch the last one.
# Return to sender!
# The guard's gun is hit, and breaks in two!
# Everyone in the room stares at you, too shocked to move.
# Any guards that still have their hands holding their weapons can't lift them high enough to point at your toes.
# You walk across the room in stride.
# Giving a mean look to one of the guards makes them put their hands in the air.
# You leave the prison.
# There's a police cruiser nearby.
# Still has the keys in, too.
# The smile on your face widens a little.
# ...

# %% [markdown]
# Testing done so far:
#
#
# *   Check if each of the endings work
# *   Check if all three endings can be done back to back
# *   Try to trigger the Donut Want text
# *   Check each section to see if setting retry to Y sends the player back to the correct section

# %% [markdown]
# Some of the outputs:
#
# (N)rG Drink
#
# You down the whole bottle, and the world around you
# slows
# down
# to
# a
# halt.
# You check the bars of your cell.
# *Creak*
# Just by poking it, the bar's been bent enough to let you move though!
# You casually walk out of your cell.
# You walk by the guard who mocked you. He gets a free trip to the trash can.
# Upon entering the main lobby, you see a (D)ount.
# Maybe... d
# Delicious.
# You walk outside, into the welcoming sun.
# You take a deep breath...
# And stop.
# [FAIL]
# NRG - Side Effects include: Nausea, Headaches, Rapid Heartbeat and possibilities of Stroke and/or Heart Attack.
# Hmm... Well that's good to know.
# Fail Count: 3
# Do you want to (R)estart from the beginning?
#
# Cool Ending
#
# You run into a wide room.
# The lobby!
# Unfortunately, it seems you weren't the first one here.
# You're surrounded.
# It looks like the one with the black hat is the one in charge.
# And as well as the one blocking the door.
# The first one to react wins.
# Get Ready...
# (D)raw! d
# Time seems to slow down...
# The guard in the black hat starts firing!
# You can just barely see each bullet flying towards you!
# You dodge one!
# Then two!
# And several more!
# You catch the last one.
# Return to sender!
# The guard's gun is hit, and breaks in two!
# Everyone in the room stares at you, too shocked to move.
# Any guards that still have their hands holding their weapons can't lift them high enough to point at your toes.
# You walk across the room in stride.
# Giving a mean look to one of the guards makes them put their hands in the air.
# You leave the prison.
# There's a police cruiser nearby.
# Still has the keys in, too.
# The smile on your face widens a little.
# You drive off under the bright blue sky.
# You win: [C]ool Ending.
# Thanks for playing!
# The original game was created by Puffballs United.
# Text adventure adaption written by Christian Cavadi.
# And the commands were written by you!
# Do you want to retry the last section (Y/N) or (R)estart from the beginning?
#
# Failing right before the Cool Ending
#
# You run into a wide room.
# The lobby!
# Unfortunately, it seems you weren't the first one here.
# You're surrounded.
# It looks like the one with the black hat is the one in charge.
# And as well as the one blocking the door.
# The first one to react wins.
# Get Ready...
# (D)raw! What, like a stickman or something?
# As soon as you start to move, the guard in the black hat starts firing at you.
# [FAIL]
# Come on. You were so close!
# Fail Count: 3
# Do you want to retry the last section (Y/N) or (R)estart from the beginning?
#
# Legal Ending
#
# Do you want to...
# Call an (A)ttorney, or browse the (I)nternet? a
# You decide to call an attorney at random.
# ...
# You excitedly walk out of the courtroom.
# Apparently, tying that bag from the inside was an impossible feat for other people.
# The van driver who thought the bag you were in belonged to the bank was "caught" for attempted murder.
# A free man once again, you take a breath of fresh air.
# And see a van belonging to a very familiar bank.
# You win: [L]egal Ending.
# Thanks for playing!
# The original game was created by Puffballs United.
# Text adventure adaption written by Christian Cavadi.
# And the commands were written by you!
# Do you want to retry the last section (Y/N) or (R)estart from the beginning?
#
# Failing the Legal Ending
#
# Do you want to...
# Call an (A)ttorney, or browse the (I)nternet? a
# You decide to call an attorney at random.
# ...
# In retrospect, you should've expected this.
# Guilty
# What kind of third-rate lawyer did you hire?
# Fail Count: 4
# Do you want to retry the last section (Y/N) or (R)estart from the beginning?
#
# Sneaky Ending
#
# You find yourself on top of the prison.
# There's a large crate nearby.
# Inside, you can use:
# A (H)arpoon gun, (P)lungers, a parachute (B), or a (J)etpack. p
# You grab the two plungers.
# You push one into your face.
# *Pop*
# Yep, it sticks.
# Moving one plunger downwards at a time, you start to climb down the prison.
# *Pop*
# Just one...
# *Pop*
# At a time...
# You use the cell windows as temporary footholds to rest on the way.
# Eventually, you make it to the bottom.
# You drop off the plungers.
# *Thump*
# You run off into the distance.
# You win: [S]neaky Ending.
# Thanks for playing!
# The original game was created by Puffballs United.
# Text adventure adaption written by Christian Cavadi.
# And the commands were written by you!
# Do you want to retry the last section (Y/N) or (R)estart from the beginning?
#
# Wrong choice in the same place
#
# You find yourself on top of the prison.
# There's a large crate nearby.
# Inside, you can use:
# A (H)arpoon gun, (P)lungers, a parachute (B), or a (J)etpack. b
# You put on the parachute.
# With one foot over the edge you lean forward.
# You start to fall down along the side of the prison.
# You pull on the cord.
# Out of the parachute comes...
# A frying pan, a bowling ball, a wrench, a soda, and a book.
# Uh oh.
# *THUD*
# *Ding* *Puff* *Shatter*
# [FAIL]
# I think that was just a regular backpack.
# See what happens when you assume?
# Fail Count: 5
# Do you want to retry the last section (Y/N) or (R)estart from the beginning?

# %% [markdown]
# Below is just code testing to find a way to interrupt an input. Unfortunately, I couldn't find anything that worked.

# %%
#oh look an empty code block
#import signal
#TIMEOUT = 20 # number of seconds your want for timeout
del input
print("Oh this code I copied really had to mess up my actual work until I ran del input")
#def interrupted(signum, frame):
    #"called when read times out"
    #print ('interrupted!')
#signal.signal(signal.SIGALRM, interrupted)

#def bbinput():
    #try:
            #print ('You have 5 seconds to type in your stuff...')
            #foo = raw_input()
            #return foo
    #except:
            # timeout
            #return

# set alarm
#signal.alarm(TIMEOUT)
#s = input()
# disable the alarm after success
#signal.alarm(0)
#print('You typed', s)

# %%
#import time
#import threading
#import os
#import signal

#class FiveSec(threading.Thread):
  #  def restart(self):
   #     self.my_timer = time.time() + 5
 #   def run(self, *args):
    #    self.restart()
    #    while 1:
     #       time.sleep(0.1)
     #       if time.time() >= self.my_timer:
      #          break
     #   os.kill(os.getpid(), signal.SIGINT)


#def main():
    #try:
        #t = FiveSec()
       # t.daemon = True
        #t.start()
       # while 1:
        #    x = input()
        #    t.restart()
        #    print('\nYou entered %r\n' % x)
 #   except KeyboardInterrupt:
   #     print("\nDone!")

#if __name__ == '__main__':
 #   main()
