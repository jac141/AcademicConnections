# %% [markdown]
# Hi there! My name is Laxya Kumar and I am a rising junior in highschool who loves to hangout with my friends and family, lift weights at the gym and am aspiring to go to a good college every day of my life!
# ![WIN_20220801_10_23_50_Pro.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Why I chose this program:
# Originally I started the adventure game for the adventure game project we had to create. Once I finsihed that project, I decided to add two experiments for fun and for extra credit. After that, I just got the idea to build on the Adventure Game and add more elements!

# %% [markdown]
# Problems and solutions I encountered:
# - Once I had  finsihed my code and everything was going fine. There would be instances where the code would not print out the function or just would simple not print out the input. I don't know if it was a error with my IDE because my code was running perfectly fine, but then sometimes it just would not run at all.
#
# -  Since my code is also relatively big, I had to be very cautious to not be clumsy and accidentally type or delete something because I have a tendency to do that. DISCLAIMER: I actually did do that and was wasting tons of minutes trying to understand what went wrong haha.
#
# - To make my code as simple as I can, I decided to use functions that I can call instead of just having a single chat bot as it would be pretty messy for me to go thorugh.

# %%
# !pip3 install ColabTurtle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7657 sha256=482c4b8f86859e96fa5a774c891f0930ba189cb4aa72bd79fbd1ec2759266a8d
#   Stored in directory: /root/.cache/pip/wheels/0d/ab/65/cc4478508751448dfb4ecb20a6533082855c227dfce8c13902
# Successfully built ColabTurtle
# ...

# %%
# !pip3 install ColabTurtle
import random 
from ColabTurtle.Turtle import *

##############################################
def flashlight():
  yesOrNo = input("""You enter the cave and turn on your flashlight...
You decide to go more deeper into the cave and you slip on a rock and fall into a underground pool! 
All of a sudden the flashlight turns off because it got waterlogged.....
Could this day be anyworse? 
Do you still want to continue exploring the cave?: yes(y) or no(n)""")
  if yesOrNo == "n":
    yOrN = input("""Smart idea, let's get out of here...
You climbed out of the pool drenched and are running in the direction of the light where the cave entrance is....WHEN SUDDENLY...
AN UNKOWN ENTITY CAUSES THE CAVE ENTRANCE TO COME CRASHING DOWN...
Now the entrance of the cave is closed and you only have 10 minutes left before you die of oxygen deficiency.... 
What do you do now? Give Up(y) or Gain Superhuman Strength and break down the walls!(n) """)
    if yOrN == "n":
      color = input("""Congrats! You have escaped the treachorous cave. Good Job! 
Here is a trophy that Reggie the turtle drew for you, a star!
What is your favorite color?""")
      snowflake(color)
    else: 
        print("""You die of suffocation.
You lost the game. Better luck next time!""")
  else:
    print("""Determined aren't you! 
You swim deeper throughout the cave....AND THEN SUDDENLY..
A CROCODILE COMES OUT OF NOWHERE AND BRUTALLY DEVOURS YOU!!
You lost the game. Better luck next time! """)
    
###################################################
def bankAccount():
 bankPin = input("Please enter your Bank PIN")
 accountBalance = "$390,237"
 homePage = input("""Welcome back to The Fortville Bank! 
What are today's options: Check Balance (B) , Deposit(d), or Transfer(t)""")
 if homePage == "t":
      moneyTransfer = int(input("How much money would you like to transfer?"))
      if moneyTransfer <= 3000:
        accountRoutingNumber= input("Please enter the Account Holder's routing number who you are transferring to.")
        print("Desired amount has been transferred!")
      elif moneyTransfer > 3000:
        print("""Sorry but you have passed the max limit in terms of the amount of money you can transfer.
You will need to visit your bank to make large transfers.

Welp...Seems you like you missed out on the money in the cave and could not buy a new phone. """)
 elif homePage == "B":
      moneyAmount = input("Please enter the Routing Number from the account that you are withdrawing from")
      print("""Desired amount has been desposited into your account!
Even though you missed out on the huge amount of money in the cave, you bought yourself a new phone!""")
 else:
      print("Your accountBalance is " + accountBalance)

###################################################

def snowflake(string):
  initializeTurtle()
  color(string)
  speed(10)
  for x in range(5):
    for i in range(5):
      forward(230)
      right(120)
      right(30)  
    
###################################################
def password():
  words  = ['tree','sun','ball','moon','earth','grass','world', 'python','dog','snake','newton','geography'] 
  x = random.choice(words)
  return x

y = password() 
  

####################################################


def quizGame():
  score = 0
  intro = (" You must answer all 4 of the questions correctly/get a score of 4 or else your fate lies in the Hunter's hand....")
  questionOne = input("""Question (1) 
What year was the Declaration of Independence signed?""")
  if questionOne == "1776":
    score = score + 1
  else:
    score = 0

  questionTwo = input("""Question (2)
What is the capital of Hawaii?""")
  if questionTwo == "honolulu" or "Honolulu":
    score = score + 1
  else:
    score = score-1
  
  questionThree = input("""Question (3)
What is 30 % 5? """)
  if questionThree == "0":
    score = score + 1  
  else:
    score = score -1 

  questionFour = input("""Question (4)
What is the best coding language? (This one should be very obvious)""")
  if questionFour == "python" or "Python":
    score = score + 1
  else:
    score = score - 1

  score = str(score)
  
  print("Your score is a total of " + score + " points. " )
 
  if score == "4":
   color2 = input("""Congratulations! You got a full score of 4. You won."
Here is a trophy that Reggie the turtle drew for you, a star!
What is your favorite color?""")
   snowflake(color2)
  else:
    print("Welp, seems like you did not get a full score of 4 and get killed by the hunter. You lost.")


    
####################################
    
def saladBowl():
   print("""You absolutely DEVOURED the tasty Salad  Bowl...
Now you find yourself feeling tired after eating and you decide to return back home...
ALL OF A SUDDEN...A hunter has came upon you and wants you to solve a life or death quiz""")
   quizGame()

####################################


def orangeLight():
  orangeLight = input("""You have been walking straight for about 20 minutes and are getting a little tired....until.. .
You see a faint orange light emanating from the distance...you now get a little more curious...
Do you want to go towards the orange light? yes(y) or no(n)""")
  if orangeLight == "y":
      print("""You proceed your trek towards the orange light for another 5 minutes and right when you enter the room you see...
TEN TREASURE CHESTS THAT ARE FILLED WITH MONEY TO THE BRIM!!!""")
      x = input("""Remember the password that was mentioned at the start? 
Please enter the password""")

      if x == y: 
        color1 = input("""The password is correct!
Congratulations, you won the game!
Here is a trophy that Reggie the turtle drew for you, a star!
What is your favorite color?""")
        snowflake(color1)
      else:
        print("""The password in incorrect.
Sucks to suck, you lost the game.""") 
  else:
      print("""You decide to walk back and after 45 minutes you exit cave and it is raining...
Not only do you have to walk back home in the rain but you also missed the oppurtunity to go the glowing orange light where there was a pile of millions of dollars!

All of a sudden...You realize that you lost your phone back in the cave and remember it dropping when you were running out of the cave!
Sucks to suck.

As you are walking back to your house, there is a stand by the side of the road who seems to be selling new phones and has a ATM with your bank!!
As a result, you hurry to the stand and ask the price for a new phone.

They tell you the price and you head on to the ATM to transfer money online""")
      bankAccount()
      

####################################


def cavingGear():
  leftOrRight= input(""" Smart choice! Never want to enter the cave without the gear!
You are slowly walking into the cave and barely avoid a huge drop into a pool of water because of your sensing gear.....
You pick up the pace for another 30 minutes before you come across a y section....with a tunnel leading in the rightwards direction and a tunnel leading in the leftwards direction..
Which direction do you pick? right(r) or left(l)?""")
  
  if leftOrRight == "r":
    return orangeLight()
  else:
    print("""You walk into the tunnel for a solid 30-40 meters before you hear a growling in the distance and freeze right in  your tracks.... 
Was that the sound of a bear?
Suddenly a 8 foot black bear comes out of no where and chops your head off! 
Seems like taking the leftwards tunnel wasn't the brightest of ideas after all. You lost and your dead.  """)
  
############################################










item1 = input("""You have decided to go on a evening walk to a trail in the woods near your house.
It has been a few hours and you randomly have stumbled upon a HUGE cave that you want to explore!.
You can pick one item to take with you into the cave- 
Flashlight(f),Salad Bowl(s), or Caving Gear(g):What do you choose?
Make sure to remember your PASSWORD: """ + y)

if item1 == "f":
  flashlight()
elif item1 == "s":
  saladBowl()
elif item1 == "g":
  cavingGear()

# %% [markdown]
# Game Overview:
#
# You have decided to go on a evening walk to a trail in the woods near your house.
# It has been a few hours and you randomly have stumbled upon a HUGE cave that you want to explore!.
# You can pick one item to take with you into the cave-
# Flashlight(f),Salad Bowl(s), or Caving Gear(g):What do you choose?
# Make sure to remember your PASSWORD: dog
#
# In this scenario, we will chose Flashlight and enter "f".
#
# The code prints:
#
# You enter the cave and turn on your flashlight...
# You decide to go more deeper into the cave and you slip on a rock and fall into a underground pool!
# All of a sudden the flashlight turns off because it got waterlogged.....
# Could this day be anyworse?
# Do you still want to continue exploring the cave?: yes(y) or no(n)
#
# Now let's say we want to keep exploring the cave,  we press yes or "y"
#
# The code prints:
#
# Determined aren't you!
# You swim deeper throughout the cave....AND THEN SUDDENLY..
# A CROCODILE COMES OUT OF NOWHERE AND BRUTALLY DEVOURS YOU!!
# You lost the game. Better luck next time!
#
# Now let's say if we did not want to explore the cave and pressed no "n", instead of yes "y".
#
# The code prints:
#
# Smart idea, let's get out of here...
# You climbed out of the pool drenched and are running in the direction of the light where the cave entrance is....WHEN SUDDENLY...
# AN UNKOWN ENTITY CAUSES THE CAVE ENTRANCE TO COME CRASHING DOWN...
# Now the entrance of the cave is closed and you only have 10 minutes left before you die of oxygen deficiency....
# What do you do now? Give Up(y) or Gain Superhuman Strength and break down the walls!(n)
#
# Let's say if we want to enter "n"..
#
# The code would print:
# Congrats! You have escaped the treachorous cave. Good Job!
# Here is a trophy that Reggie the turtle drew for you, a star!
# What is your favorite color?
#
# (geometric art part)
# Let's say you enter blue as your color..the code prints:
# ![Screenshot 2022-08-01 004657.png](data:image/png;base64,...)
#
# Let's say if we inputted "y" instead of "n" for giving up
# The code would output:
#
# You die of suffocation.
# You lost the game. Better luck next time!
#
# Now let's restart our code and start with our second option.
#
# """You have decided to go on a evening walk to a trail in the woods near your house.
# It has been a few hours and you randomly have stumbled upon a HUGE cave that you want to explore!.
# You can pick one item to take with you into the cave-
# Flashlight(f),Salad Bowl(s), or Caving Gear(g):What do you choose?
# Make sure to remember your PASSWORD: sunf"""
#
# Let's say we chose Salad Bowl or "s"
# (this is the quiz game)
# The code would print:
#
#
# Now you find yourself feeling tired after eating and you decide to return back home...
# ALL OF A SUDDEN...A hunter has came upon you and wants you to solve a life or death quiz
# Question (1)
# What year was the Declaration of Independence signed?
#
# You input "1776"
#
# The code prints:
#
# Question (2)
# What is the capital of Hawaii?
#
# You input "honolulu"
#
# The code prints:
#
# Question (3)
#
# What is 30 % 5?
#
# You input "0"
#
# The code prints:
#
# Question (4)
# What is the best coding language? (This one should be very obvious)
#
# You input "python"
#
# The code prints:
#
# Your score is a total of 4 points.
# Congratulations! You got a full score of 4. You won."
# Here is a trophy that Reggie the turtle drew for you, a star!
# What is your favorite color?
#
# You input "magenta"
#
# (geometric art part)
# The code prints:
#
# ![Screenshot 2022-08-01 083710.png](data:image/png;base64,...)
#
# Let's say if you only got 3 out of the 4 questions correct in that quiz game.
#
# The code prints:
#
# Your score is a total of 3 points.
# Welp, seems like you did not get a full score of 4 and get killed by the hunter. You lost.
#
# Now let's go back to the start and pick the third and final option.
#
# You have decided to go on a evening walk to a trail in the woods near your house.
# It has been a few hours and you randomly have stumbled upon a HUGE cave that you want to explore!.
# You can pick one item to take with you into the cave-
# Flashlight(f),Salad Bowl(s), or Caving Gear(g):What do you choose?
# Make sure to remember your PASSWORD: snakeg
#
# You input "g".
#
# The code prints:
#
# Smart choice! Never want to enter the cave without the gear!
# You are slowly walking into the cave and barely avoid a huge drop into a pool of water because of your sensing gear.....
# You pick up the pace for another 30 minutes before you come across a y section....with a tunnel leading in the rightwards direction and a tunnel leading in the leftwards direction..
# Which direction do you pick? right(r) or left(l)?
#
# Let's say we chose left.
#
# You input "l".
#
# The code prints:
#
# You walk into the tunnel for a solid 30-40 meters before you hear a growling in the distance and freeze right in  your tracks....
# Was that the sound of a bear?
# Suddenly a 8 foot black bear comes out of no where and chops your head off!
# Seems like taking the leftwards tunnel wasn't the brightest of ideas after all. You lost and your dead.
#
# Now let's say earlier when we had to choose our direction, and we chose right.
#
# You input "r".
#
# The code prints:
#
# You have been walking straight for about 20 minutes and are getting a little tired....until.. .
# You see a faint orange light emanating from the distance...you now get a little more curious...
# Do you want to go towards the orange light? yes(y) or no(n)
#
# Let's say if we chose yes.
#
# You input "y".
#
# (This is the password checker part)
# The code prints:
#
# You proceed your trek towards the orange light for another 5 minutes and right when you enter the room you see...
# TEN TREASURE CHESTS THAT ARE FILLED WITH MONEY TO THE BRIM!!!
# Remember the password that was mentioned at the start?
# Please enter the password
#
# You input the password that was mentioned at the start which is "snake".
#
# The code prints:
#
# The password is correct!
# Congratulations, you won the game!
# Here is a trophy that Reggie the turtle drew for you, a star!
# What is your favorite color?
#
# You input "red".
#
# (geometric art part)
# The code prints:
#
# ![Screenshot 2022-08-01 085446.png](data:image/png;base64,...)
#
# Let's go back to the password checker.
#
# Let's say if you input the wrong password.
#
# The code would print:
#
# The password in incorrect.
# Sucks to suck, you lost the game.
#
# Now let's go back to the part that asked if you wanted to continue walking towards the lgiht.
#
#
# You have been walking straight for about 20 minutes and are getting a little tired....until.. .
# You see a faint orange light emanating from the distance...you now get a little more curious...
# Do you want to go towards the orange light? yes(y) or no(n)
#
# You input "n".
#
# (bank account part)
# The code prints:
#
# Not only do you have to walk back home in the rain but you also missed the oppurtunity to go the glowing orange light where there was a pile of millions of dollars!
#
# All of a sudden...You realize that you lost your phone back in the cave and remember it dropping when you were running out of the cave!
# Sucks to suck.
#
# As you are walking back to your house, there is a stand by the side of the road who seems to be selling new phones and has a ATM with your bank!!
# As a result, you hurry to the stand and ask the price for a new phone.
#
# They tell you the price and you head on to the ATM to transfer money online
# Please enter your Bank PIN
#
# You input: 12345
#
# The code prints:
#
# Welcome back to The Fortville Bank!
# What are today's options: Check Balance (B) , Deposit(d), or Transfer(t)
#
# You want to transfer money so that you can buy your new phone.
#
# You input: "t"
#
# The code prints:
#
# How much money would you like to transfer?
#
# Let's say you want to transfer 900$
#
# You input: 900
#
# The code prints:
# Please enter the Account Holder's routing number who you are transferring to.
#
# You input: 123445566
# The code prints:
# Desired amount has been transferred!
#
# Back to when you wanted to transfer money.
# Let's say you chose a value greater than 3000$, so like 3100$
#
# You input: 3100
#
# The code prints:
#
# Sorry but you have passed the max limit in terms of the amount of money you can transfer.
# You will need to visit your bank to make large transfers.
#
# Welp...Seems you like you missed out on the money in the cave and could not buy a new phone.
#
#
# That is the overview of the game..hope you enjoyed!

# %% [markdown]
# What I learned:
# - I was able to solidify my base on functions more and how to call them.
#
# - I also understood for loops and nested for loop.
#
# - I understood how to create geometric art which was really helpful!
