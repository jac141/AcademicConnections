# %% [markdown]
# # Welcome to Trivia Crack: Adventure Addition

# %% [markdown]
# #### Please make sure to use correct capitaling for all inputs!! For example if it says input "yes or no" use lowercase, but if it says choose "Bonzo" please capitalize!!

# %% [markdown]
# ##### It will take about a minute to a minute and a half to load! Please be patient

# %%
import time
import random
characters = ["Bonzo", "Pop", "Al", "Tina", "Hector", "Tito"]
def hard():
  #This mode has a bit more difficult questions
  num_correct = 0
  print("Welcome to Trivia Crack: Adventure Addition")
  print("You have chosen hard mode, BE WARNED")
  print("The aim of the game is to get to collect every character by going down paths by answering fun trivia, and getting the crown!!!")
  time.sleep(3)
  print("First things first, what's your name adventurer!")
  name = input("Name: ")
  time.sleep(3)
  print("Now Let's set up a username and password to your account, make sure to remember them!!")
  time.sleep(2)
  username = input("Username: ")
  time.sleep(1)
  password = input("Password: ")
  time.sleep(2)
  print("Time to spin the wheel to choose your powerup!")
  time.sleep(1)
  powerup = random.randint(1, 2)
  num_correct = 0
  if powerup == 1:
    time.sleep(3)
    print("You recieved the powerup Skip!")
    print("This powerup allows you to skip a question you don't know the answer to for a new set!")
    #if powerup equals one then you get the Skip powerup/ 1 == powerup Skip
  else:
    time.sleep(3)
    print("You received the powerup Double Chance!")
    print("This powerup allows you to retry a question after putting the wrong answer!")
  #Now that we've recieved rthe powerup, we continue
  time.sleep(2)
  print("Now let the adventure begin!!")
  time.sleep(3)
  print("You're inside the spinning wheel of the trivia crack, and have 6 paths to go down")
  print("Each path has a titled name, but you are unsure which category of questions is which")
  print("Choose your first path:" , characters)
  choice1 = input("What path do you choose: ")
  characters.remove(choice1) #removing the option of the character chosen from "character" list!!

  #CHOICE ONE

  if choice1 == "Bonzo":
    print("You step down the hall marked, Bonzo, and as you travel down the hall, the sounds of cheers fill up the darkened hall")
    time.sleep(1)
    print("You see a light, and as you emerge from the dark hall, you realize you're in a football field with the stadium filled")
    time.sleep(1)
    print("You step out unto the green field with crowd roaring, as the jumbotron turns on")
    time.sleep(1)
    print("The screen reads 'Welcome to the sports category! Get ready for your first question' ")
    time.sleep(1)
    print('''From which country is the athlete Maria Mutola, who won her eighth world title in Paris in 2003?
  a) Mozambique
  b) America
  c) Brazil
  d) Senegal''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuebonzo1 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuebonzo1 == "yes":
        print("Ok")
        time.sleep(1)
        bonzoanswerskip = input('''How many fights did Muhammad Ali win during his career?
  a) 56
  b) 44
  c) 52
  d) 48''')
        if bonzoanswerskip == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1          
        else:
          print("The answer is not" , + bonzoanswerskip)
          #Now unto the instance where they say 'no'
      else:
        bonzoanswer = input("Answer(lowercase letter): ")
        if bonzoanswer == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1
        else: 
          print("The answer is not" , + bonzoanswer)
    else:
      bonzoanswer = input("Answer(lowercase letter): ")
      if bonzoanswer == "a":
        print("Correct!")
        print("You have collected Bonzo! The Sports character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif bonzoanswer != "a" and powerup == 2:
            print("Let's use double chance, try again!")
            bonzoanswerdouble = input('''From which country is the athlete Maria Mutola, who won her eighth world title in Paris in 2003?
  a) Mozambique
  b) America
  c) Brazil
  d) Senegal''')
            if bonzoanswerdouble == "a":
              print("Correct, see you could do it!")
              print("You have collected Bonzo! The Sports character!")
              num_correct += 1
            else: 
              print("The answer is not" , + bonzoanswerdouble)
  

  if choice1 == "Pop":
    print("You tread down the hall marked, Pop, that is covered with movie posters and albums, and hear soft voices emerging")
    time.sleep(1)
    print("You see a light coming from a screen playing a movie, and as you emerge from the dark hall, you realize you're in a movie theater, seats filled")
    time.sleep(1)
    print("The character Pop, who looks like popcorn, is sitting on the screen")
    time.sleep(1)
    print(" Pop yells 'HEYYY THERE AND WELCOME to the entertainment category! Best category if you ask me! ")
    time.sleep(1)
    print("If you're a real enteratinment buff let's see if you can answer my questions!! ")
    time.sleep(1)
    print('''How many letters did Noah write to Allie in The Notebook?
  a) 300
  b) 365
  c) 412
  d) 286''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuepop = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuepop == "yes":
        print("Ok")
        time.sleep(1)
        popanswerskip = input('''What year did ‘Thriller’, by Micheal Jackson, come out?
  a) 1979
  b) 1982
  c) 1985
  d) 1987''')
        if popanswerskip == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1          
        else:
          print("The answer is not" , + popanswerskip)
          #Now unto the instance where they say 'no'
      else:
        popanswer = input("Answer(lowercase letter): ")
        if popanswer == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1
        else: 
          print("The answer is not" , + popanswer)
    else:
      popanswer = input("Answer(lowercase letter): ")
      if popanswer == "b":
        print("Correct!")
        print("You have collected POP! The Entertainment character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif popanswer != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            popanswerdouble = input('''How many letters did Noah write to Allie in The Notebook?
  a) 300
  b) 365
  c) 412
  d) 286''')
            if popanswerdouble == "b":
              print("Correct, see you could do it!")
              print("You have collected POP! The Entertainment character!")
              num_correct += 1
            else: 
              print("The answer is not" , + popanswerdouble)


  if choice1 == "Al":
    print("You start skipping down the very well lit hall marked, Al, and as you're going down , you can hear explosions in the background")
    time.sleep(1)
    print("You see a labortaory, with many chemical reactions appearing, you realize you're in the middle of a Bill Nye the Science guy episode")
    time.sleep(1)
    print("You see he's doing a an episode with AL the beaker, who notices you're prescence")
    time.sleep(1)
    print(" Al says to you 'hey there, ready for some REAL intellitecual questions my fellow science enthusist' (just say yes)")
    time.sleep(1)
    input()
    time.sleep(1)
    print(''' OKK, What animal has the highest blood pressure?
  a) Elephant
  b) Humans
  c) Giraffe
  d) Kangaroo''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continueal = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continueal == "yes":
        print("Ok")
        time.sleep(1)
        alanswerskip = input('''What does vexology study
  a) Witchcraft
  b) Pantries
  c) Flags
  d) Handwriting''')
        if alanswerskip == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1          
        else:
          print("The answer is not " , + alanswerskip)
          #Now unto the instance where they say 'no'
      else:
        alanswer = input("Answer(lowercase letter): ")
        if alanswer == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1
        else: 
          print("The answer is not " , + alanswer)
    else:
      alanswer = input("Answer(lowercase letter): ")
      if alanswer == "c":
        print("Correct!")
        print("You have collected AL! The Science character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif alanswer != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            alanswerdouble = input(''' OKK, What animal has the highest blood pressure?
  a) Elephant
  b) Humans
  c) Giraffe
  d) Kangaroo''')
            if alanswerdouble == "c":
              print("Correct, see you could do it!")
              print("You have collected AL! The Science character!")
              num_correct += 1
            else: 
              print("The answer is not" , + alanswerdouble)



  if choice1 == "Tina":
    print("You bolt down the hall with the title, TINA in a very fancy font, and as you're going down , you hear clicks and flashes of phones")
    time.sleep(1)
    print("The hall is decroated lavishly, with iconic paintings like the Mona Lisa")
    time.sleep(1)
    print("You enter into an art gallery with many people, and Tina the paintbrush finishing their art")
    time.sleep(1)
    print(" Tina says 'Hey, I'm Tina, glad you came to my art show, ready for some trvia!")
    time.sleep(4)
    print(''' What is writer Paul Auster’s favourite city, according to his novels?
  a) Chicago
  b) London
  c) Paris
  d) New York''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetina = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetina == "yes":
        print("Ok")
        time.sleep(1)
        tinaanswerskip = input('''What year was ‘El Quijote’ published?
  a) 1773
  b) 1545 
  c) 1866
  d) 1605''')
        if tinaanswerskip == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1          
        else:
          print("The answer is not" , + tinaanswerskip)
          #Now unto the instance where they say 'no'
      else:
        tinaanswer = input("Answer(lowercase letter): ")
        if tinaanswer == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1
        else: 
          print("The answer is , not" , + tinaanswer)
    else:
      tinaanswer = input("Answer(lowercase letter): ")
      if tinaanswer == "d":
        print("Correct!")
        print("You have collected TINA! The art character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif tinaanswer != "d" and powerup == 2:
            print("Let's use double chance, try again!")
            tinaanswerdouble = input(''' What is writer Paul Auster’s favourite city, according to his novels?
  a) Chicago
  b) London
  c) Paris
  d) New York''')
            if tinaanswerdouble == "d":
              print("Correct, see you could do it!")
              print("You have collected TINA! The art character!")
              num_correct += 1
            else: 
              print("The answer is not" , + tinaanswerdouble)


  if choice1 == "Hector":
    print("You walk into the hall marked Hector when a sudden wave of old people smeel whiffs through the air")
    time.sleep(1)
    print("The hall is adorned with countless documents and events from scattered places and times in history")
    time.sleep(1)
    print("After you finally reach the end, you enter into a socratic seminar with Hector the Knight leading")
    time.sleep(1)
    print(" Hector looks over and says 'Ah I see you're here to interupt, better know some trivia then!!")
    time.sleep(4)
    print('''What South American country had a monarchy for more than 60 years?
  a) Peru
  b) Brazil
  c) Ecuador
  d) Chile''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuehector = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuehector == "yes":
        print("Ok")
        time.sleep(1)
        hectoranswerskip = input(''' How many people died in the Munich massacre of 1972?
  a) 23
  b) 17 
  c) 21
  d) 12''')
        if hectoranswerskip == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1          
        else:
          print("The answer is not" , + hectoranswerskip)
          #Now unto the instance where they say 'no'
      else:
        hectoranswer = input("Answer(lowercase letter): ")
        if hectoranswer == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1
        else: 
          print("The answer is  not" , + hectoranswer)
    else:
      hectoranswer = input("Answer(lowercase letter): ")
      if hectoranswer == "b":
        print("Correct!")
        print("You have collected Hector! The History character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif hectoranswer != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            hectoranswerdouble = input('''What South American country had a monarchy for more than 60 years?
  a) Peru
  b) Brazil
  c) Ecuador
  d) Chile''')
            if hectoranswerdouble == "b":
              print("Correct, see you could do it!")
              print("You have collected Hector! The History character!")
              num_correct += 1
            else: 
              print("The answer is not" , + hectoranswerdouble)



  if choice1 == "Tito":
    print("As you enter the hall with the title, Tito, it suddenly smells like the ocean")
    time.sleep(1)
    print("You see the halls covered with maps of different regions across the world, and see a light at the end of the hall")
    time.sleep(1)
    print("You enter onto a mountain hill with Tito, the globe, standing with binoculars")
    time.sleep(1)
    print(" Tito says 'LOOOK AT THIS VIEW, glad you could make it, ready for some geography trvia!")
    time.sleep(4)
    print(''' SDE is the international code for what country?
  a) Denmark
  b) Russia
  c) Germany
  d) Portugual''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetito = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetito == "yes":
        print("Ok")
        time.sleep(1)
        titoanswerskip = input('''How many countries border with Egypt?
  a) 2
  b) 7 
  c) 4
  d) 3''')
        if titoanswerskip == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1          
        else:
          print("The answer is not" , + titoanswerskip)
          #Now unto the instance where they say 'no'
      else:
        titoanswer = input("Answer(lowercase letter): ")
        if titoanswer == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1
        else: 
          print("The answer is not" , + titoanswer)
    else:
      titoanswer = input("Answer(lowercase letter): ")
      if titoanswer == "c":
        print("Correct!")
        print("You have collected Tito! The Geography character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif titoanswer != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            titoanswerdouble = input(''' SDE is the international code for what country?
  a) Denmark
  b) Russia
  c) Germany
  d) Portugual''')
            if titoanswerdouble == "c":
              print("Correct, see you could do it!")
              print("You have collected Tito! The Geography character!")
              num_correct += 1
            else: 
              print("The answer is not" , + titoanswerdouble)


  time.sleep(4)
  print("You head back down the" , choice1 + "hall")
  time.sleep(1)
  print("You have these paths left" , characters)
  choice2 = input("What path do you choose next: ")
  characters.remove(choice2)

  ###CHOICE TWO###########################################################################################################################

  if choice2 == "Bonzo":
    print("You step down the hall marked, Bonzo, and as you travel down the hall, the sounds of cheers fill up the darkened hall")
    time.sleep(1)
    print("You see a light, and as you emerge from the dark hall, you realize you're in a football field with the stadium filled")
    time.sleep(1)
    print("You step out unto the green field with crowd roaring, as the jumbotron turns on")
    time.sleep(1)
    print("The screen reads 'Welcome to the sports category! Get ready for your first question' ")
    time.sleep(1)
    print('''From which country is the athlete Maria Mutola, who won her eighth world title in Paris in 2003?
  a) Mozambique
  b) America
  c) Brazil
  d) Senegal''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuebonzo2 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuebonzo2 == "yes":
        print("Ok")
        time.sleep(1)
        bonzoanswerskip2 = input('''How many fights did Muhammad Ali win during his career?
  a) 56
  b) 44
  c) 52
  d) 48''')
        if bonzoanswerskip2 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1          
        else:
          print("The answer is not" , + bonzoanswerskip2)
          #Now unto the instance where they say 'no'
      else:
        bonzoanswer2 = input("Answer(lowercase letter): ")
        if bonzoanswer2 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1
        else: 
          print("The answer is not" , + bonzoanswer2)
    else:
      bonzoanswer2 = input("Answer(lowercase letter): ")
      if bonzoanswer2 == "a":
        print("Correct!")
        print("You have collected Bonzo! The Sports character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif bonzoanswer2 != "a" and powerup == 2:
            print("Let's use double chance, try again!")
            bonzoanswerdouble2 = input('''From which country is the athlete Maria Mutola, who won her eighth world title in Paris in 2003?
  a) Mozambique
  b) America
  c) Brazil
  d) Senegal''')
            if bonzoanswerdouble2 == "a":
              print("Correct, see you could do it!")
              print("You have collected Bonzo! The Sports character!")
              num_correct += 1
            else: 
              print("The answer is not" , + bonzoanswerdouble2)


  if choice2 == "Pop":
    print("You tread down the hall marked, Pop, that is covered with movie posters and albums, and hear soft voices emerging")
    time.sleep(1)
    print("You see a light coming from a screen playing a movie, and as you emerge from the dark hall, you realize you're in a movie theater, seats filled")
    time.sleep(1)
    print("The character Pop, who looks like popcorn, is sitting on the screen")
    time.sleep(1)
    print(" Pop yells 'HEYYY THERE AND WELCOME to the entertainment category! Best category if you ask me! ")
    time.sleep(1)
    print("If you're a real enteratinment buff let's see if you can answer my questions!! ")
    time.sleep(1)
    print('''How many letters did Noah write to Allie in The Notebook?
  a) 300
  b) 365
  c) 412
  d) 286''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuepop2 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuepop2 == "yes":
        print("Ok")
        time.sleep(1)
        popanswerskip2 = input('''What year did ‘Thriller’, by Micheal Jackson, come out?
  a) 1979
  b) 1982
  c) 1985
  d) 1987''')
        if popanswerskip2 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1          
        else:
          print("The answer is, not" , + popanswerskip2)
          #Now unto the instance where they say 'no'
      else:
        popanswer2 = input("Answer(lowercase letter): ")
        if popanswer2 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1
        else: 
          print("The answer is, not" , + popanswer2)
    else:
      popanswer2 = input("Answer(lowercase letter): ")
      if popanswer2 == "b":
        print("Correct!")
        print("You have collected POP! The Entertainment character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif popanswer2 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            popanswerdouble2 = input('''How many letters did Noah write to Allie in The Notebook?
  a) 300
  b) 365
  c) 412
  d) 286''')
            if popanswerdouble2 == "b":
              print("Correct, see you could do it!")
              print("You have collected POP! The Entertainment character!")
              num_correct += 1
            else: 
              print("The answer is not" , + popanswerdouble2)  


  if choice2 == "Al":
    print("You start skipping down the very well lit hall marked, Al, and as you're going down , you can hear explosions in the background")
    time.sleep(1)
    print("You see a labortaory, with many chemical reactions appearing, you realize you're in the middle of a Bill Nye the Science guy episode")
    time.sleep(1)
    print("You see he's doing a an episode with AL the beaker, who notices you're prescence")
    time.sleep(1)
    print(" Al says to you 'hey there, ready for some REAL intellitecual questions my fellow science enthusist' (just say yes)")
    time.sleep(1)
    input()
    time.sleep(1)
    print(''' OKK, What animal has the highest blood pressure?
  a) Elephant
  b) Humans
  c) Giraffe
  d) Kangaroo''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continueal2 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continueal2 == "yes":
        print("Ok")
        time.sleep(1)
        alanswerskip2 = input('''What does vexology study
  a) Witchcraft
  b) Pantries
  c) Flags
  d) Handwriting''')
        if alanswerskip2 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1          
        else:
          print("The answer is not" , + alanswerskip2)
          #Now unto the instance where they say 'no'
      else:
        alanswer2 = input("Answer(lowercase letter): ")
        if alanswer2 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1
        else: 
          print("The answer is not" , + alanswer2)
    else:
      alanswer2 = input("Answer(lowercase letter): ")
      if alanswer2 == "c":
        print("Correct!")
        print("You have collected AL! The Science character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif alanswer2 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            alanswerdouble2 = input(''' OKK, What animal has the highest blood pressure?
  a) Elephant
  b) Humans
  c) Giraffe
  d) Kangaroo''')
            if alanswerdouble2 == "c":
              print("Correct, see you could do it!")
              print("You have collected AL! The Science character!")
              num_correct += 1
            else: 
              print("The answer is not" , + alanswerdouble2)

  if choice2 == "Tina":
    print("You bolt down the hall with the title, TINA in a very fancy font, and as you're going down , you hear clicks and flashes of phones")
    time.sleep(1)
    print("The hall is decroated lavishly, with iconic paintings like the Mona Lisa")
    time.sleep(1)
    print("You enter into an art gallery with many people, and Tina the paintbrush finishing their art")
    time.sleep(1)
    print(" Tina says 'Hey, I'm Tina, glad you came to my art show, ready for some trvia!")
    time.sleep(4)
    print(''' What is writer Paul Auster’s favourite city, according to his novels?
  a) Chicago
  b) London
  c) Paris
  d) New York''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetina2 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetina2 == "yes":
        print("Ok")
        time.sleep(1)
        tinaanswerskip2 = input('''What year was ‘El Quijote’ published?
  a) 1773
  b) 1545 
  c) 1866
  d) 1605''')
        if tinaanswerskip2 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1          
        else:
          print("The answer is , not" , + tinaanswerskip2)
          #Now unto the instance where they say 'no'
      else:
        tinaanswer2 = input("Answer(lowercase letter): ")
        if tinaanswer2 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1
        else: 
          print("The answer is , not" , + tinaanswer2)
    else:
      tinaanswer2 = input("Answer(lowercase letter): ")
      if tinaanswer2 == "d":
        print("Correct!")
        print("You have collected TINA! The art character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif tinaanswer2 != "d" and powerup == 2:
            print("Let's use double chance, try again!")
            tinaanswerdouble2 = input(''' What is writer Paul Auster’s favourite city, according to his novels?
  a) Chicago
  b) London
  c) Paris
  d) New York''')
            if tinaanswerdouble2 == "d":
              print("Correct, see you could do it!")
              print("You have collected TINA! The art character!")
              num_correct += 1
            else: 
              print("The answer is  not" , + tinaanswerdouble2)  


  if choice2 == "Hector":
    print("You walk into the hall marked Hector when a sudden wave of old people smeel whiffs through the air")
    time.sleep(1)
    print("The hall is adorned with countless documents and events from scattered places and times in history")
    time.sleep(1)
    print("After you finally reach the end, you enter into a socratic seminar with Hector the Knight leading")
    time.sleep(1)
    print(" Hector looks over and says 'Ah I see you're here to interupt, better know some trivia then!!")
    time.sleep(4)
    print('''What South American country had a monarchy for more than 60 years?
  a) Peru
  b) Brazil
  c) Ecuador
  d) Chile''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuehector2 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuehector2 == "yes":
        print("Ok")
        time.sleep(1)
        hectoranswerskip2 = input(''' How many people died in the Munich massacre of 1972?
  a) 23
  b) 17 
  c) 21
  d) 12''')
        if hectoranswerskip2 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1          
        else:
          print("The answer is not" , + hectoranswerskip2)
          #Now unto the instance where they say 'no'
      else:
        hectoranswer2 = input("Answer(lowercase letter): ")
        if hectoranswer2 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1
        else: 
          print("The answer is not" , + hectoranswer2)
    else:
      hectoranswer2 = input("Answer(lowercase letter): ")
      if hectoranswer2 == "b":
        print("Correct!")
        print("You have collected Hector! The History character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif hectoranswer2 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            hectoranswerdouble2 = input('''What South American country had a monarchy for more than 60 years?
  a) Peru
  b) Brazil
  c) Ecuador
  d) Chile''')
            if hectoranswerdouble2 == "b":
              print("Correct, see you could do it!")
              print("You have collected Hector! The History character!")
              num_correct += 1
            else: 
              print("The answer is not" , + hectoranswerdouble2)


  if choice2 == "Tito":
    print("As you enter the hall with the title, Tito, it suddenly smells like the ocean")
    time.sleep(1)
    print("You see the halls covered with maps of different regions across the world, and see a light at the end of the hall")
    time.sleep(1)
    print("You enter onto a mountain hill with Tito, the globe, standing with binoculars")
    time.sleep(1)
    print(" Tito says 'LOOOK AT THIS VIEW, glad you could make it, ready for some geography trvia!")
    time.sleep(4)
    print(''' SDE is the international code for what country?
  a) Denmark
  b) Russia
  c) Germany
  d) Portugual''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetito2 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetito2 == "yes":
        print("Ok")
        time.sleep(1)
        titoanswerskip2 = input('''How many countries border with Egypt?
  a) 2
  b) 7 
  c) 4
  d) 3''')
        if titoanswerskip2 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1          
        else:
          print("The answer is not" , + titoanswerskip2)
          #Now unto the instance where they say 'no'
      else:
        titoanswer2 = input("Answer(lowercase letter): ")
        if titoanswer2 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1
        else: 
          print("The answer is not" , + titoanswer2)
    else:
      titoanswer2 = input("Answer(lowercase letter): ")
      if titoanswer2 == "c":
        print("Correct!")
        print("You have collected Tito! The Geography character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif titoanswer2 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            titoanswerdouble2 = input(''' SDE is the international code for what country?
  a) Denmark
  b) Russia
  c) Germany
  d) Portugual''')
            if titoanswerdouble2 == "c":
              print("Correct, see you could do it!")
              print("You have collected Tito! The Geography character!")
              num_correct += 1
            else: 
              print("The answer is not" , + titoanswerdouble2)


  time.sleep(4)
  print("You head back down the" , choice2 + "path")
  time.sleep(1)
  print("You have these paths left" , characters)
  choice3 = input("What path do you choose next: ")
  characters.remove(choice3)


  ####CHOICE THREE
  if choice3 == "Bonzo":
    print("You step down the hall marked, Bonzo, and as you travel down the hall, the sounds of cheers fill up the darkened hall")
    time.sleep(1)
    print("You see a light, and as you emerge from the dark hall, you realize you're in a football field with the stadium filled")
    time.sleep(1)
    print("You step out unto the green field with crowd roaring, as the jumbotron turns on")
    time.sleep(1)
    print("The screen reads 'Welcome to the sports category! Get ready for your first question' ")
    time.sleep(1)
    print('''From which country is the athlete Maria Mutola, who won her eighth world title in Paris in 2003?
  a) Mozambique
  b) America
  c) Brazil
  d) Senegal''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuebonzo3 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuebonzo3 == "yes":
        print("Ok")
        time.sleep(1)
        bonzoanswerskip3 = input('''How many fights did Muhammad Ali win during his career?
  a) 56
  b) 44
  c) 52
  d) 48''')
        if bonzoanswerskip3 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1          
        else:
          print("The answer is 56 not" , + bonzoanswerskip3)
          #Now unto the instance where they say 'no'
      else:
        bonzoanswer3 = input("Answer(lowercase letter): ")
        if bonzoanswer3 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1
        else: 
          print("The answer is not" , + bonzoanswer3)
    else:
      bonzoanswer3 = input("Answer(lowercase letter): ")
      if bonzoanswer3 == "a":
        print("Correct!")
        print("You have collected Bonzo! The Sports character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif bonzoanswer3 != "a" and powerup == 2:
            print("Let's use double chance, try again!")
            bonzoanswerdouble3 = input('''From which country is the athlete Maria Mutola, who won her eighth world title in Paris in 2003?
  a) Mozambique
  b) America
  c) Brazil
  d) Senegal''')
            if bonzoanswerdouble3 == "a":
              print("Correct, see you could do it!")
              print("You have collected Bonzo! The Sports character!")
              num_correct += 1
            else: 
              print("The answer is not" , + bonzoanswerdouble3)

  if choice3 == "Pop":
    print("You tread down the hall marked, Pop, that is covered with movie posters and albums, and hear soft voices emerging")
    time.sleep(1)
    print("You see a light coming from a screen playing a movie, and as you emerge from the dark hall, you realize you're in a movie theater, seats filled")
    time.sleep(1)
    print("The character Pop, who looks like popcorn, is sitting on the screen")
    time.sleep(1)
    print(" Pop yells 'HEYYY THERE AND WELCOME to the entertainment category! Best category if you ask me! ")
    time.sleep(1)
    print("If you're a real enteratinment buff let's see if you can answer my questions!! ")
    time.sleep(1)
    print('''How many letters did Noah write to Allie in The Notebook?
  a) 300
  b) 365
  c) 412
  d) 286''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuepop3 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuepop3 == "yes":
        print("Ok")
        time.sleep(1)
        popanswerskip3 = input('''What year did ‘Thriller’, by Micheal Jackson, come out?
  a) 1979
  b) 1982
  c) 1985
  d) 1987''')
        if popanswerskip3 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1          
        else:
          print("The answer is not" , + popanswerskip3)
          #Now unto the instance where they say 'no'
      else:
        popanswer3 = input("Answer(lowercase letter): ")
        if popanswer3 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1
        else: 
          print("The answer is not" , + popanswer3)
    else:
      popanswer3 = input("Answer(lowercase letter): ")
      if popanswer3 == "b":
        print("Correct!")
        print("You have collected POP! The Entertainment character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif popanswer3 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            popanswerdouble3 = input('''How many letters did Noah write to Allie in The Notebook?
  a) 300
  b) 365
  c) 412
  d) 286''')
            if popanswerdouble3 == "b":
              print("Correct, see you could do it!")
              print("You have collected POP! The Entertainment character!")
              num_correct += 1
            else: 
              print("The answer is not" , + popanswerdouble3)

  
  if choice3 == "Al":
    print("You start skipping down the very well lit hall marked, Al, and as you're going down , you can hear explosions in the background")
    time.sleep(1)
    print("You see a labortaory, with many chemical reactions appearing, you realize you're in the middle of a Bill Nye the Science guy episode")
    time.sleep(1)
    print("You see he's doing a an episode with AL the beaker, who notices you're prescence")
    time.sleep(1)
    print(" Al says to you 'hey there, ready for some REAL intellitecual questions my fellow science enthusist' (just say yes)")
    time.sleep(1)
    input()
    time.sleep(1)
    print(''' OKK, What animal has the highest blood pressure?
  a) Elephant
  b) Humans
  c) Giraffe
  d) Kangaroo''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continueal3 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continueal3 == "yes":
        print("Ok")
        time.sleep(1)
        alanswerskip3 = input('''What does vexology study
  a) Witchcraft
  b) Pantries
  c) Flags
  d) Handwriting''')
        if alanswerskip3 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1          
        else:
          print("The answer is not " , + alanswerskip3)
          #Now unto the instance where they say 'no'
      else:
        alanswer3 = input("Answer(lowercase letter): ")
        if alanswer3 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1
        else: 
          print("The answer is not " , + alanswer3)
    else:
      alanswer3 = input("Answer(lowercase letter): ")
      if alanswer3 == "c":
        print("Correct!")
        print("You have collected AL! The Science character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif alanswer3 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            alanswerdouble3 = input(''' OKK, What animal has the highest blood pressure?
  a) Elephant
  b) Humans
  c) Giraffe
  d) Kangaroo''')
            if alanswerdouble3 == "c":
              print("Correct, see you could do it!")
              print("You have collected AL! The Science character!")
              num_correct += 1
            else: 
              print("The answer is not " , + alanswerdouble3)


  if choice3 == "Tina":
    print("You bolt down the hall with the title, TINA in a very fancy font, and as you're going down , you hear clicks and flashes of phones")
    time.sleep(1)
    print("The hall is decroated lavishly, with iconic paintings like the Mona Lisa")
    time.sleep(1)
    print("You enter into an art gallery with many people, and Tina the paintbrush finishing their art")
    time.sleep(1)
    print(" Tina says 'Hey, I'm Tina, glad you came to my art show, ready for some trvia!")
    time.sleep(4)
    print(''' What is writer Paul Auster’s favourite city, according to his novels?
  a) Chicago
  b) London
  c) Paris
  d) New York''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetina3 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetina3 == "yes":
        print("Ok")
        time.sleep(1)
        tinaanswerskip3 = input('''What year was ‘El Quijote’ published?
  a) 1773
  b) 1545 
  c) 1866
  d) 1605''')
        if tinaanswerskip3 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1          
        else:
          print("The answer is not" , + tinaanswerskip3)
          #Now unto the instance where they say 'no'
      else:
        tinaanswer3 = input("Answer(lowercase letter): ")
        if tinaanswer3 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1
        else: 
          print("The answer is not" , + tinaanswer3)
    else:
      tinaanswer3 = input("Answer(lowercase letter): ")
      if tinaanswer3 == "d":
        print("Correct!")
        print("You have collected TINA! The art character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif tinaanswer3 != "d" and powerup == 2:
            print("Let's use double chance, try again!")
            tinaanswerdouble3 = input(''' What is writer Paul Auster’s favourite city, according to his novels?
  a) Chicago
  b) London
  c) Paris
  d) New York''')
            if tinaanswerdouble3 == "d":
              print("Correct, see you could do it!")
              print("You have collected TINA! The art character!")
              num_correct += 1
            else: 
              print("The answer is not" , + tinaanswerdouble3)


  if choice3 == "Hector":
    print("You walk into the hall marked Hector when a sudden wave of old people smeel whiffs through the air")
    time.sleep(1)
    print("The hall is adorned with countless documents and events from scattered places and times in history")
    time.sleep(1)
    print("After you finally reach the end, you enter into a socratic seminar with Hector the Knight leading")
    time.sleep(1)
    print(" Hector looks over and says 'Ah I see you're here to interupt, better know some trivia then!!")
    time.sleep(4)
    print('''What South American country had a monarchy for more than 60 years?
  a) Peru
  b) Brazil
  c) Ecuador
  d) Chile''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuehector3 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuehector3 == "yes":
        print("Ok")
        time.sleep(1)
        hectoranswerskip3 = input(''' How many people died in the Munich massacre of 1972?
  a) 23
  b) 17 
  c) 21
  d) 12''')
        if hectoranswerskip3 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1          
        else:
          print("The answer is, not" , + hectoranswerskip3)
          #Now unto the instance where they say 'no'
      else:
        hectoranswer3 = input("Answer(lowercase letter): ")
        if hectoranswer3 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1
        else: 
          print("The answer is not" , + hectoranswer3)
    else:
      hectoranswer3 = input("Answer(lowercase letter): ")
      if hectoranswer3 == "b":
        print("Correct!")
        print("You have collected Hector! The History character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif hectoranswer3 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            hectoranswerdouble3 = input('''What South American country had a monarchy for more than 60 years?
  a) Peru
  b) Brazil
  c) Ecuador
  d) Chile''')
            if hectoranswerdouble3 == "b":
              print("Correct, see you could do it!")
              print("You have collected Hector! The History character!")
              num_correct += 1
            else: 
              print("The answer is not" , + hectoranswerdouble3)


  if choice3 == "Tito":
    print("As you enter the hall with the title, Tito, it suddenly smells like the ocean")
    time.sleep(1)
    print("You see the halls covered with maps of different regions across the world, and see a light at the end of the hall")
    time.sleep(1)
    print("You enter onto a mountain hill with Tito, the globe, standing with binoculars")
    time.sleep(1)
    print(" Tito says 'LOOOK AT THIS VIEW, glad you could make it, ready for some geography trvia!")
    time.sleep(4)
    print(''' SDE is the international code for what country?
  a) Denmark
  b) Russia
  c) Germany
  d) Portugual''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetito3 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetito3 == "yes":
        print("Ok")
        time.sleep(1)
        titoanswerskip3 = input('''How many countries border with Egypt?
  a) 2
  b) 7 
  c) 4
  d) 3''')
        if titoanswerskip3 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1          
        else:
          print("The answer is not" , + titoanswerskip3)
          #Now unto the instance where they say 'no'
      else:
        titoanswer3 = input("Answer(lowercase letter): ")
        if titoanswer3 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1
        else: 
          print("The answer is not" , + titoanswer3)
    else:
      titoanswer3 = input("Answer(lowercase letter): ")
      if titoanswer3 == "c":
        print("Correct!")
        print("You have collected Tito! The Geography character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif titoanswer3 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            titoanswerdouble3 = input(''' SDE is the international code for what country?
  a) Denmark
  b) Russia
  c) Germany
  d) Portugual''')
            if titoanswerdouble3 == "c":
              print("Correct, see you could do it!")
              print("You have collected Tito! The Geography character!")
              num_correct += 1
            else: 
              print("The answer is not" , + titoanswerdouble3)


  time.sleep(4)
  print("You head back down the" , choice3 + "path")
  time.sleep(1)
  print("You have these paths left" , characters)
  choice4 = input("What path do you choose next: ")
  characters.remove(choice4)


  ########CHOICE FOUR##################

  if choice4 == "Bonzo":
    print("You step down the hall marked, Bonzo, and as you travel down the hall, the sounds of cheers fill up the darkened hall")
    time.sleep(1)
    print("You see a light, and as you emerge from the dark hall, you realize you're in a football field with the stadium filled")
    time.sleep(1)
    print("You step out unto the green field with crowd roaring, as the jumbotron turns on")
    time.sleep(1)
    print("The screen reads 'Welcome to the sports category! Get ready for your first question' ")
    time.sleep(1)
    print('''From which country is the athlete Maria Mutola, who won her eighth world title in Paris in 2003?
  a) Mozambique
  b) America
  c) Brazil
  d) Senegal''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuebonzo4 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuebonzo4 == "yes":
        print("Ok")
        time.sleep(1)
        bonzoanswerskip4 = input('''How many fights did Muhammad Ali win during his career?
  a) 56
  b) 44
  c) 52
  d) 48''')
        if bonzoanswerskip4 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1          
        else:
          print("The answer is not" , + bonzoanswerskip4)
          #Now unto the instance where they say 'no'
      else:
        bonzoanswer4 = input("Answer(lowercase letter): ")
        if bonzoanswer4 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1
        else: 
          print("The answer is not" , + bonzoanswer4)
    else:
      bonzoanswer4 = input("Answer(lowercase letter): ")
      if bonzoanswer4 == "a":
        print("Correct!")
        print("You have collected Bonzo! The Sports character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif bonzoanswer4 != "a" and powerup == 2:
            print("Let's use double chance, try again!")
            bonzoanswerdouble4 = input('''From which country is the athlete Maria Mutola, who won her eighth world title in Paris in 2003?
  a) Mozambique
  b) America
  c) Brazil
  d) Senegal''')
            if bonzoanswerdouble4 == "a":
              print("Correct, see you could do it!")
              print("You have collected Bonzo! The Sports character!")
              num_correct += 1
            else: 
              print("The answer is not" , + bonzoanswerdouble4)

  if choice4 == "Pop":
    print("You tread down the hall marked, Pop, that is covered with movie posters and albums, and hear soft voices emerging")
    time.sleep(1)
    print("You see a light coming from a screen playing a movie, and as you emerge from the dark hall, you realize you're in a movie theater, seats filled")
    time.sleep(1)
    print("The character Pop, who looks like popcorn, is sitting on the screen")
    time.sleep(1)
    print(" Pop yells 'HEYYY THERE AND WELCOME to the entertainment category! Best category if you ask me! ")
    time.sleep(1)
    print("If you're a real enteratinment buff let's see if you can answer my questions!! ")
    time.sleep(1)
    print('''How many letters did Noah write to Allie in The Notebook?
  a) 300
  b) 365
  c) 412
  d) 286''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuepop4 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuepop4 == "yes":
        print("Ok")
        time.sleep(1)
        popanswerskip4 = input('''What year did ‘Thriller’, by Micheal Jackson, come out?
  a) 1979
  b) 1982
  c) 1985
  d) 1987''')
        if popanswerskip4 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1          
        else:
          print("The answer is not" , + popanswerskip4)
          #Now unto the instance where they say 'no'
      else:
        popanswer4 = input("Answer(lowercase letter): ")
        if popanswer4 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1
        else: 
          print("The answer is not" , + popanswer4)
    else:
      popanswer4 = input("Answer(lowercase letter): ")
      if popanswer4 == "b":
        print("Correct!")
        print("You have collected POP! The Entertainment character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif popanswer4 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            popanswerdouble4 = input('''How many letters did Noah write to Allie in The Notebook?
  a) 300
  b) 365
  c) 412
  d) 286''')
            if popanswerdouble4 == "b":
              print("Correct, see you could do it!")
              print("You have collected POP! The Entertainment character!")
              num_correct += 1
            else: 
              print("The answer is not" , + popanswerdouble4)

  
  if choice4 == "Al":
    print("You start skipping down the very well lit hall marked, Al, and as you're going down , you can hear explosions in the background")
    time.sleep(1)
    print("You see a labortaory, with many chemical reactions appearing, you realize you're in the middle of a Bill Nye the Science guy episode")
    time.sleep(1)
    print("You see he's doing a an episode with AL the beaker, who notices you're prescence")
    time.sleep(1)
    print(" Al says to you 'hey there, ready for some REAL intellitecual questions my fellow science enthusist' (just say yes)")
    time.sleep(1)
    input()
    time.sleep(1)
    print(''' OKK, What animal has the highest blood pressure?
  a) Elephant
  b) Humans
  c) Giraffe
  d) Kangaroo''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continueal4 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continueal4 == "yes":
        print("Ok")
        time.sleep(1)
        alanswerskip4 = input('''What does vexology study
  a) Witchcraft
  b) Pantries
  c) Flags
  d) Handwriting''')
        if alanswerskip4 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1          
        else:
          print("The answer is not " , + alanswerskip4)
          #Now unto the instance where they say 'no'
      else:
        alanswer4 = input("Answer(lowercase letter): ")
        if alanswer4 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1
        else: 
          print("The answer is not " , + alanswer4)
    else:
      alanswer4 = input("Answer(lowercase letter): ")
      if alanswer4 == "c":
        print("Correct!")
        print("You have collected AL! The Science character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif alanswer4 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            alanswerdouble4 = input(''' OKK, What animal has the highest blood pressure?
  a) Elephant
  b) Humans
  c) Giraffe
  d) Kangaroo''')
            if alanswerdouble4 == "c":
              print("Correct, see you could do it!")
              print("You have collected AL! The Science character!")
              num_correct += 1
            else: 
              print("The answer is not " , + alanswerdouble4)

  if choice4 == "Tina":
    print("You bolt down the hall with the title, TINA in a very fancy font, and as you're going down , you hear clicks and flashes of phones")
    time.sleep(1)
    print("The hall is decroated lavishly, with iconic paintings like the Mona Lisa")
    time.sleep(1)
    print("You enter into an art gallery with many people, and Tina the paintbrush finishing their art")
    time.sleep(1)
    print(" Tina says 'Hey, I'm Tina, glad you came to my art show, ready for some trvia!")
    time.sleep(4)
    print(''' What is writer Paul Auster’s favourite city, according to his novels?
  a) Chicago
  b) London
  c) Paris
  d) New York''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetina4 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetina4 == "yes":
        print("Ok")
        time.sleep(1)
        tinaanswerskip4 = input('''What year was ‘El Quijote’ published?
  a) 1773
  b) 1545 
  c) 1866
  d) 1605''')
        if tinaanswerskip4 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1          
        else:
          print("The answer is not" , + tinaanswerskip4)
          #Now unto the instance where they say 'no'
      else:
        tinaanswer4 = input("Answer(lowercase letter): ")
        if tinaanswer4 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1
        else: 
          print("The answer is not" , + tinaanswer4)
    else:
      tinaanswer4 = input("Answer(lowercase letter): ")
      if tinaanswer4 == "d":
        print("Correct!")
        print("You have collected TINA! The art character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif tinaanswer4 != "d" and powerup == 2:
            print("Let's use double chance, try again!")
            tinaanswerdouble4 = input(''' What is writer Paul Auster’s favourite city, according to his novels?
  a) Chicago
  b) London
  c) Paris
  d) New York''')
            if tinaanswerdouble4 == "d":
              print("Correct, see you could do it!")
              print("You have collected TINA! The art character!")
              num_correct += 1
            else: 
              print("The answer is not" , + tinaanswerdouble4)


  if choice4 == "Hector":
    print("You walk into the hall marked Hector when a sudden wave of old people smeel whiffs through the air")
    time.sleep(1)
    print("The hall is adorned with countless documents and events from scattered places and times in history")
    time.sleep(1)
    print("After you finally reach the end, you enter into a socratic seminar with Hector the Knight leading")
    time.sleep(1)
    print(" Hector looks over and says 'Ah I see you're here to interupt, better know some trivia then!!")
    time.sleep(4)
    print('''What South American country had a monarchy for more than 60 years?
  a) Peru
  b) Brazil
  c) Ecuador
  d) Chile''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuehector4 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuehector4 == "yes":
        print("Ok")
        time.sleep(1)
        hectoranswerskip4 = input(''' How many people died in the Munich massacre of 1972?
  a) 23
  b) 17 
  c) 21
  d) 12''')
        if hectoranswerskip4 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1          
        else:
          print("The answer is not" , + hectoranswerskip4)
          #Now unto the instance where they say 'no'
      else:
        hectoranswer4 = input("Answer(lowercase letter): ")
        if hectoranswer4 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1
        else: 
          print("The answer is not" , + hectoranswer4)
    else:
      hectoranswer4 = input("Answer(lowercase letter): ")
      if hectoranswer4 == "b":
        print("Correct!")
        print("You have collected Hector! The History character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif hectoranswer4 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            hectoranswerdouble4 = input('''What South American country had a monarchy for more than 60 years?
  a) Peru
  b) Brazil
  c) Ecuador
  d) Chile''')
            if hectoranswerdouble4 == "b":
              print("Correct, see you could do it!")
              print("You have collected Hector! The History character!")
              num_correct += 1
            else: 
              print("The answer is not" , + hectoranswerdouble4)

  
  if choice4 == "Tito":
    print("As you enter the hall with the title, Tito, it suddenly smells like the ocean")
    time.sleep(1)
    print("You see the halls covered with maps of different regions across the world, and see a light at the end of the hall")
    time.sleep(1)
    print("You enter onto a mountain hill with Tito, the globe, standing with binoculars")
    time.sleep(1)
    print(" Tito says 'LOOOK AT THIS VIEW, glad you could make it, ready for some geography trvia!")
    time.sleep(4)
    print(''' SDE is the international code for what country?
  a) Denmark
  b) Russia
  c) Germany
  d) Portugual''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetito4 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetito4 == "yes":
        print("Ok")
        time.sleep(1)
        titoanswerskip4 = input('''How many countries border with Egypt?
  a) 2
  b) 7 
  c) 4
  d) 3''')
        if titoanswerskip4 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1          
        else:
          print("The answer is, not" , + titoanswerskip4)
          #Now unto the instance where they say 'no'
      else:
        titoanswer4 = input("Answer(lowercase letter): ")
        if titoanswer4 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1
        else: 
          print("The answer is not" , + titoanswer4)
    else:
      titoanswer4 = input("Answer(lowercase letter): ")
      if titoanswer4 == "c":
        print("Correct!")
        print("You have collected Tito! The Geography character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif titoanswer4 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            titoanswerdouble4 = input(''' SDE is the international code for what country?
  a) Denmark
  b) Russia
  c) Germany
  d) Portugual''')
            if titoanswerdouble4 == "c":
              print("Correct, see you could do it!")
              print("You have collected Tito! The Geography character!")
              num_correct += 1
            else: 
              print("The answer is not" , + titoanswerdouble4)


  time.sleep(4)
  print("You head back down the" , choice4 + "path")
  time.sleep(1)
  print("You have these paths left" , characters)
  choice5 = input("What path do you choose next: ")
  characters.remove(choice5)


  #######CHOICE FIVE#################################

  if choice5 == "Bonzo":
    print("You step down the hall marked, Bonzo, and as you travel down the hall, the sounds of cheers fill up the darkened hall")
    time.sleep(1)
    print("You see a light, and as you emerge from the dark hall, you realize you're in a football field with the stadium filled")
    time.sleep(1)
    print("You step out unto the green field with crowd roaring, as the jumbotron turns on")
    time.sleep(1)
    print("The screen reads 'Welcome to the sports category! Get ready for your first question' ")
    time.sleep(1)
    print('''From which country is the athlete Maria Mutola, who won her eighth world title in Paris in 2003?
  a) Mozambique
  b) America
  c) Brazil
  d) Senegal''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuebonzo5 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuebonzo5 == "yes":
        print("Ok")
        time.sleep(1)
        bonzoanswerskip5 = input('''How many fights did Muhammad Ali win during his career?
  a) 56
  b) 44
  c) 52
  d) 48''')
        if bonzoanswerskip5 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1          
        else:
          print("The answer is not" , + bonzoanswerskip5)
          #Now unto the instance where they say 'no'
      else:
        bonzoanswer5 = input("Answer(lowercase letter): ")
        if bonzoanswer5 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1
        else: 
          print("The answer is not" , + bonzoanswer5)
    else:
      bonzoanswer5 = input("Answer(lowercase letter): ")
      if bonzoanswer5 == "a":
        print("Correct!")
        print("You have collected Bonzo! The Sports character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif bonzoanswer5 != "a" and powerup == 2:
            print("Let's use double chance, try again!")
            bonzoanswerdouble5 = input('''From which country is the athlete Maria Mutola, who won her eighth world title in Paris in 2003?
  a) Mozambique
  b) America
  c) Brazil
  d) Senegal''')
            if bonzoanswerdouble5 == "a":
              print("Correct, see you could do it!")
              print("You have collected Bonzo! The Sports character!")
              num_correct += 1
            else: 
              print("The answer is not" , + bonzoanswerdouble5)
  
  if choice5 == "Pop":
    print("You tread down the hall marked, Pop, that is covered with movie posters and albums, and hear soft voices emerging")
    time.sleep(1)
    print("You see a light coming from a screen playing a movie, and as you emerge from the dark hall, you realize you're in a movie theater, seats filled")
    time.sleep(1)
    print("The character Pop, who looks like popcorn, is sitting on the screen")
    time.sleep(1)
    print(" Pop yells 'HEYYY THERE AND WELCOME to the entertainment category! Best category if you ask me! ")
    time.sleep(1)
    print("If you're a real enteratinment buff let's see if you can answer my questions!! ")
    time.sleep(1)
    print('''How many letters did Noah write to Allie in The Notebook?
  a) 300
  b) 365
  c) 412
  d) 286''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuepop5 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuepop5 == "yes":
        print("Ok")
        time.sleep(1)
        popanswerskip5 = input('''What year did ‘Thriller’, by Micheal Jackson, come out?
  a) 1979
  b) 1982
  c) 1985
  d) 1987''')
        if popanswerskip5 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1          
        else:
          print("The answer is not " , + popanswerskip5)
          #Now unto the instance where they say 'no'
      else:
        popanswer5 = input("Answer(lowercase letter): ")
        if popanswer5 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1
        else: 
          print("The answer is not " , + popanswer5)
    else:
      popanswer5 = input("Answer(lowercase letter): ")
      if popanswer5 == "b":
        print("Correct!")
        print("You have collected POP! The Entertainment character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif popanswer5 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            popanswerdouble5 = input('''How many letters did Noah write to Allie in The Notebook?
  a) 300
  b) 365
  c) 412
  d) 286''')
            if popanswerdouble5 == "b":
              print("Correct, see you could do it!")
              print("You have collected POP! The Entertainment character!")
              num_correct += 1
            else: 
              print("The answer is not " , + popanswerdouble5)

  
  if choice5 == "Al":
    print("You start skipping down the very well lit hall marked, Al, and as you're going down , you can hear explosions in the background")
    time.sleep(1)
    print("You see a labortaory, with many chemical reactions appearing, you realize you're in the middle of a Bill Nye the Science guy episode")
    time.sleep(1)
    print("You see he's doing a an episode with AL the beaker, who notices you're prescence")
    time.sleep(1)
    print(" Al says to you 'hey there, ready for some REAL intellitecual questions my fellow science enthusist' (just say yes)")
    time.sleep(1)
    input()
    time.sleep(1)
    print(''' OKK, What animal has the highest blood pressure?
  a) Elephant
  b) Humans
  c) Giraffe
  d) Kangaroo''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continueal5 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continueal5 == "yes":
        print("Ok")
        time.sleep(1)
        alanswerskip5 = input('''What does vexology study
  a) Witchcraft
  b) Pantries
  c) Flags
  d) Handwriting''')
        if alanswerskip5 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1          
        else:
          print("The answer is, not" , + alanswerskip5)
          #Now unto the instance where they say 'no'
      else:
        alanswer5 = input("Answer(lowercase letter): ")
        if alanswer5 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1
        else: 
          print("The answer is, not" , + alanswer5)
    else:
      alanswer5 = input("Answer(lowercase letter): ")
      if alanswer5 == "c":
        print("Correct!")
        print("You have collected AL! The Science character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif alanswer5 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            alanswerdouble5 = input(''' OKK, What animal has the highest blood pressure?
  a) Elephant
  b) Humans
  c) Giraffe
  d) Kangaroo''')
            if alanswerdouble5 == "c":
              print("Correct, see you could do it!")
              print("You have collected AL! The Science character!")
              num_correct += 1
            else: 
              print("The answer is not " , + alanswerdouble5)


  if choice5 == "Tina":
    print("You bolt down the hall with the title, TINA in a very fancy font, and as you're going down , you hear clicks and flashes of phones")
    time.sleep(1)
    print("The hall is decroated lavishly, with iconic paintings like the Mona Lisa")
    time.sleep(1)
    print("You enter into an art gallery with many people, and Tina the paintbrush finishing their art")
    time.sleep(1)
    print(" Tina says 'Hey, I'm Tina, glad you came to my art show, ready for some trvia!")
    time.sleep(4)
    print(''' What is writer Paul Auster’s favourite city, according to his novels?
  a) Chicago
  b) London
  c) Paris
  d) New York''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetina5 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetina5 == "yes":
        print("Ok")
        time.sleep(1)
        tinaanswerskip5 = input('''What year was ‘El Quijote’ published?
  a) 1773
  b) 1545 
  c) 1866
  d) 1605''')
        if tinaanswerskip5 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1          
        else:
          print("The answer is not" , + tinaanswerskip5)
          #Now unto the instance where they say 'no'
      else:
        tinaanswer5 = input("Answer(lowercase letter): ")
        if tinaanswer5 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1
        else: 
          print("The answer is not" , + tinaanswer5)
    else:
      tinaanswer5 = input("Answer(lowercase letter): ")
      if tinaanswer5 == "d":
        print("Correct!")
        print("You have collected TINA! The art character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif tinaanswer5 != "d" and powerup == 2:
            print("Let's use double chance, try again!")
            tinaanswerdouble5 = input(''' What is writer Paul Auster’s favourite city, according to his novels?
  a) Chicago
  b) London
  c) Paris
  d) New York''')
            if tinaanswerdouble5 == "d":
              print("Correct, see you could do it!")
              print("You have collected TINA! The art character!")
              num_correct += 1
            else: 
              print("The answer is not" , + tinaanswerdouble5)


  if choice5 == "Hector":
    print("You walk into the hall marked Hector when a sudden wave of old people smeel whiffs through the air")
    time.sleep(1)
    print("The hall is adorned with countless documents and events from scattered places and times in history")
    time.sleep(1)
    print("After you finally reach the end, you enter into a socratic seminar with Hector the Knight leading")
    time.sleep(1)
    print(" Hector looks over and says 'Ah I see you're here to interupt, better know some trivia then!!")
    time.sleep(4)
    print('''What South American country had a monarchy for more than 60 years?
  a) Peru
  b) Brazil
  c) Ecuador
  d) Chile''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuehector5 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuehector5 == "yes":
        print("Ok")
        time.sleep(1)
        hectoranswerskip5 = input(''' How many people died in the Munich massacre of 1972?
  a) 23
  b) 17 
  c) 21
  d) 12''')
        if hectoranswerskip5 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1          
        else:
          print("The answer is not" , + hectoranswerskip5)
          #Now unto the instance where they say 'no'
      else:
        hectoranswer5 = input("Answer(lowercase letter): ")
        if hectoranswer5 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1
        else: 
          print("The answer is not" , + hectoranswer5)
    else:
      hectoranswer5 = input("Answer(lowercase letter): ")
      if hectoranswer5 == "b":
        print("Correct!")
        print("You have collected Hector! The History character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif hectoranswer5 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            hectoranswerdouble5 = input('''What South American country had a monarchy for more than 60 years?
  a) Peru
  b) Brazil
  c) Ecuador
  d) Chile''')
            if hectoranswerdouble5 == "b":
              print("Correct, see you could do it!")
              print("You have collected Hector! The History character!")
              num_correct += 1
            else: 
              print("The answer is, not" , + hectoranswerdouble5)


  if choice5 == "Tito":
    print("As you enter the hall with the title, Tito, it suddenly smells like the ocean")
    time.sleep(1)
    print("You see the halls covered with maps of different regions across the world, and see a light at the end of the hall")
    time.sleep(1)
    print("You enter onto a mountain hill with Tito, the globe, standing with binoculars")
    time.sleep(1)
    print(" Tito says 'LOOOK AT THIS VIEW, glad you could make it, ready for some geography trvia!")
    time.sleep(4)
    print(''' SDE is the international code for what country?
  a) Denmark
  b) Russia
  c) Germany
  d) Portugual''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetito5 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetito5 == "yes":
        print("Ok")
        time.sleep(1)
        titoanswerskip5 = input('''How many countries border with Egypt?
  a) 2
  b) 7 
  c) 4
  d) 3''')
        if titoanswerskip5 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1          
        else:
          print("The answer is, not" , + titoanswerskip5)
          #Now unto the instance where they say 'no'
      else:
        titoanswer5 = input("Answer(lowercase letter): ")
        if titoanswer5 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1
        else: 
          print("The answer is not" , + titoanswer5)
    else:
      titoanswer5 = input("Answer(lowercase letter): ")
      if titoanswer5 == "c":
        print("Correct!")
        print("You have collected Tito! The Geography character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif titoanswer != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            titoanswerdouble5 = input(''' SDE is the international code for what country?
  a) Denmark
  b) Russia
  c) Germany
  d) Portugual''')
            if titoanswerdouble5 == "c":
              print("Correct, see you could do it!")
              print("You have collected Tito! The Geography character!")
              num_correct += 1
            else: 
              print("The answer is not" , + titoanswerdouble5)

  time.sleep(4)
  print("You head back down the" , choice5 + "path")
  time.sleep(1)
  print("You have this path left" , characters)
  choice6 = input("Type in your last path!: ")
  characters.remove(choice6)


  ###########CHOICE SIX###############


  if choice6 == "Bonzo":
    print("You step down the hall marked, Bonzo, and as you travel down the hall, the sounds of cheers fill up the darkened hall")
    time.sleep(1)
    print("You see a light, and as you emerge from the dark hall, you realize you're in a football field with the stadium filled")
    time.sleep(1)
    print("You step out unto the green field with crowd roaring, as the jumbotron turns on")
    time.sleep(1)
    print("The screen reads 'Welcome to the sports category! Get ready for your first question' ")
    time.sleep(1)
    print('''From which country is the athlete Maria Mutola, who won her eighth world title in Paris in 2003?
  a) Mozambique
  b) America
  c) Brazil
  d) Senegal''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuebonzo6 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuebonzo6 == "yes":
        print("Ok")
        time.sleep(1)
        bonzoanswerskip6 = input('''How many fights did Muhammad Ali win during his career?
  a) 56
  b) 44
  c) 52
  d) 48''')
        if bonzoanswerskip6 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1          
        else:
          print("The answer is not" , + bonzoanswerskip6)
          #Now unto the instance where they say 'no'
      else:
        bonzoanswer6 = input("Answer(lowercase letter): ")
        if bonzoanswer6 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1
        else: 
          print("The answer is not" , + bonzoanswer6)
    else:
      bonzoanswer6 = input("Answer(lowercase letter): ")
      if bonzoanswer6 == "a":
        print("Correct!")
        print("You have collected Bonzo! The Sports character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif bonzoanswer6 != "a" and powerup == 2:
            print("Let's use double chance, try again!")
            bonzoanswerdouble6 = input('''From which country is the athlete Maria Mutola, who won her eighth world title in Paris in 2003?
  a) Mozambique
  b) America
  c) Brazil
  d) Senegal''')
            if bonzoanswerdouble6 == "a":
              print("Correct, see you could do it!")
              print("You have collected Bonzo! The Sports character!")
              num_correct += 1
            else: 
              print("The answer is not" , + bonzoanswerdouble6)

  if choice6 == "Pop":
    print("You tread down the hall marked, Pop, that is covered with movie posters and albums, and hear soft voices emerging")
    time.sleep(1)
    print("You see a light coming from a screen playing a movie, and as you emerge from the dark hall, you realize you're in a movie theater, seats filled")
    time.sleep(1)
    print("The character Pop, who looks like popcorn, is sitting on the screen")
    time.sleep(1)
    print(" Pop yells 'HEYYY THERE AND WELCOME to the entertainment category! Best category if you ask me! ")
    time.sleep(1)
    print("If you're a real enteratinment buff let's see if you can answer my questions!! ")
    time.sleep(1)
    print('''How many letters did Noah write to Allie in The Notebook?
  a) 300
  b) 365
  c) 412
  d) 286''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuepop6 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuepop6 == "yes":
        print("Ok")
        time.sleep(1)
        popanswerskip6 = input('''What year did ‘Thriller’, by Micheal Jackson, come out?
  a) 1979
  b) 1982
  c) 1985
  d) 1987''')
        if popanswerskip6 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1          
        else:
          print("The answer is not " , + popanswerskip6)
          #Now unto the instance where they say 'no'
      else:
        popanswer6 = input("Answer(lowercase letter): ")
        if popanswer6 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1
        else: 
          print("The answer is not " , + popanswer6)
    else:
      popanswer6 = input("Answer(lowercase letter): ")
      if popanswer6 == "b":
        print("Correct!")
        print("You have collected POP! The Entertainment character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif popanswer6 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            popanswerdouble6 = input('''How many letters did Noah write to Allie in The Notebook?
  a) 300
  b) 365
  c) 412
  d) 286''')
            if popanswerdouble6 == "b":
              print("Correct, see you could do it!")
              print("You have collected POP! The Entertainment character!")
              num_correct += 1
            else: 
              print("The answer is not " , + popanswerdouble6)

  if choice6 == "Al":
    print("You start skipping down the very well lit hall marked, Al, and as you're going down , you can hear explosions in the background")
    time.sleep(1)
    print("You see a labortaory, with many chemical reactions appearing, you realize you're in the middle of a Bill Nye the Science guy episode")
    time.sleep(1)
    print("You see he's doing a an episode with AL the beaker, who notices you're prescence")
    time.sleep(1)
    print(" Al says to you 'hey there, ready for some REAL intellitecual questions my fellow science enthusist' (just say yes)")
    time.sleep(1)
    input()
    time.sleep(1)
    print(''' OKK, What animal has the highest blood pressure?
  a) Elephant
  b) Humans
  c) Giraffe
  d) Kangaroo''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continueal6 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continueal6 == "yes":
        print("Ok")
        time.sleep(1)
        alanswerskip6 = input('''What does vexology study
  a) Witchcraft
  b) Pantries
  c) Flags
  d) Handwriting''')
        if alanswerskip6 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1          
        else:
          print("The answer is not" , + alanswerskip6)
          #Now unto the instance where they say 'no'
      else:
        alanswer6 = input("Answer(lowercase letter): ")
        if alanswer6 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1
        else: 
          print("The answer is not" , + alanswer6)
    else:
      alanswer6 = input("Answer(lowercase letter): ")
      if alanswer6 == "c":
        print("Correct!")
        print("You have collected AL! The Science character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif alanswer6 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            alanswerdouble6 = input(''' OKK, What animal has the highest blood pressure?
  a) Elephant
  b) Humans
  c) Giraffe
  d) Kangaroo''')
            if alanswerdouble6 == "c":
              print("Correct, see you could do it!")
              print("You have collected AL! The Science character!")
              num_correct += 1
            else: 
              print("The answer is not" , + alanswerdouble6)

  if choice6 == "Tina":
    print("You bolt down the hall with the title, TINA in a very fancy font, and as you're going down , you hear clicks and flashes of phones")
    time.sleep(1)
    print("The hall is decroated lavishly, with iconic paintings like the Mona Lisa")
    time.sleep(1)
    print("You enter into an art gallery with many people, and Tina the paintbrush finishing their art")
    time.sleep(1)
    print(" Tina says 'Hey, I'm Tina, glad you came to my art show, ready for some trvia!")
    time.sleep(4)
    print(''' What is writer Paul Auster’s favourite city, according to his novels?
  a) Chicago
  b) London
  c) Paris
  d) New York''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetina6 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetina6 == "yes":
        print("Ok")
        time.sleep(1)
        tinaanswerskip6 = input('''What year was ‘El Quijote’ published?
  a) 1773
  b) 1545 
  c) 1866
  d) 1605''')
        if tinaanswerskip6 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1          
        else:
          print("The answer is, not" , + tinaanswerskip6)
          #Now unto the instance where they say 'no'
      else:
        tinaanswer6 = input("Answer(lowercase letter): ")
        if tinaanswer6 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1
        else: 
          print("The answer is, not" , + tinaanswer6)
    else:
      tinaanswer6 = input("Answer(lowercase letter): ")
      if tinaanswer6 == "d":
        print("Correct!")
        print("You have collected TINA! The art character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif tinaanswer6 != "d" and powerup == 2:
            print("Let's use double chance, try again!")
            tinaanswerdouble6 = input(''' What is writer Paul Auster’s favourite city, according to his novels?
  a) Chicago
  b) London
  c) Paris
  d) New York''')
            if tinaanswerdouble6 == "d":
              print("Correct, see you could do it!")
              print("You have collected TINA! The art character!")
              num_correct += 1
            else: 
              print("The answer is not" , + tinaanswerdouble6)


  if choice6 == "Hector":
    print("You walk into the hall marked Hector when a sudden wave of old people smeel whiffs through the air")
    time.sleep(1)
    print("The hall is adorned with countless documents and events from scattered places and times in history")
    time.sleep(1)
    print("After you finally reach the end, you enter into a socratic seminar with Hector the Knight leading")
    time.sleep(1)
    print(" Hector looks over and says 'Ah I see you're here to interupt, better know some trivia then!!")
    time.sleep(4)
    print('''What South American country had a monarchy for more than 60 years?
  a) Peru
  b) Brazil
  c) Ecuador
  d) Chile''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuehector6 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuehector6 == "yes":
        print("Ok")
        time.sleep(1)
        hectoranswerskip6 = input(''' How many people died in the Munich massacre of 1972?
  a) 23
  b) 17 
  c) 21
  d) 12''')
        if hectoranswerskip6 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1          
        else:
          print("The answer is not" , + hectoranswerskip6)
          #Now unto the instance where they say 'no'
      else:
        hectoranswer6 = input("Answer(lowercase letter): ")
        if hectoranswer6 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1
        else: 
          print("The answer is not" , + hectoranswer6)
    else:
      hectoranswer6 = input("Answer(lowercase letter): ")
      if hectoranswer6 == "b":
        print("Correct!")
        print("You have collected Hector! The History character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif hectoranswer6 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            hectoranswerdouble6 = input('''What South American country had a monarchy for more than 60 years?
  a) Peru
  b) Brazil
  c) Ecuador
  d) Chile''')
            if hectoranswerdouble6 == "b":
              print("Correct, see you could do it!")
              print("You have collected Hector! The History character!")
              num_correct += 1
            else: 
              print("The answer is not" , + hectoranswerdouble6)


  if choice6 == "Tito":
    print("As you enter the hall with the title, Tito, it suddenly smells like the ocean")
    time.sleep(1)
    print("You see the halls covered with maps of different regions across the world, and see a light at the end of the hall")
    time.sleep(1)
    print("You enter onto a mountain hill with Tito, the globe, standing with binoculars")
    time.sleep(1)
    print(" Tito says 'LOOOK AT THIS VIEW, glad you could make it, ready for some geography trvia!")
    time.sleep(4)
    print(''' SDE is the international code for what country?
  a) Denmark
  b) Russia
  c) Germany
  d) Portugual''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetito6 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetito6 == "yes":
        print("Ok")
        time.sleep(1)
        titoanswerskip6 = input('''How many countries border with Egypt?
  a) 2
  b) 7 
  c) 4
  d) 3''')
        if titoanswerskip6 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1          
        else:
          print("The answer is not" , + titoanswerskip6)
          #Now unto the instance where they say 'no'
      else:
        titoanswer6 = input("Answer(lowercase letter): ")
        if titoanswer6 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1
        else: 
          print("The answer is  not" , + titoanswer6)
    else:
      titoanswer6 = input("Answer(lowercase letter): ")
      if titoanswer6 == "c":
        print("Correct!")
        print("You have collected Tito! The Geography character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif titoanswer6 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            titoanswerdouble6 = input(''' SDE is the international code for what country?
  a) Denmark
  b) Russia
  c) Germany
  d) Portugual''')
            if titoanswerdouble6 == "c":
              print("Correct, see you could do it!")
              print("You have collected Tito! The Geography character!")
              num_correct += 1
            else: 
              print("The answer is not" , + titoanswerdouble6)


  
  print("You've finally gone through all the paths, Congrats!!")
  print("Now lets see your award for your trvia achevements" , name)
  if num_correct == 6:
    print("CONGRATS you're a trvia crack wiz, you've gotten ALL the characters")
    print("So NOW you get the crown! (And bragging rights)")
  else:
    print("You tried your best, and while you didn't get all the characters, we hope you learned something!!!")
    print("You get a particapation award!")
    if powerup == 0:
      print("You used NONE of your powerups, meaning you really killed it!!") ### may try to print out an image of a crown
    else:
      pass
  print("Time to log out!")
  print('What is the your username? ')
  username1 = input() 
  while username1 != username:
          print("Guess Again ")
          print('What is your username?')
          name = input()
          if name == username:
            print("Got it!")
          break
  password1 = input("Password:")
  while password1 != password:
          print("Try Again!")
          print('What is your password?')
          name2 = input()
          if name2 == password:
            print("Got it!")
          break
  print("Thank you for playing!!")
  print(''' 
| \                    / \                 /  |
|   \                /     \             /    |
|     \            /        \          /      |
|      \         /            \      /        |
|         \    /               \   /          |
|           \/                   \/           |
|                                             |
|               YOU DID IT!!!                 |
|_____________________________________________|''')
  
def easy():
  #This mode has the more simple questions!!
  num_correct = 0
  print("Welcome to Trivia Crack: Adventure Addition")
  print("The aim of the game is to get to collect every character by going down paths by answering fun trivia, and getting the crown!!!")
  time.sleep(3)
  print("First things first, what's your name adventurer!")
  name = input("Name: ")
  time.sleep(3)
  print("Now Let's set up a username and password to your account, make sure to remember them!!")
  time.sleep(2)
  username = input("Username: ")
  time.sleep(1)
  password = input("Password: ")
  time.sleep(2)
  print("Time to spin the wheel to choose your powerup!")
  time.sleep(1)
  powerup = random.randint(1, 2)
  num_correct = 0
  if powerup == 1:
    time.sleep(3)
    print("You recieved the powerup Skip!")
    print("This powerup allows you to skip a question you don't know the answer to for a new set!")
    #if powerup equals one then you get the Skip powerup/ 1 == powerup Skip
  else:
    time.sleep(3)
    print("You received the powerup Double Chance!")
    print("This powerup allows you to retry a question after putting the wrong answer!")
  #Now that we've recieved rthe powerup, we continue
  time.sleep(2)
  print("Now let the adventure begin!!")
  time.sleep(3)
  print("You're inside the spinning wheel of the trivia crack, and have 6 paths to go down")
  print("Each path has a titled name, but you are unsure which category of questions is which")
  print("Choose your first path:" , characters)
  choice1 = input("What path do you choose: ")
  characters.remove(choice1) #removing the option of the character chosen from "character" list!!

  #CHOICE ONE

  if choice1 == "Bonzo":
    print("You step down the hall marked, Bonzo, and as you travel down the hall, the sounds of cheers fill up the darkened hall")
    time.sleep(1)
    print("You see a light, and as you emerge from the dark hall, you realize you're in a football field with the stadium filled")
    time.sleep(1)
    print("You step out unto the green field with crowd roaring, as the jumbotron turns on")
    time.sleep(1)
    print("The screen reads 'Welcome to the sports category! Get ready for your first question' ")
    time.sleep(1)
    print('''Every how many years are the Winter Olympic Games celebrated?
  a) Every Four Years
  b) Every Tweleve Years
  c) Every Year
  d) Every Other Year''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuebonzo1 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuebonzo1 == "yes":
        print("Ok")
        time.sleep(1)
        bonzoanswerskip = input('''How many cards does a standrad English deck of cards have?
  a) 52 cards
  b) 48 cards
  c) 50 cards
  d) 54 cards''')
        if bonzoanswerskip == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1          
        else:
          print("The answer is '52 cards', not" , + bonzoanswerskip)
          #Now unto the instance where they say 'no'
      else:
        bonzoanswer = input("Answer(lowercase letter): ")
        if bonzoanswer == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1
        else: 
          print("The answer is 'Every Four Years', not" , + bonzoanswer)
    else:
      bonzoanswer = input("Answer(lowercase letter): ")
      if bonzoanswer == "a":
        print("Correct!")
        print("You have collected Bonzo! The Sports character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif bonzoanswer != "a" and powerup == 2:
            print("Let's use double chance, try again!")
            bonzoanswerdouble = input('''Every how many years are the Winter Olympic Games celebrated?
  a) Every Four Years
  b) Every Tweleve Years
  c) Every Year
  d) Every Other Year''')
            if bonzoanswerdouble == "a":
              print("Correct, see you could do it!")
              print("You have collected Bonzo! The Sports character!")
              num_correct += 1
            else: 
              print("The answer is 'Every Four Years', not" , + bonzoanswerdouble)
  

  if choice1 == "Pop":
    print("You tread down the hall marked, Pop, that is covered with movie posters and albums, and hear soft voices emerging")
    time.sleep(1)
    print("You see a light coming from a screen playing a movie, and as you emerge from the dark hall, you realize you're in a movie theater, seats filled")
    time.sleep(1)
    print("The character Pop, who looks like popcorn, is sitting on the screen")
    time.sleep(1)
    print(" Pop yells 'HEYYY THERE AND WELCOME to the entertainment category! Best category if you ask me! ")
    time.sleep(1)
    print("If you're a real enteratinment buff let's see if you can answer my questions!! ")
    time.sleep(1)
    print('''What colour was Clifford, the giant dog?
  a) Yellow
  b) Red
  c) Orange
  d) Green''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuepop = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuepop == "yes":
        print("Ok")
        time.sleep(1)
        popanswerskip = input('''What shape is Spongebob’s pants?
  a) Circluar
  b) Square
  c) Oval
  d) Pants''')
        if popanswerskip == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1          
        else:
          print("The answer is 'Square', not" , + popanswerskip)
          #Now unto the instance where they say 'no'
      else:
        popanswer = input("Answer(lowercase letter): ")
        if popanswer == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1
        else: 
          print("The answer is 'Red', not" , + popanswer)
    else:
      popanswer = input("Answer(lowercase letter): ")
      if popanswer == "b":
        print("Correct!")
        print("You have collected POP! The Entertainment character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif popanswer != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            popanswerdouble = input('''What colour was Clifford, the giant dog?
  a) Yellow
  b) Red
  c) Orange
  d) Green''')
            if popanswerdouble == "b":
              print("Correct, see you could do it!")
              print("You have collected POP! The Entertainment character!")
              num_correct += 1
            else: 
              print("The answer is 'Red', not" , + popanswerdouble)


  if choice1 == "Al":
    print("You start skipping down the very well lit hall marked, Al, and as you're going down , you can hear explosions in the background")
    time.sleep(1)
    print("You see a labortaory, with many chemical reactions appearing, you realize you're in the middle of a Bill Nye the Science guy episode")
    time.sleep(1)
    print("You see he's doing a an episode with AL the beaker, who notices you're prescence")
    time.sleep(1)
    print(" Al says to you 'hey there, ready for some REAL intellitecual questions my fellow science enthusist' (just say yes)")
    time.sleep(1)
    input()
    time.sleep(1)
    print(''' OKK, To what are photosensitive materials sensitive to?
  a) Bees
  b) Cameras
  c) Light
  d) People''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continueal = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continueal == "yes":
        print("Ok")
        time.sleep(1)
        alanswerskip = input('''How many chromosomes does the average human have?
  a) 50
  b) 45
  c) 46
  d) 48''')
        if alanswerskip == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1          
        else:
          print("The answer is '46', not" , + alanswerskip)
          #Now unto the instance where they say 'no'
      else:
        alanswer = input("Answer(lowercase letter): ")
        if alanswer == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1
        else: 
          print("The answer is '46', not" , + alanswer)
    else:
      alanswer = input("Answer(lowercase letter): ")
      if alanswer == "c":
        print("Correct!")
        print("You have collected AL! The Science character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif alanswer != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            alanswerdouble = input('''How many chromosomes does the average human have?
  a) 50
  b) 45
  c) 46
  d) 48''')
            if alanswerdouble == "c":
              print("Correct, see you could do it!")
              print("You have collected AL! The Science character!")
              num_correct += 1
            else: 
              print("The answer is '46', not" , + alanswerdouble)



  if choice1 == "Tina":
    print("You bolt down the hall with the title, TINA in a very fancy font, and as you're going down , you hear clicks and flashes of phones")
    time.sleep(1)
    print("The hall is decroated lavishly, with iconic paintings like the Mona Lisa")
    time.sleep(1)
    print("You enter into an art gallery with many people, and Tina the paintbrush finishing their art")
    time.sleep(1)
    print(" Tina says 'Hey, I'm Tina, glad you came to my art show, ready for some trvia!")
    time.sleep(4)
    print(''' Nike was the Greek goddess of what?
  a) Love
  b) War
  c) The Gods
  d) Victory''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetina = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetina == "yes":
        print("Ok")
        time.sleep(1)
        tinaanswerskip = input('''Compelete the sentence: to be or…?
  a) to want
  b) to have 
  c) not to eat
  d) not to be''')
        if tinaanswerskip == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1          
        else:
          print("The answer is 'not to be', not" , + tinaanswerskip)
          #Now unto the instance where they say 'no'
      else:
        tinaanswer = input("Answer(lowercase letter): ")
        if tinaanswer == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1
        else: 
          print("The answer is 'Victory', not" , + tinaanswer)
    else:
      tinaanswer = input("Answer(lowercase letter): ")
      if tinaanswer == "d":
        print("Correct!")
        print("You have collected TINA! The art character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif tinaanswer != "d" and powerup == 2:
            print("Let's use double chance, try again!")
            tinaanswerdouble = input(''' Nike was the Greek goddess of what?
  a) Love
  b) War
  c) The Gods
  d) Victory''')
            if tinaanswerdouble == "d":
              print("Correct, see you could do it!")
              print("You have collected TINA! The art character!")
              num_correct += 1
            else: 
              print("The answer is 'Victory', not" , + tinaanswerdouble)


  if choice1 == "Hector":
    print("You walk into the hall marked Hector when a sudden wave of old people smeel whiffs through the air")
    time.sleep(1)
    print("The hall is adorned with countless documents and events from scattered places and times in history")
    time.sleep(1)
    print("After you finally reach the end, you enter into a socratic seminar with Hector the Knight leading")
    time.sleep(1)
    print(" Hector looks over and says 'Ah I see you're here to interupt, better know some trivia then!!")
    time.sleep(4)
    print('''The country of Bolivia is named after which patriot?
  a) San de Martin
  b) Simon Bolivar
  c) Diego Rivera
  d) Santa Maria''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuehector = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuehector == "yes":
        print("Ok")
        time.sleep(1)
        hectoranswerskip = input('''What city was divided in two after the Second World War?
  a) Moscow
  b) Berlin 
  c) New York
  d) Paris''')
        if hectoranswerskip == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1          
        else:
          print("The answer is 'Berlin', not" , + hectoranswerskip)
          #Now unto the instance where they say 'no'
      else:
        hectoranswer = input("Answer(lowercase letter): ")
        if hectoranswer == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1
        else: 
          print("The answer is 'Simon Bolivar', not" , + hectoranswer)
    else:
      hectoranswer = input("Answer(lowercase letter): ")
      if hectoranswer == "b":
        print("Correct!")
        print("You have collected Hector! The History character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif hectoranswer != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            hectoranswerdouble = input('''The country of Bolivia is named after which patriot?
  a) San de Martin
  b) Simon Bolivar
  c) Diego Rivera
  d) Santa Maria''')
            if hectoranswerdouble == "b":
              print("Correct, see you could do it!")
              print("You have collected Hector! The History character!")
              num_correct += 1
            else: 
              print("The answer is 'Simon Bolivar', not" , + hectoranswerdouble)



  if choice1 == "Tito":
    print("As you enter the hall with the title, Tito, it suddenly smells like the ocean")
    time.sleep(1)
    print("You see the halls covered with maps of different regions across the world, and see a light at the end of the hall")
    time.sleep(1)
    print("You enter onto a mountain hill with Tito, the globe, standing with binoculars")
    time.sleep(1)
    print(" Tito says 'LOOOK AT THIS VIEW, glad you could make it, ready for some geography trvia!")
    time.sleep(4)
    print(''' Senegal is located in what continent?
  a) Asia
  b) The Americas
  c) Africa
  d) Europe''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetito = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetito == "yes":
        print("Ok")
        time.sleep(1)
        titoanswerskip = input('''The ‘Maple Leaf’ flag is the national flag of what country?
  a) Russia
  b) France 
  c) Canada
  d) Indonesia''')
        if titoanswerskip == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1          
        else:
          print("The answer is 'Canada', not" , + titoanswerskip)
          #Now unto the instance where they say 'no'
      else:
        titoanswer = input("Answer(lowercase letter): ")
        if titoanswer == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1
        else: 
          print("The answer is 'Africa', not" , + titoanswer)
    else:
      titoanswer = input("Answer(lowercase letter): ")
      if titoanswer == "c":
        print("Correct!")
        print("You have collected Tito! The Geography character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif titoanswer != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            titoanswerdouble = input(''' Senegal is located in what continent?
  a) Asia
  b) The Americas
  c) Africa
  d) Europe''')
            if titoanswerdouble == "c":
              print("Correct, see you could do it!")
              print("You have collected Tito! The Geography character!")
              num_correct += 1
            else: 
              print("The answer is 'Africa', not" , + titoanswerdouble)


  time.sleep(4)
  print("You head back down the" , choice1 + "hall")
  time.sleep(1)
  print("You have these paths left" , characters)
  choice2 = input("What path do you choose next: ")
  characters.remove(choice2)

  ###CHOICE TWO###########################################################################################################################

  if choice2 == "Bonzo":
    print("You step down the hall marked, Bonzo, and as you travel down the hall, the sounds of cheers fill up the darkened hall")
    time.sleep(1)
    print("You see a light, and as you emerge from the dark hall, you realize you're in a football field with the stadium filled")
    time.sleep(1)
    print("You step out unto the green field with crowd roaring, as the jumbotron turns on")
    time.sleep(1)
    print("The screen reads 'Welcome to the sports category! Get ready for your first question' ")
    time.sleep(1)
    print('''Every how many years are the Winter Olympic Games celebrated?
  a) Every Four Years
  b) Every Tweleve Years
  c) Every Year
  d) Every Other Year''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuebonzo2 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuebonzo2 == "yes":
        print("Ok")
        time.sleep(1)
        bonzoanswerskip2 = input('''How many cards does a standrad English deck of cards have?
  a) 52 cards
  b) 48 cards
  c) 50 cards
  d) 54 cards''')
        if bonzoanswerskip2 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1          
        else:
          print("The answer is '52 cards', not" , + bonzoanswerskip2)
          #Now unto the instance where they say 'no'
      else:
        bonzoanswer2 = input("Answer(lowercase letter): ")
        if bonzoanswer2 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1
        else: 
          print("The answer is 'Every Four Years', not" , + bonzoanswer2)
    else:
      bonzoanswer2 = input("Answer(lowercase letter): ")
      if bonzoanswer2 == "a":
        print("Correct!")
        print("You have collected Bonzo! The Sports character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif bonzoanswer2 != "a" and powerup == 2:
            print("Let's use double chance, try again!")
            bonzoanswerdouble2 = input('''Every how many years are the Winter Olympic Games celebrated?
  a) Every Four Years
  b) Every Tweleve Years
  c) Every Year
  d) Every Other Year''')
            if bonzoanswerdouble2 == "a":
              print("Correct, see you could do it!")
              print("You have collected Bonzo! The Sports character!")
              num_correct += 1
            else: 
              print("The answer is 'Every Four Years', not" , + bonzoanswerdouble2)


  if choice2 == "Pop":
    print("You tread down the hall marked, Pop, that is covered with movie posters and albums, and hear soft voices emerging")
    time.sleep(1)
    print("You see a light coming from a screen playing a movie, and as you emerge from the dark hall, you realize you're in a movie theater, seats filled")
    time.sleep(1)
    print("The character Pop, who looks like popcorn, is sitting on the screen")
    time.sleep(1)
    print(" Pop yells 'HEYYY THERE AND WELCOME to the entertainment category! Best category if you ask me! ")
    time.sleep(1)
    print("If you're a real enteratinment buff let's see if you can answer my questions!! ")
    time.sleep(1)
    print('''What colour was Clifford, the giant dog?
  a) Yellow
  b) Red
  c) Orange
  d) Green''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuepop2 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuepop2 == "yes":
        print("Ok")
        time.sleep(1)
        popanswerskip2 = input('''What shape is Spongebob’s pants?
  a) Circluar
  b) Square
  c) Oval
  d) Pants''')
        if popanswerskip2 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1          
        else:
          print("The answer is 'Square', not" , + popanswerskip2)
          #Now unto the instance where they say 'no'
      else:
        popanswer2 = input("Answer(lowercase letter): ")
        if popanswer2 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1
        else: 
          print("The answer is 'Red', not" , + popanswer2)
    else:
      popanswer2 = input("Answer(lowercase letter): ")
      if popanswer2 == "b":
        print("Correct!")
        print("You have collected POP! The Entertainment character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif popanswer2 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            popanswerdouble2 = input('''What colour was Clifford, the giant dog?
  a) Yellow
  b) Red
  c) Orange
  d) Green''')
            if popanswerdouble2 == "b":
              print("Correct, see you could do it!")
              print("You have collected POP! The Entertainment character!")
              num_correct += 1
            else: 
              print("The answer is 'Red', not" , + popanswerdouble2)  


  if choice2 == "Al":
    print("You start skipping down the very well lit hall marked, Al, and as you're going down , you can hear explosions in the background")
    time.sleep(1)
    print("You see a labortaory, with many chemical reactions appearing, you realize you're in the middle of a Bill Nye the Science guy episode")
    time.sleep(1)
    print("You see he's doing a an episode with AL the beaker, who notices you're prescence")
    time.sleep(1)
    print(" Al says to you 'hey there, ready for some REAL intellitecual questions my fellow science enthusist' (just say yes)")
    time.sleep(1)
    input()
    time.sleep(1)
    print(''' OKK, To what are photosensitive materials sensitive to?
  a) Bees
  b) Cameras
  c) Light
  d) People''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continueal2 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continueal2 == "yes":
        print("Ok")
        time.sleep(1)
        alanswerskip2 = input('''How many chromosomes does the average human have?
  a) 50
  b) 45
  c) 46
  d) 48''')
        if alanswerskip2 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1          
        else:
          print("The answer is '46', not" , + alanswerskip2)
          #Now unto the instance where they say 'no'
      else:
        alanswer2 = input("Answer(lowercase letter): ")
        if alanswer2 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1
        else: 
          print("The answer is '46', not" , + alanswer2)
    else:
      alanswer2 = input("Answer(lowercase letter): ")
      if alanswer2 == "c":
        print("Correct!")
        print("You have collected AL! The Science character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif alanswer2 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            alanswerdouble2 = input('''How many chromosomes does the average human have?
  a) 50
  b) 45
  c) 46
  d) 48''')
            if alanswerdouble2 == "c":
              print("Correct, see you could do it!")
              print("You have collected AL! The Science character!")
              num_correct += 1
            else: 
              print("The answer is '46', not" , + alanswerdouble2)

  if choice2 == "Tina":
    print("You bolt down the hall with the title, TINA in a very fancy font, and as you're going down , you hear clicks and flashes of phones")
    time.sleep(1)
    print("The hall is decroated lavishly, with iconic paintings like the Mona Lisa")
    time.sleep(1)
    print("You enter into an art gallery with many people, and Tina the paintbrush finishing their art")
    time.sleep(1)
    print(" Tina says 'Hey, I'm Tina, glad you came to my art show, ready for some trvia!")
    time.sleep(4)
    print(''' Nike was the Greek goddess of what?
  a) Love
  b) War
  c) The Gods
  d) Victory''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetina2 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetina2 == "yes":
        print("Ok")
        time.sleep(1)
        tinaanswerskip2 = input('''Compelete the sentence: to be or…?
  a) to want
  b) to have 
  c) not to eat
  d) not to be''')
        if tinaanswerskip2 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1          
        else:
          print("The answer is 'not to be', not" , + tinaanswerskip2)
          #Now unto the instance where they say 'no'
      else:
        tinaanswer2 = input("Answer(lowercase letter): ")
        if tinaanswer2 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1
        else: 
          print("The answer is 'Victory', not" , + tinaanswer2)
    else:
      tinaanswer2 = input("Answer(lowercase letter): ")
      if tinaanswer2 == "d":
        print("Correct!")
        print("You have collected TINA! The art character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif tinaanswer2 != "d" and powerup == 2:
            print("Let's use double chance, try again!")
            tinaanswerdouble2 = input(''' Nike was the Greek goddess of what?
  a) Love
  b) War
  c) The Gods
  d) Victory''')
            if tinaanswerdouble2 == "d":
              print("Correct, see you could do it!")
              print("You have collected TINA! The art character!")
              num_correct += 1
            else: 
              print("The answer is 'Victory', not" , + tinaanswerdouble2)  


  if choice2 == "Hector":
    print("You walk into the hall marked Hector when a sudden wave of old people smeel whiffs through the air")
    time.sleep(1)
    print("The hall is adorned with countless documents and events from scattered places and times in history")
    time.sleep(1)
    print("After you finally reach the end, you enter into a socratic seminar with Hector the Knight leading")
    time.sleep(1)
    print(" Hector looks over and says 'Ah I see you're here to interupt, better know some trivia then!!")
    time.sleep(4)
    print('''The country of Bolivia is named after which patriot?
  a) San de Martin
  b) Simon Bolivar
  c) Diego Rivera
  d) Santa Maria''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuehector2 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuehector2 == "yes":
        print("Ok")
        time.sleep(1)
        hectoranswerskip2 = input('''What city was divided in two after the Second World War?
  a) Moscow
  b) Berlin 
  c) New York
  d) Paris''')
        if hectoranswerskip2 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1          
        else:
          print("The answer is 'Berlin', not" , + hectoranswerskip2)
          #Now unto the instance where they say 'no'
      else:
        hectoranswer2 = input("Answer(lowercase letter): ")
        if hectoranswer2 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1
        else: 
          print("The answer is 'Simon Bolivar', not" , + hectoranswer2)
    else:
      hectoranswer2 = input("Answer(lowercase letter): ")
      if hectoranswer2 == "b":
        print("Correct!")
        print("You have collected Hector! The History character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif hectoranswer2 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            hectoranswerdouble2 = input('''The country of Bolivia is named after which patriot?
  a) San de Martin
  b) Simon Bolivar
  c) Diego Rivera
  d) Santa Maria''')
            if hectoranswerdouble2 == "b":
              print("Correct, see you could do it!")
              print("You have collected Hector! The History character!")
              num_correct += 1
            else: 
              print("The answer is 'Simon Bolivar', not" , + hectoranswerdouble2)


  if choice2 == "Tito":
    print("As you enter the hall with the title, Tito, it suddenly smells like the ocean")
    time.sleep(1)
    print("You see the halls covered with maps of different regions across the world, and see a light at the end of the hall")
    time.sleep(1)
    print("You enter onto a mountain hill with Tito, the globe, standing with binoculars")
    time.sleep(1)
    print(" Tito says 'LOOOK AT THIS VIEW, glad you could make it, ready for some geography trvia!")
    time.sleep(4)
    print(''' Senegal is located in what continent?
  a) Asia
  b) The Americas
  c) Africa
  d) Europe''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetito2 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetito2 == "yes":
        print("Ok")
        time.sleep(1)
        titoanswerskip2 = input('''The ‘Maple Leaf’ flag is the national flag of what country?
  a) Russia
  b) France 
  c) Canada
  d) Indonesia''')
        if titoanswerskip2 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1          
        else:
          print("The answer is 'Canada', not" , + titoanswerskip2)
          #Now unto the instance where they say 'no'
      else:
        titoanswer2 = input("Answer(lowercase letter): ")
        if titoanswer2 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1
        else: 
          print("The answer is 'Africa', not" , + titoanswer2)
    else:
      titoanswer2 = input("Answer(lowercase letter): ")
      if titoanswer2 == "c":
        print("Correct!")
        print("You have collected Tito! The Geography character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif titoanswer2 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            titoanswerdouble2 = input(''' Senegal is located in what continent?
  a) Asia
  b) The Americas
  c) Africa
  d) Europe''')
            if titoanswerdouble2 == "c":
              print("Correct, see you could do it!")
              print("You have collected Tito! The Geography character!")
              num_correct += 1
            else: 
              print("The answer is 'Africa', not" , + titoanswerdouble2)


  time.sleep(4)
  print("You head back down the" , choice2 + "path")
  time.sleep(1)
  print("You have these paths left" , characters)
  choice3 = input("What path do you choose next: ")
  characters.remove(choice3)


  ####CHOICE THREE
  if choice3 == "Bonzo":
    print("You step down the hall marked, Bonzo, and as you travel down the hall, the sounds of cheers fill up the darkened hall")
    time.sleep(1)
    print("You see a light, and as you emerge from the dark hall, you realize you're in a football field with the stadium filled")
    time.sleep(1)
    print("You step out unto the green field with crowd roaring, as the jumbotron turns on")
    time.sleep(1)
    print("The screen reads 'Welcome to the sports category! Get ready for your first question' ")
    time.sleep(1)
    print('''Every how many years are the Winter Olympic Games celebrated?
  a) Every Four Years
  b) Every Tweleve Years
  c) Every Year
  d) Every Other Year''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuebonzo3 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuebonzo3 == "yes":
        print("Ok")
        time.sleep(1)
        bonzoanswerskip3 = input('''How many cards does a standrad English deck of cards have?
  a) 52 cards
  b) 48 cards
  c) 50 cards
  d) 54 cards''')
        if bonzoanswerskip3 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1          
        else:
          print("The answer is '52 cards', not" , + bonzoanswerskip3)
          #Now unto the instance where they say 'no'
      else:
        bonzoanswer3 = input("Answer(lowercase letter): ")
        if bonzoanswer3 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1
        else: 
          print("The answer is 'Every Four Years', not" , + bonzoanswer3)
    else:
      bonzoanswer3 = input("Answer(lowercase letter): ")
      if bonzoanswer3 == "a":
        print("Correct!")
        print("You have collected Bonzo! The Sports character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif bonzoanswer3 != "a" and powerup == 2:
            print("Let's use double chance, try again!")
            bonzoanswerdouble3 = input('''Every how many years are the Winter Olympic Games celebrated?
  a) Every Four Years
  b) Every Tweleve Years
  c) Every Year
  d) Every Other Year''')
            if bonzoanswerdouble3 == "a":
              print("Correct, see you could do it!")
              print("You have collected Bonzo! The Sports character!")
              num_correct += 1
            else: 
              print("The answer is 'Every Four Years', not" , + bonzoanswerdouble3)

  if choice3 == "Pop":
    print("You tread down the hall marked, Pop, that is covered with movie posters and albums, and hear soft voices emerging")
    time.sleep(1)
    print("You see a light coming from a screen playing a movie, and as you emerge from the dark hall, you realize you're in a movie theater, seats filled")
    time.sleep(1)
    print("The character Pop, who looks like popcorn, is sitting on the screen")
    time.sleep(1)
    print(" Pop yells 'HEYYY THERE AND WELCOME to the entertainment category! Best category if you ask me! ")
    time.sleep(1)
    print("If you're a real enteratinment buff let's see if you can answer my questions!! ")
    time.sleep(1)
    print('''What colour was Clifford, the giant dog?
  a) Yellow
  b) Red
  c) Orange
  d) Green''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuepop3 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuepop3 == "yes":
        print("Ok")
        time.sleep(1)
        popanswerskip3 = input('''What shape is Spongebob’s pants?
  a) Circluar
  b) Square
  c) Oval
  d) Pants''')
        if popanswerskip3 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1          
        else:
          print("The answer is 'Square', not" , + popanswerskip3)
          #Now unto the instance where they say 'no'
      else:
        popanswer3 = input("Answer(lowercase letter): ")
        if popanswer3 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1
        else: 
          print("The answer is 'Red', not" , + popanswer3)
    else:
      popanswer3 = input("Answer(lowercase letter): ")
      if popanswer3 == "b":
        print("Correct!")
        print("You have collected POP! The Entertainment character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif popanswer3 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            popanswerdouble3 = input('''What colour was Clifford, the giant dog?
  a) Yellow
  b) Red
  c) Orange
  d) Green''')
            if popanswerdouble3 == "b":
              print("Correct, see you could do it!")
              print("You have collected POP! The Entertainment character!")
              num_correct += 1
            else: 
              print("The answer is 'Red', not" , + popanswerdouble3)

  
  if choice3 == "Al":
    print("You start skipping down the very well lit hall marked, Al, and as you're going down , you can hear explosions in the background")
    time.sleep(1)
    print("You see a labortaory, with many chemical reactions appearing, you realize you're in the middle of a Bill Nye the Science guy episode")
    time.sleep(1)
    print("You see he's doing a an episode with AL the beaker, who notices you're prescence")
    time.sleep(1)
    print(" Al says to you 'hey there, ready for some REAL intellitecual questions my fellow science enthusist' (just say yes)")
    time.sleep(1)
    input()
    time.sleep(1)
    print(''' OKK, To what are photosensitive materials sensitive to?
  a) Bees
  b) Cameras
  c) Light
  d) People''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continueal3 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continueal3 == "yes":
        print("Ok")
        time.sleep(1)
        alanswerskip3 = input('''How many chromosomes does the average human have?
  a) 50
  b) 45
  c) 46
  d) 48''')
        if alanswerskip3 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1          
        else:
          print("The answer is '46', not" , + alanswerskip3)
          #Now unto the instance where they say 'no'
      else:
        alanswer3 = input("Answer(lowercase letter): ")
        if alanswer3 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1
        else: 
          print("The answer is '46', not" , + alanswer3)
    else:
      alanswer3 = input("Answer(lowercase letter): ")
      if alanswer3 == "c":
        print("Correct!")
        print("You have collected AL! The Science character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif alanswer3 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            alanswerdouble3 = input('''How many chromosomes does the average human have?
  a) 50
  b) 45
  c) 46
  d) 48''')
            if alanswerdouble3 == "c":
              print("Correct, see you could do it!")
              print("You have collected AL! The Science character!")
              num_correct += 1
            else: 
              print("The answer is '46', not" , + alanswerdouble3)


  if choice3 == "Tina":
    print("You bolt down the hall with the title, TINA in a very fancy font, and as you're going down , you hear clicks and flashes of phones")
    time.sleep(1)
    print("The hall is decroated lavishly, with iconic paintings like the Mona Lisa")
    time.sleep(1)
    print("You enter into an art gallery with many people, and Tina the paintbrush finishing their art")
    time.sleep(1)
    print(" Tina says 'Hey, I'm Tina, glad you came to my art show, ready for some trvia!")
    time.sleep(4)
    print(''' Nike was the Greek goddess of what?
  a) Love
  b) War
  c) The Gods
  d) Victory''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetina3 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetina3 == "yes":
        print("Ok")
        time.sleep(1)
        tinaanswerskip3 = input('''Compelete the sentence: to be or…?
  a) to want
  b) to have 
  c) not to eat
  d) not to be''')
        if tinaanswerskip3 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1          
        else:
          print("The answer is 'not to be', not" , + tinaanswerskip3)
          #Now unto the instance where they say 'no'
      else:
        tinaanswer3 = input("Answer(lowercase letter): ")
        if tinaanswer3 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1
        else: 
          print("The answer is 'Victory', not" , + tinaanswer3)
    else:
      tinaanswer3 = input("Answer(lowercase letter): ")
      if tinaanswer3 == "d":
        print("Correct!")
        print("You have collected TINA! The art character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif tinaanswer3 != "d" and powerup == 2:
            print("Let's use double chance, try again!")
            tinaanswerdouble3 = input(''' Nike was the Greek goddess of what?
  a) Love
  b) War
  c) The Gods
  d) Victory''')
            if tinaanswerdouble3 == "d":
              print("Correct, see you could do it!")
              print("You have collected TINA! The art character!")
              num_correct += 1
            else: 
              print("The answer is 'Victory', not" , + tinaanswerdouble3)


  if choice3 == "Hector":
    print("You walk into the hall marked Hector when a sudden wave of old people smeel whiffs through the air")
    time.sleep(1)
    print("The hall is adorned with countless documents and events from scattered places and times in history")
    time.sleep(1)
    print("After you finally reach the end, you enter into a socratic seminar with Hector the Knight leading")
    time.sleep(1)
    print(" Hector looks over and says 'Ah I see you're here to interupt, better know some trivia then!!")
    time.sleep(4)
    print('''The country of Bolivia is named after which patriot?
  a) San de Martin
  b) Simon Bolivar
  c) Diego Rivera
  d) Santa Maria''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuehector3 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuehector3 == "yes":
        print("Ok")
        time.sleep(1)
        hectoranswerskip3 = input('''What city was divided in two after the Second World War?
  a) Moscow
  b) Berlin 
  c) New York
  d) Paris''')
        if hectoranswerskip3 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1          
        else:
          print("The answer is 'Berlin', not" , + hectoranswerskip3)
          #Now unto the instance where they say 'no'
      else:
        hectoranswer3 = input("Answer(lowercase letter): ")
        if hectoranswer3 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1
        else: 
          print("The answer is 'Simon Bolivar', not" , + hectoranswer3)
    else:
      hectoranswer3 = input("Answer(lowercase letter): ")
      if hectoranswer3 == "b":
        print("Correct!")
        print("You have collected Hector! The History character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif hectoranswer3 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            hectoranswerdouble3 = input('''The country of Bolivia is named after which patriot?
  a) San de Martin
  b) Simon Bolivar
  c) Diego Rivera
  d) Santa Maria''')
            if hectoranswerdouble3 == "b":
              print("Correct, see you could do it!")
              print("You have collected Hector! The History character!")
              num_correct += 1
            else: 
              print("The answer is 'Simon Bolivar', not" , + hectoranswerdouble3)


  if choice3 == "Tito":
    print("As you enter the hall with the title, Tito, it suddenly smells like the ocean")
    time.sleep(1)
    print("You see the halls covered with maps of different regions across the world, and see a light at the end of the hall")
    time.sleep(1)
    print("You enter onto a mountain hill with Tito, the globe, standing with binoculars")
    time.sleep(1)
    print(" Tito says 'LOOOK AT THIS VIEW, glad you could make it, ready for some geography trvia!")
    time.sleep(4)
    print(''' Senegal is located in what continent?
  a) Asia
  b) The Americas
  c) Africa
  d) Europe''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetito3 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetito3 == "yes":
        print("Ok")
        time.sleep(1)
        titoanswerskip3 = input('''The ‘Maple Leaf’ flag is the national flag of what country?
  a) Russia
  b) France 
  c) Canada
  d) Indonesia''')
        if titoanswerskip3 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1          
        else:
          print("The answer is 'Canada', not" , + titoanswerskip3)
          #Now unto the instance where they say 'no'
      else:
        titoanswer3 = input("Answer(lowercase letter): ")
        if titoanswer3 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1
        else: 
          print("The answer is 'Africa', not" , + titoanswer3)
    else:
      titoanswer3 = input("Answer(lowercase letter): ")
      if titoanswer3 == "c":
        print("Correct!")
        print("You have collected Tito! The Geography character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif titoanswer3 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            titoanswerdouble3 = input(''' Senegal is located in what continent?
  a) Asia
  b) The Americas
  c) Africa
  d) Europe''')
            if titoanswerdouble3 == "c":
              print("Correct, see you could do it!")
              print("You have collected Tito! The Geography character!")
              num_correct += 1
            else: 
              print("The answer is 'Africa', not" , + titoanswerdouble3)


  time.sleep(4)
  print("You head back down the" , choice3 + "path")
  time.sleep(1)
  print("You have these paths left" , characters)
  choice4 = input("What path do you choose next: ")
  characters.remove(choice4)


  ########CHOICE FOUR##################

  if choice4 == "Bonzo":
    print("You step down the hall marked, Bonzo, and as you travel down the hall, the sounds of cheers fill up the darkened hall")
    time.sleep(1)
    print("You see a light, and as you emerge from the dark hall, you realize you're in a football field with the stadium filled")
    time.sleep(1)
    print("You step out unto the green field with crowd roaring, as the jumbotron turns on")
    time.sleep(1)
    print("The screen reads 'Welcome to the sports category! Get ready for your first question' ")
    time.sleep(1)
    print('''Every how many years are the Winter Olympic Games celebrated?
  a) Every Four Years
  b) Every Tweleve Years
  c) Every Year
  d) Every Other Year''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuebonzo4 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuebonzo4 == "yes":
        print("Ok")
        time.sleep(1)
        bonzoanswerskip4 = input('''How many cards does a standrad English deck of cards have?
  a) 52 cards
  b) 48 cards
  c) 50 cards
  d) 54 cards''')
        if bonzoanswerskip4 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1          
        else:
          print("The answer is '52 cards', not" , + bonzoanswerskip4)
          #Now unto the instance where they say 'no'
      else:
        bonzoanswer4 = input("Answer(lowercase letter): ")
        if bonzoanswer4 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1
        else: 
          print("The answer is 'Every Four Years', not" , + bonzoanswer4)
    else:
      bonzoanswer4 = input("Answer(lowercase letter): ")
      if bonzoanswer4 == "a":
        print("Correct!")
        print("You have collected Bonzo! The Sports character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif bonzoanswer4 != "a" and powerup == 2:
            print("Let's use double chance, try again!")
            bonzoanswerdouble4 = input('''Every how many years are the Winter Olympic Games celebrated?
  a) Every Four Years
  b) Every Tweleve Years
  c) Every Year
  d) Every Other Year''')
            if bonzoanswerdouble4 == "a":
              print("Correct, see you could do it!")
              print("You have collected Bonzo! The Sports character!")
              num_correct += 1
            else: 
              print("The answer is 'Every Four Years', not" , + bonzoanswerdouble4)

  if choice4 == "Pop":
    print("You tread down the hall marked, Pop, that is covered with movie posters and albums, and hear soft voices emerging")
    time.sleep(1)
    print("You see a light coming from a screen playing a movie, and as you emerge from the dark hall, you realize you're in a movie theater, seats filled")
    time.sleep(1)
    print("The character Pop, who looks like popcorn, is sitting on the screen")
    time.sleep(1)
    print(" Pop yells 'HEYYY THERE AND WELCOME to the entertainment category! Best category if you ask me! ")
    time.sleep(1)
    print("If you're a real enteratinment buff let's see if you can answer my questions!! ")
    time.sleep(1)
    print('''What colour was Clifford, the giant dog?
  a) Yellow
  b) Red
  c) Orange
  d) Green''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuepop4 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuepop4 == "yes":
        print("Ok")
        time.sleep(1)
        popanswerskip4 = input('''What shape is Spongebob’s pants?
  a) Circluar
  b) Square
  c) Oval
  d) Pants''')
        if popanswerskip4 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1          
        else:
          print("The answer is 'Square', not" , + popanswerskip4)
          #Now unto the instance where they say 'no'
      else:
        popanswer4 = input("Answer(lowercase letter): ")
        if popanswer4 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1
        else: 
          print("The answer is 'Red', not" , + popanswer4)
    else:
      popanswer4 = input("Answer(lowercase letter): ")
      if popanswer4 == "b":
        print("Correct!")
        print("You have collected POP! The Entertainment character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif popanswer4 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            popanswerdouble4 = input('''What colour was Clifford, the giant dog?
  a) Yellow
  b) Red
  c) Orange
  d) Green''')
            if popanswerdouble4 == "b":
              print("Correct, see you could do it!")
              print("You have collected POP! The Entertainment character!")
              num_correct += 1
            else: 
              print("The answer is 'Red', not" , + popanswerdouble4)

  
  if choice4 == "Al":
    print("You start skipping down the very well lit hall marked, Al, and as you're going down , you can hear explosions in the background")
    time.sleep(1)
    print("You see a labortaory, with many chemical reactions appearing, you realize you're in the middle of a Bill Nye the Science guy episode")
    time.sleep(1)
    print("You see he's doing a an episode with AL the beaker, who notices you're prescence")
    time.sleep(1)
    print(" Al says to you 'hey there, ready for some REAL intellitecual questions my fellow science enthusist' (just say yes)")
    time.sleep(1)
    input()
    time.sleep(1)
    print(''' OKK, To what are photosensitive materials sensitive to?
  a) Bees
  b) Cameras
  c) Light
  d) People''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continueal4 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continueal4 == "yes":
        print("Ok")
        time.sleep(1)
        alanswerskip4 = input('''How many chromosomes does the average human have?
  a) 50
  b) 45
  c) 46
  d) 48''')
        if alanswerskip4 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1          
        else:
          print("The answer is '46', not" , + alanswerskip4)
          #Now unto the instance where they say 'no'
      else:
        alanswer4 = input("Answer(lowercase letter): ")
        if alanswer4 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1
        else: 
          print("The answer is '46', not" , + alanswer4)
    else:
      alanswer4 = input("Answer(lowercase letter): ")
      if alanswer4 == "c":
        print("Correct!")
        print("You have collected AL! The Science character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif alanswer4 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            alanswerdouble4 = input('''How many chromosomes does the average human have?
  a) 50
  b) 45
  c) 46
  d) 48''')
            if alanswerdouble4 == "c":
              print("Correct, see you could do it!")
              print("You have collected AL! The Science character!")
              num_correct += 1
            else: 
              print("The answer is '46', not" , + alanswerdouble4)

  if choice4 == "Tina":
    print("You bolt down the hall with the title, TINA in a very fancy font, and as you're going down , you hear clicks and flashes of phones")
    time.sleep(1)
    print("The hall is decroated lavishly, with iconic paintings like the Mona Lisa")
    time.sleep(1)
    print("You enter into an art gallery with many people, and Tina the paintbrush finishing their art")
    time.sleep(1)
    print(" Tina says 'Hey, I'm Tina, glad you came to my art show, ready for some trvia!")
    time.sleep(4)
    print(''' Nike was the Greek goddess of what?
  a) Love
  b) War
  c) The Gods
  d) Victory''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetina4 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetina4 == "yes":
        print("Ok")
        time.sleep(1)
        tinaanswerskip4 = input('''Compelete the sentence: to be or…?
  a) to want
  b) to have 
  c) not to eat
  d) not to be''')
        if tinaanswerskip4 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1          
        else:
          print("The answer is 'not to be', not" , + tinaanswerskip4)
          #Now unto the instance where they say 'no'
      else:
        tinaanswer4 = input("Answer(lowercase letter): ")
        if tinaanswer4 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1
        else: 
          print("The answer is 'Victory', not" , + tinaanswer4)
    else:
      tinaanswer4 = input("Answer(lowercase letter): ")
      if tinaanswer4 == "d":
        print("Correct!")
        print("You have collected TINA! The art character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif tinaanswer4 != "d" and powerup == 2:
            print("Let's use double chance, try again!")
            tinaanswerdouble4 = input(''' Nike was the Greek goddess of what?
  a) Love
  b) War
  c) The Gods
  d) Victory''')
            if tinaanswerdouble4 == "d":
              print("Correct, see you could do it!")
              print("You have collected TINA! The art character!")
              num_correct += 1
            else: 
              print("The answer is 'Victory', not" , + tinaanswerdouble4)


  if choice4 == "Hector":
    print("You walk into the hall marked Hector when a sudden wave of old people smeel whiffs through the air")
    time.sleep(1)
    print("The hall is adorned with countless documents and events from scattered places and times in history")
    time.sleep(1)
    print("After you finally reach the end, you enter into a socratic seminar with Hector the Knight leading")
    time.sleep(1)
    print(" Hector looks over and says 'Ah I see you're here to interupt, better know some trivia then!!")
    time.sleep(4)
    print('''The country of Bolivia is named after which patriot?
  a) San de Martin
  b) Simon Bolivar
  c) Diego Rivera
  d) Santa Maria''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuehector4 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuehector4 == "yes":
        print("Ok")
        time.sleep(1)
        hectoranswerskip4 = input('''What city was divided in two after the Second World War?
  a) Moscow
  b) Berlin 
  c) New York
  d) Paris''')
        if hectoranswerskip4 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1          
        else:
          print("The answer is 'Berlin', not" , + hectoranswerskip4)
          #Now unto the instance where they say 'no'
      else:
        hectoranswer4 = input("Answer(lowercase letter): ")
        if hectoranswer4 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1
        else: 
          print("The answer is 'Simon Bolivar', not" , + hectoranswer4)
    else:
      hectoranswer4 = input("Answer(lowercase letter): ")
      if hectoranswer4 == "b":
        print("Correct!")
        print("You have collected Hector! The History character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif hectoranswer4 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            hectoranswerdouble4 = input('''The country of Bolivia is named after which patriot?
  a) San de Martin
  b) Simon Bolivar
  c) Diego Rivera
  d) Santa Maria''')
            if hectoranswerdouble4 == "b":
              print("Correct, see you could do it!")
              print("You have collected Hector! The History character!")
              num_correct += 1
            else: 
              print("The answer is 'Simon Bolivar', not" , + hectoranswerdouble4)

  
  if choice4 == "Tito":
    print("As you enter the hall with the title, Tito, it suddenly smells like the ocean")
    time.sleep(1)
    print("You see the halls covered with maps of different regions across the world, and see a light at the end of the hall")
    time.sleep(1)
    print("You enter onto a mountain hill with Tito, the globe, standing with binoculars")
    time.sleep(1)
    print(" Tito says 'LOOOK AT THIS VIEW, glad you could make it, ready for some geography trvia!")
    time.sleep(4)
    print(''' Senegal is located in what continent?
  a) Asia
  b) The Americas
  c) Africa
  d) Europe''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetito4 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetito4 == "yes":
        print("Ok")
        time.sleep(1)
        titoanswerskip4 = input('''The ‘Maple Leaf’ flag is the national flag of what country?
  a) Russia
  b) France 
  c) Canada
  d) Indonesia''')
        if titoanswerskip4 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1          
        else:
          print("The answer is 'Canada', not" , + titoanswerskip4)
          #Now unto the instance where they say 'no'
      else:
        titoanswer4 = input("Answer(lowercase letter): ")
        if titoanswer4 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1
        else: 
          print("The answer is 'Africa', not" , + titoanswer4)
    else:
      titoanswer4 = input("Answer(lowercase letter): ")
      if titoanswer4 == "c":
        print("Correct!")
        print("You have collected Tito! The Geography character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif titoanswer4 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            titoanswerdouble4 = input(''' Senegal is located in what continent?
  a) Asia
  b) The Americas
  c) Africa
  d) Europe''')
            if titoanswerdouble4 == "c":
              print("Correct, see you could do it!")
              print("You have collected Tito! The Geography character!")
              num_correct += 1
            else: 
              print("The answer is 'Africa', not" , + titoanswerdouble4)


  time.sleep(4)
  print("You head back down the" , choice4 + "path")
  time.sleep(1)
  print("You have these paths left" , characters)
  choice5 = input("What path do you choose next: ")
  characters.remove(choice5)


  #######CHOICE FIVE#################################

  if choice5 == "Bonzo":
    print("You step down the hall marked, Bonzo, and as you travel down the hall, the sounds of cheers fill up the darkened hall")
    time.sleep(1)
    print("You see a light, and as you emerge from the dark hall, you realize you're in a football field with the stadium filled")
    time.sleep(1)
    print("You step out unto the green field with crowd roaring, as the jumbotron turns on")
    time.sleep(1)
    print("The screen reads 'Welcome to the sports category! Get ready for your first question' ")
    time.sleep(1)
    print('''Every how many years are the Winter Olympic Games celebrated?
  a) Every Four Years
  b) Every Tweleve Years
  c) Every Year
  d) Every Other Year''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuebonzo5 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuebonzo5 == "yes":
        print("Ok")
        time.sleep(1)
        bonzoanswerskip5 = input('''How many cards does a standrad English deck of cards have?
  a) 52 cards
  b) 48 cards
  c) 50 cards
  d) 54 cards''')
        if bonzoanswerskip5 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1          
        else:
          print("The answer is '52 cards', not" , + bonzoanswerskip5)
          #Now unto the instance where they say 'no'
      else:
        bonzoanswer5 = input("Answer(lowercase letter): ")
        if bonzoanswer5 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1
        else: 
          print("The answer is 'Every Four Years', not" , + bonzoanswer5)
    else:
      bonzoanswer5 = input("Answer(lowercase letter): ")
      if bonzoanswer5 == "a":
        print("Correct!")
        print("You have collected Bonzo! The Sports character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif bonzoanswer5 != "a" and powerup == 2:
            print("Let's use double chance, try again!")
            bonzoanswerdouble5 = input('''Every how many years are the Winter Olympic Games celebrated?
  a) Every Four Years
  b) Every Tweleve Years
  c) Every Year
  d) Every Other Year''')
            if bonzoanswerdouble5 == "a":
              print("Correct, see you could do it!")
              print("You have collected Bonzo! The Sports character!")
              num_correct += 1
            else: 
              print("The answer is 'Every Four Years', not" , + bonzoanswerdouble5)
  
  if choice5 == "Pop":
    print("You tread down the hall marked, Pop, that is covered with movie posters and albums, and hear soft voices emerging")
    time.sleep(1)
    print("You see a light coming from a screen playing a movie, and as you emerge from the dark hall, you realize you're in a movie theater, seats filled")
    time.sleep(1)
    print("The character Pop, who looks like popcorn, is sitting on the screen")
    time.sleep(1)
    print(" Pop yells 'HEYYY THERE AND WELCOME to the entertainment category! Best category if you ask me! ")
    time.sleep(1)
    print("If you're a real enteratinment buff let's see if you can answer my questions!! ")
    time.sleep(1)
    print('''What colour was Clifford, the giant dog?
  a) Yellow
  b) Red
  c) Orange
  d) Green''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuepop5 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuepop5 == "yes":
        print("Ok")
        time.sleep(1)
        popanswerskip5 = input('''What shape is Spongebob’s pants?
  a) Circluar
  b) Square
  c) Oval
  d) Pants''')
        if popanswerskip5 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1          
        else:
          print("The answer is 'Square', not" , + popanswerskip5)
          #Now unto the instance where they say 'no'
      else:
        popanswer5 = input("Answer(lowercase letter): ")
        if popanswer5 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1
        else: 
          print("The answer is 'Red', not" , + popanswer5)
    else:
      popanswer5 = input("Answer(lowercase letter): ")
      if popanswer5 == "b":
        print("Correct!")
        print("You have collected POP! The Entertainment character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif popanswer5 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            popanswerdouble5 = input('''What colour was Clifford, the giant dog?
  a) Yellow
  b) Red
  c) Orange
  d) Green''')
            if popanswerdouble5 == "b":
              print("Correct, see you could do it!")
              print("You have collected POP! The Entertainment character!")
              num_correct += 1
            else: 
              print("The answer is 'Red', not" , + popanswerdouble5)

  
  if choice5 == "Al":
    print("You start skipping down the very well lit hall marked, Al, and as you're going down , you can hear explosions in the background")
    time.sleep(1)
    print("You see a labortaory, with many chemical reactions appearing, you realize you're in the middle of a Bill Nye the Science guy episode")
    time.sleep(1)
    print("You see he's doing a an episode with AL the beaker, who notices you're prescence")
    time.sleep(1)
    print(" Al says to you 'hey there, ready for some REAL intellitecual questions my fellow science enthusist' (just say yes)")
    time.sleep(1)
    input()
    time.sleep(1)
    print(''' OKK, To what are photosensitive materials sensitive to?
  a) Bees
  b) Cameras
  c) Light
  d) People''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continueal5 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continueal5 == "yes":
        print("Ok")
        time.sleep(1)
        alanswerskip5 = input('''How many chromosomes does the average human have?
  a) 50
  b) 45
  c) 46
  d) 48''')
        if alanswerskip5 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1          
        else:
          print("The answer is '46', not" , + alanswerskip5)
          #Now unto the instance where they say 'no'
      else:
        alanswer5 = input("Answer(lowercase letter): ")
        if alanswer5 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1
        else: 
          print("The answer is '46', not" , + alanswer5)
    else:
      alanswer5 = input("Answer(lowercase letter): ")
      if alanswer5 == "c":
        print("Correct!")
        print("You have collected AL! The Science character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif alanswer5 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            alanswerdouble5 = input('''How many chromosomes does the average human have?
  a) 50
  b) 45
  c) 46
  d) 48''')
            if alanswerdouble5 == "c":
              print("Correct, see you could do it!")
              print("You have collected AL! The Science character!")
              num_correct += 1
            else: 
              print("The answer is '46', not" , + alanswerdouble5)


  if choice5 == "Tina":
    print("You bolt down the hall with the title, TINA in a very fancy font, and as you're going down , you hear clicks and flashes of phones")
    time.sleep(1)
    print("The hall is decroated lavishly, with iconic paintings like the Mona Lisa")
    time.sleep(1)
    print("You enter into an art gallery with many people, and Tina the paintbrush finishing their art")
    time.sleep(1)
    print(" Tina says 'Hey, I'm Tina, glad you came to my art show, ready for some trvia!")
    time.sleep(4)
    print(''' Nike was the Greek goddess of what?
  a) Love
  b) War
  c) The Gods
  d) Victory''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetina5 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetina5 == "yes":
        print("Ok")
        time.sleep(1)
        tinaanswerskip5 = input('''Compelete the sentence: to be or…?
  a) to want
  b) to have 
  c) not to eat
  d) not to be''')
        if tinaanswerskip5 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1          
        else:
          print("The answer is 'not to be', not" , + tinaanswerskip5)
          #Now unto the instance where they say 'no'
      else:
        tinaanswer5 = input("Answer(lowercase letter): ")
        if tinaanswer5 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1
        else: 
          print("The answer is 'Victory', not" , + tinaanswer5)
    else:
      tinaanswer5 = input("Answer(lowercase letter): ")
      if tinaanswer5 == "d":
        print("Correct!")
        print("You have collected TINA! The art character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif tinaanswer5 != "d" and powerup == 2:
            print("Let's use double chance, try again!")
            tinaanswerdouble5 = input(''' Nike was the Greek goddess of what?
  a) Love
  b) War
  c) The Gods
  d) Victory''')
            if tinaanswerdouble5 == "d":
              print("Correct, see you could do it!")
              print("You have collected TINA! The art character!")
              num_correct += 1
            else: 
              print("The answer is 'Victory', not" , + tinaanswerdouble5)


  if choice5 == "Hector":
    print("You walk into the hall marked Hector when a sudden wave of old people smeel whiffs through the air")
    time.sleep(1)
    print("The hall is adorned with countless documents and events from scattered places and times in history")
    time.sleep(1)
    print("After you finally reach the end, you enter into a socratic seminar with Hector the Knight leading")
    time.sleep(1)
    print(" Hector looks over and says 'Ah I see you're here to interupt, better know some trivia then!!")
    time.sleep(4)
    print('''The country of Bolivia is named after which patriot?
  a) San de Martin
  b) Simon Bolivar
  c) Diego Rivera
  d) Santa Maria''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuehector5 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuehector5 == "yes":
        print("Ok")
        time.sleep(1)
        hectoranswerskip5 = input('''What city was divided in two after the Second World War?
  a) Moscow
  b) Berlin 
  c) New York
  d) Paris''')
        if hectoranswerskip5 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1          
        else:
          print("The answer is 'Berlin', not" , + hectoranswerskip5)
          #Now unto the instance where they say 'no'
      else:
        hectoranswer5 = input("Answer(lowercase letter): ")
        if hectoranswer5 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1
        else: 
          print("The answer is 'Simon Bolivar', not" , + hectoranswer5)
    else:
      hectoranswer5 = input("Answer(lowercase letter): ")
      if hectoranswer5 == "b":
        print("Correct!")
        print("You have collected Hector! The History character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif hectoranswer5 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            hectoranswerdouble5 = input('''The country of Bolivia is named after which patriot?
  a) San de Martin
  b) Simon Bolivar
  c) Diego Rivera
  d) Santa Maria''')
            if hectoranswerdouble5 == "b":
              print("Correct, see you could do it!")
              print("You have collected Hector! The History character!")
              num_correct += 1
            else: 
              print("The answer is 'Simon Bolivar', not" , + hectoranswerdouble5)


  if choice5 == "Tito":
    print("As you enter the hall with the title, Tito, it suddenly smells like the ocean")
    time.sleep(1)
    print("You see the halls covered with maps of different regions across the world, and see a light at the end of the hall")
    time.sleep(1)
    print("You enter onto a mountain hill with Tito, the globe, standing with binoculars")
    time.sleep(1)
    print(" Tito says 'LOOOK AT THIS VIEW, glad you could make it, ready for some geography trvia!")
    time.sleep(4)
    print(''' Senegal is located in what continent?
  a) Asia
  b) The Americas
  c) Africa
  d) Europe''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetito5 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetito5 == "yes":
        print("Ok")
        time.sleep(1)
        titoanswerskip5 = input('''The ‘Maple Leaf’ flag is the national flag of what country?
  a) Russia
  b) France 
  c) Canada
  d) Indonesia''')
        if titoanswerskip5 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1          
        else:
          print("The answer is 'Canada', not" , + titoanswerskip5)
          #Now unto the instance where they say 'no'
      else:
        titoanswer5 = input("Answer(lowercase letter): ")
        if titoanswer5 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1
        else: 
          print("The answer is 'Africa', not" , + titoanswer5)
    else:
      titoanswer5 = input("Answer(lowercase letter): ")
      if titoanswer5 == "c":
        print("Correct!")
        print("You have collected Tito! The Geography character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif titoanswer != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            titoanswerdouble5 = input(''' Senegal is located in what continent?
  a) Asia
  b) The Americas
  c) Africa
  d) Europe''')
            if titoanswerdouble5 == "c":
              print("Correct, see you could do it!")
              print("You have collected Tito! The Geography character!")
              num_correct += 1
            else: 
              print("The answer is 'Africa', not" , + titoanswerdouble5)

  time.sleep(4)
  print("You head back down the" , choice5 + "path")
  time.sleep(1)
  print("You have this path left" , characters)
  choice6 = input("Type in your last path!: ")
  characters.remove(choice6)


  ###########CHOICE SIX###############


  if choice6 == "Bonzo":
    print("You step down the hall marked, Bonzo, and as you travel down the hall, the sounds of cheers fill up the darkened hall")
    time.sleep(1)
    print("You see a light, and as you emerge from the dark hall, you realize you're in a football field with the stadium filled")
    time.sleep(1)
    print("You step out unto the green field with crowd roaring, as the jumbotron turns on")
    time.sleep(1)
    print("The screen reads 'Welcome to the sports category! Get ready for your first question' ")
    time.sleep(1)
    print('''Every how many years are the Winter Olympic Games celebrated?
  a) Every Four Years
  b) Every Tweleve Years
  c) Every Year
  d) Every Other Year''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuebonzo6 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuebonzo6 == "yes":
        print("Ok")
        time.sleep(1)
        bonzoanswerskip6 = input('''How many cards does a standrad English deck of cards have?
  a) 52 cards
  b) 48 cards
  c) 50 cards
  d) 54 cards''')
        if bonzoanswerskip6 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1          
        else:
          print("The answer is '52 cards', not" , + bonzoanswerskip6)
          #Now unto the instance where they say 'no'
      else:
        bonzoanswer6 = input("Answer(lowercase letter): ")
        if bonzoanswer6 == "a":
          print("Correct!")
          print("You have collected Bonzo! The Sports character!")
          num_correct += 1
        else: 
          print("The answer is 'Every Four Years', not" , + bonzoanswer6)
    else:
      bonzoanswer6 = input("Answer(lowercase letter): ")
      if bonzoanswer6 == "a":
        print("Correct!")
        print("You have collected Bonzo! The Sports character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif bonzoanswer6 != "a" and powerup == 2:
            print("Let's use double chance, try again!")
            bonzoanswerdouble6 = input('''Every how many years are the Winter Olympic Games celebrated?
  a) Every Four Years
  b) Every Tweleve Years
  c) Every Year
  d) Every Other Year''')
            if bonzoanswerdouble6 == "a":
              print("Correct, see you could do it!")
              print("You have collected Bonzo! The Sports character!")
              num_correct += 1
            else: 
              print("The answer is 'Every Four Years', not" , + bonzoanswerdouble6)

  if choice6 == "Pop":
    print("You tread down the hall marked, Pop, that is covered with movie posters and albums, and hear soft voices emerging")
    time.sleep(1)
    print("You see a light coming from a screen playing a movie, and as you emerge from the dark hall, you realize you're in a movie theater, seats filled")
    time.sleep(1)
    print("The character Pop, who looks like popcorn, is sitting on the screen")
    time.sleep(1)
    print(" Pop yells 'HEYYY THERE AND WELCOME to the entertainment category! Best category if you ask me! ")
    time.sleep(1)
    print("If you're a real enteratinment buff let's see if you can answer my questions!! ")
    time.sleep(1)
    print('''What colour was Clifford, the giant dog?
  a) Yellow
  b) Red
  c) Orange
  d) Green''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuepop6 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuepop6 == "yes":
        print("Ok")
        time.sleep(1)
        popanswerskip6 = input('''What shape is Spongebob’s pants?
  a) Circluar
  b) Square
  c) Oval
  d) Pants''')
        if popanswerskip6 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1          
        else:
          print("The answer is 'Square', not" , + popanswerskip6)
          #Now unto the instance where they say 'no'
      else:
        popanswer6 = input("Answer(lowercase letter): ")
        if popanswer6 == "b":
          print("Correct!")
          print("You have collected POP! The Entertainment character!")
          num_correct += 1
        else: 
          print("The answer is 'Red', not" , + popanswer6)
    else:
      popanswer6 = input("Answer(lowercase letter): ")
      if popanswer6 == "b":
        print("Correct!")
        print("You have collected POP! The Entertainment character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif popanswer6 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            popanswerdouble6 = input('''What colour was Clifford, the giant dog?
  a) Yellow
  b) Red
  c) Orange
  d) Green''')
            if popanswerdouble6 == "b":
              print("Correct, see you could do it!")
              print("You have collected POP! The Entertainment character!")
              num_correct += 1
            else: 
              print("The answer is 'Red', not" , + popanswerdouble6)

  if choice6 == "Al":
    print("You start skipping down the very well lit hall marked, Al, and as you're going down , you can hear explosions in the background")
    time.sleep(1)
    print("You see a labortaory, with many chemical reactions appearing, you realize you're in the middle of a Bill Nye the Science guy episode")
    time.sleep(1)
    print("You see he's doing a an episode with AL the beaker, who notices you're prescence")
    time.sleep(1)
    print(" Al says to you 'hey there, ready for some REAL intellitecual questions my fellow science enthusist' (just say yes)")
    time.sleep(1)
    input()
    time.sleep(1)
    print(''' OKK, To what are photosensitive materials sensitive to?
  a) Bees
  b) Cameras
  c) Light
  d) People''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continueal6 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continueal6 == "yes":
        print("Ok")
        time.sleep(1)
        alanswerskip6 = input('''How many chromosomes does the average human have?
  a) 50
  b) 45
  c) 46
  d) 48''')
        if alanswerskip6 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1          
        else:
          print("The answer is '46', not" , + alanswerskip6)
          #Now unto the instance where they say 'no'
      else:
        alanswer6 = input("Answer(lowercase letter): ")
        if alanswer6 == "c":
          print("Correct!")
          print("You have collected AL! The Science character!")
          num_correct += 1
        else: 
          print("The answer is '46', not" , + alanswer6)
    else:
      alanswer6 = input("Answer(lowercase letter): ")
      if alanswer6 == "c":
        print("Correct!")
        print("You have collected AL! The Science character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif alanswer6 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            alanswerdouble6 = input('''How many chromosomes does the average human have?
  a) 50
  b) 45
  c) 46
  d) 48''')
            if alanswerdouble6 == "c":
              print("Correct, see you could do it!")
              print("You have collected AL! The Science character!")
              num_correct += 1
            else: 
              print("The answer is '46', not" , + alanswerdouble6)

  if choice6 == "Tina":
    print("You bolt down the hall with the title, TINA in a very fancy font, and as you're going down , you hear clicks and flashes of phones")
    time.sleep(1)
    print("The hall is decroated lavishly, with iconic paintings like the Mona Lisa")
    time.sleep(1)
    print("You enter into an art gallery with many people, and Tina the paintbrush finishing their art")
    time.sleep(1)
    print(" Tina says 'Hey, I'm Tina, glad you came to my art show, ready for some trvia!")
    time.sleep(4)
    print(''' Nike was the Greek goddess of what?
  a) Love
  b) War
  c) The Gods
  d) Victory''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetina6 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetina6 == "yes":
        print("Ok")
        time.sleep(1)
        tinaanswerskip6 = input('''Compelete the sentence: to be or…?
  a) to want
  b) to have 
  c) not to eat
  d) not to be''')
        if tinaanswerskip6 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1          
        else:
          print("The answer is 'not to be', not" , + tinaanswerskip6)
          #Now unto the instance where they say 'no'
      else:
        tinaanswer6 = input("Answer(lowercase letter): ")
        if tinaanswer6 == "d":
          print("Correct!")
          print("You have collected TINA! The art character!")
          num_correct += 1
        else: 
          print("The answer is 'Victory', not" , + tinaanswer6)
    else:
      tinaanswer6 = input("Answer(lowercase letter): ")
      if tinaanswer6 == "d":
        print("Correct!")
        print("You have collected TINA! The art character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif tinaanswer6 != "d" and powerup == 2:
            print("Let's use double chance, try again!")
            tinaanswerdouble6 = input(''' Nike was the Greek goddess of what?
  a) Love
  b) War
  c) The Gods
  d) Victory''')
            if tinaanswerdouble6 == "d":
              print("Correct, see you could do it!")
              print("You have collected TINA! The art character!")
              num_correct += 1
            else: 
              print("The answer is 'Victory', not" , + tinaanswerdouble6)


  if choice6 == "Hector":
    print("You walk into the hall marked Hector when a sudden wave of old people smeel whiffs through the air")
    time.sleep(1)
    print("The hall is adorned with countless documents and events from scattered places and times in history")
    time.sleep(1)
    print("After you finally reach the end, you enter into a socratic seminar with Hector the Knight leading")
    time.sleep(1)
    print(" Hector looks over and says 'Ah I see you're here to interupt, better know some trivia then!!")
    time.sleep(4)
    print('''The country of Bolivia is named after which patriot?
  a) San de Martin
  b) Simon Bolivar
  c) Diego Rivera
  d) Santa Maria''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuehector6 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuehector6 == "yes":
        print("Ok")
        time.sleep(1)
        hectoranswerskip6 = input('''What city was divided in two after the Second World War?
  a) Moscow
  b) Berlin 
  c) New York
  d) Paris''')
        if hectoranswerskip6 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1          
        else:
          print("The answer is 'Berlin', not" , + hectoranswerskip6)
          #Now unto the instance where they say 'no'
      else:
        hectoranswer6 = input("Answer(lowercase letter): ")
        if hectoranswer6 == "b":
          print("Correct!")
          print("You have collected Hector! The History character!")
          num_correct += 1
        else: 
          print("The answer is 'Simon Bolivar', not" , + hectoranswer6)
    else:
      hectoranswer6 = input("Answer(lowercase letter): ")
      if hectoranswer6 == "b":
        print("Correct!")
        print("You have collected Hector! The History character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif hectoranswer6 != "b" and powerup == 2:
            print("Let's use double chance, try again!")
            hectoranswerdouble6 = input('''The country of Bolivia is named after which patriot?
  a) San de Martin
  b) Simon Bolivar
  c) Diego Rivera
  d) Santa Maria''')
            if hectoranswerdouble6 == "b":
              print("Correct, see you could do it!")
              print("You have collected Hector! The History character!")
              num_correct += 1
            else: 
              print("The answer is 'Simon Bolivar', not" , + hectoranswerdouble6)


  if choice6 == "Tito":
    print("As you enter the hall with the title, Tito, it suddenly smells like the ocean")
    time.sleep(1)
    print("You see the halls covered with maps of different regions across the world, and see a light at the end of the hall")
    time.sleep(1)
    print("You enter onto a mountain hill with Tito, the globe, standing with binoculars")
    time.sleep(1)
    print(" Tito says 'LOOOK AT THIS VIEW, glad you could make it, ready for some geography trvia!")
    time.sleep(4)
    print(''' Senegal is located in what continent?
  a) Asia
  b) The Americas
  c) Africa
  d) Europe''')
    #If you have skip powerup you get to decide to skip the question or not
    if powerup == 1:
      continuetito6 = input("Let's use the Skip powerup! Would you like to skip this question, yes or no?")
      if continuetito6 == "yes":
        print("Ok")
        time.sleep(1)
        titoanswerskip6 = input('''The ‘Maple Leaf’ flag is the national flag of what country?
  a) Russia
  b) France 
  c) Canada
  d) Indonesia''')
        if titoanswerskip6 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1          
        else:
          print("The answer is 'Canada', not" , + titoanswerskip6)
          #Now unto the instance where they say 'no'
      else:
        titoanswer6 = input("Answer(lowercase letter): ")
        if titoanswer6 == "c":
          print("Correct!")
          print("You have collected Tito! The Geography character!")
          num_correct += 1
        else: 
          print("The answer is 'Africa', not" , + titoanswer6)
    else:
      titoanswer6 = input("Answer(lowercase letter): ")
      if titoanswer6 == "c":
        print("Correct!")
        print("You have collected Tito! The Geography character!")
        num_correct += 1
        #UNTO doublechance scenario
      elif titoanswer6 != "c" and powerup == 2:
            print("Let's use double chance, try again!")
            titoanswerdouble6 = input(''' Senegal is located in what continent?
  a) Asia
  b) The Americas
  c) Africa
  d) Europe''')
            if titoanswerdouble6 == "c":
              print("Correct, see you could do it!")
              print("You have collected Tito! The Geography character!")
              num_correct += 1
            else: 
              print("The answer is 'Africa', not" , + titoanswerdouble6)


  
  print("You've finally gone through all the paths, Congrats!!")
  print("Now lets see your award for your trvia achevements" , name)
  if num_correct == 6:
    print("CONGRATS you're a trvia crack wiz, you've gotten ALL the characters")
    print("So NOW you get the crown! (And bragging rights)")
  else:
    print("You tried your best, and while you didn't get all the characters, we hope you learned something!!!")
    print("You get a particapation award!")
    if powerup == 0:
      print("You used NONE of your powerups, meaning you really killed it!!") ### may try to print out an image of a crown
    else:
      pass
  print("Time to log out!")
  print('What is the your username? ')
  username1 = input() 
  while username1 != username:
          print("Guess Again ")
          print('What is your username?')
          name = input()
          if name == username:
            print("Got it!")
          break
  password1 = input("Password:")
  while password1 != password:
          print("Try Again!")
          print('What is your password?')
          name2 = input()
          if name2 == password:
            print("Got it!")
          break
  print("Thank you for playing!!")
  print(''' 
| \                    / \                 /  |
|   \                /     \             /    |
|     \            /        \          /      |
|      \         /            \      /        |
|         \    /               \   /          |
|           \/                   \/           |
|                                             |
|               YOU DID IT!!!                 |
|_____________________________________________|''')
      



                                  

choose_mode = {0 : hard,
           1 : easy,

}
user_input=int(input("Hi! Which mode would you like to play? : \n press 0 for hard \n press 1 for easy"))
choose_mode[user_input]()
# Out:
# Hi! Which mode would you like to play? :
#  press 0 for hard
#  press 1 for easy0
# Welcome to Trivia Crack: Adventure Addition
# You have chosen hard mode, BE WARNED
# The aim of the game is to get to collect every character by going down paths by answering fun trivia, and getting the crown!!!
# First things first, what's your name adventurer!
# Name: Jamie
# Now Let's set up a username and password to your account, make sure to remember them!!
# Username: jamie
# Password: jamie
# Time to spin the wheel to choose your powerup!
# You received the powerup Double Chance!
# This powerup allows you to retry a question after putting the wrong answer!
# Now let the adventure begin!!
# You're inside the spinning wheel of the trivia crack, and have 6 paths to go down
# Each path has a titled name, but you are unsure which category of questions is which
# Choose your first path: ['Bonzo', 'Pop', 'Al', 'Tina', 'Hector', 'Tito']
# What path do you choose: Bonzo
# ...

# %%
#If anything doesn't work please comment!
##Leave ur coursor here for least annoying action
