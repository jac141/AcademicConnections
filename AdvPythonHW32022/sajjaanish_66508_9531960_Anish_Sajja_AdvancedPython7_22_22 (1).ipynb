# %% [markdown]
# # 3D graphs
#
# I tried to use the code in the description to create the 360 video, but it didn't work in the ipynb format.
# It seems to not be able to create multiple figures in the same cell. I tested this out in this notebook using a print statement
# in between two loops in order to see whether changing models would allow for the models to be seen.
#
# I created a 3d graph at the end of this page with different angle.

# %%
# %matplotlib inline
import numpy as np
from numpy import linspace
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
# We read plots into variables


fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection = '3d')

# %%
# Linspace generates a set of evenly spaced points. 
# Good for generating imaginary data

from scipy import signal 

fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection = '3d')


t = np.linspace(0, 1, 1000, endpoint=True)
ax.plot3D(t, signal.square(2 * np.pi * 5 * t))

# %%
#testing whether or not changing the model will change it

fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection='3d')
 
t = np.linspace(0, 1, 1000, endpoint=True)
ax.plot3D(t, signal.square(2 * np.pi * 5 * t))
 
for angle in range(0, 360):
   ax.view_init(angle,100)
   plt.draw()
   plt.pause(.001)
print(100000000000000000000000000000000000000000000)

z = np.linspace(0, 15, 1000)
x = np.sin(z)
y = np.cos(z)
ax.plot3D(x, y, z, 'green')

for angle in range(0, 360):
    ax.view_init(angle,30)
    plt.draw()
    plt.pause(0.5)
    plt.show()
# Out:
# 100000000000000000000000000000000000000000000

# %%
fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection='3d')
 
t = np.linspace(0, 1, 1000, endpoint=True)
ax.plot3D(t, signal.square(2 * np.pi * 5 * t))


for angle in range(0, 360):
    ax.view_init(angle,30)
    plt.draw()
    plt.pause(0.5)
    plt.show()

# HW2 Question try to use a software that actually shows the video of 360 view
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-f3b5d0732f51> in <module>
#       9     ax.view_init(angle,30)
#      10     plt.draw()
# ---> 11     plt.pause(0.5)
#      12     plt.show()
#      13
#
# D:\anaconda3\lib\site-packages\matplotlib\pyplot.py in pause(interval)
#     436             canvas.draw_idle()
#     437         show(block=False)
# --> 438         canvas.start_event_loop(interval)
#     439     else:
#     440         time.sleep(interval)
#
# D:\anaconda3\lib\site-packages\matplotlib\backend_bases.py in start_event_loop(self, timeout)
#    2406         while self._looping and counter * timestep < timeout:
#    2407             self.flush_events()
# -> 2408             time.sleep(timestep)
#    2409             counter += 1
#    2410
#
# KeyboardInterrupt:

# %%
# Creating 3D figure
fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection='3d')
 
# Creating Dataset
z = np.linspace(0, 15, 1000)
x = np.sin(z)
y = np.cos(z)
ax.plot3D(x, y, z, 'green')

# # 360 Degree view
# for angle in range(0, 360):
#     ax.view_init(angle, 30)
#     plt.draw()
#     plt.pause(.001)
 
plt.show()

# %%
from numpy import linspace
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from scipy import signal
 
# Creating 3D figure
fig = plt.figure(figsize = (8, 8))
ax = plt.axes(projection = '3d')
 
# Creating Dataset
t = np.linspace(0, 1, 1000, endpoint = True)
ax.plot3D(t, signal.square(2 * np.pi * 5 * t))
 
# 360 Degree view
for angle in range(0, 360):
   ax.view_init(angle, 30)
   plt.draw()
   plt.pause(.001)
     
#plt.show()

# %% [markdown]
# ## Added 3D graph with different angle view
# The below code I created to show the 3D graph in different angle.

# %%
fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection='3d')
 
t = np.linspace(0, 1, 1000, endpoint=True)
ax.plot3D(t, signal.square(2 * np.pi * 5 * t))

ax.view_init(130,30)
plt.draw()

'''
for angle in range(0, 360):
   ax.view_init(angle,30)
   plt.draw()
   plt.pause(.01)
'''
plt.show()

# %%
'''
I tried to use the code in the description to create the 360 video, but it didn't work in the ipynb format.
It seems to not be able to create multiple figures in the same cell. I tested this out in this notebook using a print statement
in between two loops in order to see whether changing models would allow for the models to be seen.
'''
