# %% [markdown]
# # **Kevin Yan Advanced Python HW3 Topic2 Code Improvement:**

# %%
import numpy as np
from numpy import linspace
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
# We read plots into variables


fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection = '3d')

# %%
# Linspace generates a set of evenly spaced points. 
# Good for generating imaginary data

from scipy import signal 

fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection = '3d')


t = np.linspace(0, 1, 1000, endpoint=True)
ax.plot3D(t, signal.square(2 * np.pi * 5 * t))

# %%
fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection='3d')
 
t = np.linspace(0, 1, 1000, endpoint=True)
ax.plot3D(t, signal.square(2 * np.pi * 5 * t))
 
for angle in range(0, 360):
   ax.view_init(angle,30)
   plt.draw()
   plt.pause(.001)

# %%
fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection='3d')
 
t = np.linspace(0, 1, 1000, endpoint=True)
ax.plot3D(t, signal.square(2 * np.pi * 5 * t))
 
for angle in range(0, 360):
   ax.view_init(angle,30)
   plt.draw()
   plt.pause(.001)

plt.show()

# %%
# Creating 3D figure
fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection='3d')
 
# Creating Dataset
z = np.linspace(0, 15, 1000)
x = np.sin(z)
y = np.cos(z)
ax.plot3D(x, y, z, 'green')

# 360 Degree view
for angle in range(0, 360):
    ax.view_init(angle, 30)
    plt.draw()
    plt.pause(.001)
 
plt.show()

# %% [markdown]
# # **Summary:**

# %% [markdown]
# ## **After reading the Data Visualization website in Github. I understand some basic idea of how to make graphs that better illustrate the data. Firstly, choosing between graphs are very important. Different graphs such as line graph or bar graph can represent different data better that other graphs do. Secondly, using different color to illustrate can also help building the graph. For example color red might means danger and color yellow might means cautious. Lastly, make your plot readable. Make 3D graphs to better illustrate how the data flows.**

# %% [markdown]
# # **Make another 3D graph:**

# %%
# Creating 3D figure
fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection = '3d')
 
# Creating Dataset
color_cycle = plt.rcParams['axes.prop_cycle']()
x = linspace(0, 1, 51)
a = x*( 1 - x)   
b = 0.25 - a   
c = x*x*(1 - x)
d = 0.25-c   
 
ax.plot3D(x, a, **next(color_cycle))
 
# 360 Degree view
for angle in range(0, 360):
   ax.view_init(angle, 30)
   plt.draw()
   plt.pause(.001)
 
plt.show()
