# %% [markdown]
# # Creating Geometric Art Project
#
#
# Hello Students in this project you will be creating your own geometric art.You will be using a library called turtle that allows you to draw in python. **IMPORTANT** This works differently in REPLIT and Google Colab. So there may be some functionality differences. It is totally ok to do this project in REPLIT and then save all the correct code here. I haven't done this project in mybinder. BUT my assumption is that it will work better there than here because google just programmed their python notebooks very differently. However, I hope you have fun. And this is your chance to get **VERY** creative!!!!

# %% [markdown]
# # Step 1: Make a Hexagon
# To begin any turtle project, import the turtle module so you can use the functions. You must also
# create a turtle. (see page 38).
# Start a new file called Art.py, enter the following code, and run it to make sure you get a turtle.
# Add a comment line on the top to remind you of the project. Adding comments is good
# programming practice.
#
# **You MUST RUN the following code to make sure that turtle works in colab**
#
#
#
# ```
# !pip3 install ColabTurtle
#
# ```

# %%
# !pip3 install ColabTurtle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ColabTurtle in /usr/local/lib/python3.7/dist-packages (2.1.0)

# %%
# Step 1 

import ColabTurtle.Turtle as shelly    
# If you look the PDF instructions you will notice this is slightly different. You need this line to run it in colab as opposed to the line in the PDF for REPLIT
shelly.initializeTurtle(initial_speed=10)

# Pseudocode 
# Repeat 6 times the following: 
# move 100 steps forward (the form of this command is the library.command for example shelly.forward(100))
# turn 60 degrees to the left 
# HINT: Use a for loop for this

for i in range(6):
  shelly.forward(100)
  shelly.left(60)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="313.397" y2="100.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="313.397" y1="100.0" x2="226.794" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="226.794" y1="150.0" x2="226.794" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="226.794" y1="250.0" x2="313.397" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="313.397" y1="300.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# <path style=" stroke:none;fill-rule:evenodd;fill:white;fill-opacity:1;" d="M 18.214844 0.632812 C 16.109375 1.800781 15.011719 4.074219 15.074219 7.132812 L 15.085938 7.652344 L 14.785156 7.496094 C 13.476562 6.824219 11.957031 6.671875 10.40625 7.066406 C 8.46875 7.550781 6.515625 9.15625 4.394531 11.992188 C 3.0625 13.777344 2.679688 14.636719 3.042969 15.027344 L 3.15625 15.152344 L 3.519531 15.152344 C 4.238281 15.152344 4.828125 14.886719 8.1875 13.039062 C 9.386719 12.378906 10.371094 11.839844 10.378906 11.839844 C 10.386719 11.839844 10.355469 11.929688 10.304688 12.035156 C 9.832031 13.09375 9.257812 14.820312 8.96875 16.078125 C 7.914062 20.652344 8.617188 24.53125 11.070312 27.660156 C 11.351562 28.015625 11.363281 27.914062 10.972656 28.382812 C 8.925781 30.84375 7.945312 33.28125 8.238281 35.1875 C 8.289062 35.527344 8.28125 35.523438 8.917969 35.523438 C 10.941406 35.523438 13.074219 34.207031 15.136719 31.6875 C 15.359375 31.417969 15.328125 31.425781 15.5625 31.574219 C 16.292969 32.042969 18.023438 32.964844 18.175781 32.964844 C 18.335938 32.964844 19.941406 32.210938 20.828125 31.71875 C 20.996094 31.625 21.136719 31.554688 21.136719 31.558594 C 21.203125 31.664062 21.898438 32.414062 22.222656 32.730469 C 23.835938 34.300781 25.5625 35.132812 27.582031 35.300781 C 27.90625 35.328125 27.9375 35.308594 28.007812 34.984375 C 28.382812 33.242188 27.625 30.925781 25.863281 28.425781 L 25.542969 27.96875 L 25.699219 27.785156 C 28.945312 23.960938 29.132812 18.699219 26.257812 11.96875 L 26.207031 11.84375 L 27.945312 12.703125 C 31.53125 14.476562 32.316406 14.800781 33.03125 14.800781 C 33.976562 14.800781 33.78125 13.9375 32.472656 12.292969 C 28.519531 7.355469 25.394531 5.925781 21.921875 7.472656 L 21.558594 7.636719 L 21.578125 7.542969 C 21.699219 6.992188 21.761719 5.742188 21.699219 5.164062 C 21.496094 3.296875 20.664062 1.964844 19.003906 0.855469 C 18.480469 0.503906 18.457031 0.5 18.214844 0.632812"/>
# </g>
#       </svg>

# %% [markdown]
# # Step 2: Repeat the Hexagon Using a Nested Loop
# Now that we have a hexagon using a loop, we can put this hexagon code inside another loop
# that repeats, to get a number of hexagons arranged in a circle, each slightly overlapping each
# other.
# Modifying the pseudocode from Step 1, we can turn each hexagon just 10 degrees from the
# previous one. To complete the circle, we need to do this a total of 360 ÷ 10 = 36 times (360 is
# the total number of degrees in a circle).
#
#
#
#
# ```
# Pseudocode
# Repeat 36 times the following:
#   Repeat 6 times the following:
#     Move 100 steps forward
#     Turn 60 degrees to the left
#   Turn at 10 degrees to the right
#
# ```
#
# **Notice how "Repeat" and the second "Turn" have the same level of indentation**
#
#
# You can select the ​for​ loop code from your previous project and press Tab to indent it (or select
# and click on Format > Indent Region on IDLE).
# Then, add the ​for n in range(36):​ on top and the ​shelly.right(10)​ below it to handle the other
# part of the pseudocode.
# Remember, the comments after the # are optional. They only explain to the programmer what
# the code is doing.
# To complete Step 2, your python code should look like this:
#
# ![screenshot.png](data:image/png;base64,...)

# %%
#step 2

for x in range(36):
  for y in range(6):
    shelly.forward(100)
    shelly.left(60)
  shelly.right(10)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="313.397" y2="100.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="313.397" y1="100.0" x2="226.794" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="226.794" y1="150.0" x2="226.794" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="226.794" y1="250.0" x2="313.397" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="313.397" y1="300.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="250.0" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="313.397" y2="100.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="313.397" y1="100.0" x2="226.794" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="226.794" y1="150.0" x2="226.794" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="226.794" y1="250.0" x2="313.397" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="313.397" y1="300.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="250.0" x2="417.365" y2="151.519" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="417.365" y1="151.519" x2="340.761" y2="87.24" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="340.761" y1="87.24" x2="246.792" y2="121.442" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="246.792" y1="121.442" x2="229.427" y2="219.923" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="229.427" y1="219.923" x2="306.031" y2="284.202" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="306.031" y1="284.202" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="250.0" x2="434.202" y2="156.031" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="434.202" y1="156.031" x2="369.923" y2="79.427" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="369.923" y1="79.427" x2="271.442" y2="96.792" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="271.442" y1="96.792" x2="237.24" y2="190.761" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="237.24" y1="190.761" x2="301.519" y2="267.365" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="301.519" y1="267.365" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="250.0" x2="450.0" y2="163.397" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="450.0" y1="163.397" x2="400.0" y2="76.794" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="76.794" x2="300.0" y2="76.794" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="300.0" y1="76.794" x2="250.0" y2="163.397" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="250.0" y1="163.397" x2="300.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="300.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="250.0" x2="464.279" y2="173.396" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="464.279" y1="173.396" x2="430.077" y2="79.427" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="430.077" y1="79.427" x2="331.596" y2="62.062" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="331.596" y1="62.062" x2="267.317" y2="138.666" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="267.317" y1="138.666" x2="301.519" y2="232.635" stroke-linecap="round" style="stroke:white;stroke-width:4"/> ...

# %% [markdown]
# # Step 3: Change the Background; Add Rainbow Colors
# You can make this drawing more interesting by adding colors and a background.
# Here’s the code you need to change the background color:
#
# turtle.bgcolor(‘black’) ​# turn background black ​Test this see if you like it better
# ____________________________________________________________________________
# The computer can store related items in a list -
# like a list of colors. We can use the loop to go from item 0 to item 1 and print all the colors in the
# list. The “​i​” in the for loop is a counter, which starts at 0 and stops before 6. Using ​colors[i]
# gives us the ​i​th item in the list.
# The new line of code to add inside the loop for the hexagon is.
# ____________________________________________________________________________
# shelly.color(colors[i])
# ____________________________________________________________________________
# To use different colors in the drawing, you’ll need to modify the code so the turtle color is
# changed inside the loop. Here’s the final code to make this rainbow pattern:
# ____________________________________________________________________________
# # make a geometric rainbow pattern
# import turtle
#
# # pick order of colors for the hexagon
# Write a list of colors called colors with 6 elements (i invite you to see which colors work)
# shelly​ = turtle.Turtle()
# turtle.bgcolor(‘black’) ​# turn background black
#
# Using your code from above, inside the nested loop for making a hexagon repeat six times.
# Include the line of code ​shelly.color(colors[i])
#
# ***When you are done it should look like this.***
#
# ![screenshot2.png](data:image/png;base64,...)

# %%
#step 3
shelly.clear()
shelly.penup()
shelly.home()
shelly.pendown()
colors = ["purple","green","blue","yellow","orange","purple"]
for x in range(36):
  for y in range(6):
    shelly.color(colors[y])
    shelly.forward(100)
    shelly.left(60)
  shelly.right(10)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="400.0" y1="150.0" x2="313.397" y2="100.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="313.397" y1="100.0" x2="226.794" y2="150.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="226.794" y1="150.0" x2="226.794" y2="250.0" stroke-linecap="round" style="stroke:yellow;stroke-width:4"/><line x1="226.794" y1="250.0" x2="313.397" y2="300.0" stroke-linecap="round" style="stroke:orange;stroke-width:4"/><line x1="313.397" y1="300.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="400.0" y1="250.0" x2="417.365" y2="151.519" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="417.365" y1="151.519" x2="340.761" y2="87.24" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="340.761" y1="87.24" x2="246.792" y2="121.442" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="246.792" y1="121.442" x2="229.427" y2="219.923" stroke-linecap="round" style="stroke:yellow;stroke-width:4"/><line x1="229.427" y1="219.923" x2="306.031" y2="284.202" stroke-linecap="round" style="stroke:orange;stroke-width:4"/><line x1="306.031" y1="284.202" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="400.0" y1="250.0" x2="434.202" y2="156.031" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="434.202" y1="156.031" x2="369.923" y2="79.427" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="369.923" y1="79.427" x2="271.442" y2="96.792" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="271.442" y1="96.792" x2="237.24" y2="190.761" stroke-linecap="round" style="stroke:yellow;stroke-width:4"/><line x1="237.24" y1="190.761" x2="301.519" y2="267.365" stroke-linecap="round" style="stroke:orange;stroke-width:4"/><line x1="301.519" y1="267.365" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="400.0" y1="250.0" x2="450.0" y2="163.397" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="450.0" y1="163.397" x2="400.0" y2="76.794" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="400.0" y1="76.794" x2="300.0" y2="76.794" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="300.0" y1="76.794" x2="250.0" y2="163.397" stroke-linecap="round" style="stroke:yellow;stroke-width:4"/><line x1="250.0" y1="163.397" x2="300.0" y2="250.0" stroke-linecap="round" style="stroke:orange;stroke-width:4"/><line x1="300.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="400.0" y1="250.0" x2="464.279" y2="173.396" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="464.279" y1="173.396" x2="430.077" y2="79.427" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="430.077" y1="79.427" x2="331.596" y2="62.062" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="331.596" y1="62.062" x2="267.317" y2="138.666" stroke-linecap="round" style="stroke:yellow;stroke-width:4"/><line x1="267.317" y1="138.666" x2="301.519" y2="232.635" stroke-linecap="round" style="stroke:orange;stroke-width:4"/><line x1="301.519" y1="232.635" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="400.0" y1="250.0" x2="476.604" y2="185.721" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="476.604" y1="185.721" x2="459.239" y2="87.24" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="459.239" y1="87.24" x2="365.27" y2="53.038" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="365.27" y1="53.038" x2="288.666" y2="117.317" stroke-linecap="round" style="stroke:yellow;stroke-width:4"/><line x1="288.666" y1="117.317" x2="306.031" y2="215.798" stroke-linecap="round" style ...

# %% [markdown]
# # Step 4: Add Small White Circles Around the Pattern
# You can also make the turtle go to the outer edge of the patterns, make a small circle, return to
# the center, and then repeat, going all the way around the pattern. This is fun to watch, and it
# adds an extra detail to the art that’s very easy to do in code but not so easy to create using any
# other art medium.
# This step demonstrates the turtle moving forward and returning by going backward to its start
# position. Since there are 36 hexagons, we’ll draw 36 small circles to match; each time the turtle
# returns to the centerm, it turns 10 degrees: 36 x 10 = 360 degrees, to make a complete circle
# around the pattern.
# Add the following code to the end of the code in Step 3:
#
#
#
# ```
# # get ready to draw 36 circles
# shelly​.penup()
# shelly​.color(‘white’)
# # repeat 36 times to match the 36 hexagons
# For i in range(36):
#   shelly​.forward(220)
#   shelly​.pendown() ​comment as to why you think there needs to be a penup and pendown
#   shelly​.circle(5)
#   shelly​.penup()
#   shelly​.backward(220)
#   shelly​.right(10) # hide turtle to finish the drawing
# shelly​.hideturtle()
#
# ```
#
# ***Your drawing can look like this***
#
# ![screenshot4.png](data:image/png;base64,...)

# %%
#step 4
def circle(length, n):
  for i in range(n):
    shelly.forward(length)
    shelly.left(360 / n)

shelly.clear()
shelly.penup()
shelly.home()
shelly.pendown()
colors = ["purple","green","blue","yellow","orange","purple"]
for x in range(36):
  for y in range(6):
    shelly.color(colors[y])
    shelly.forward(100)
    shelly.left(60)
  shelly.color("white")
  shelly.penup()
  shelly.forward(220)
  shelly.pendown() #because it will draw as it moves if pen is not up
  circle(5,10)
  shelly.penup()
  shelly.backward(220)
  shelly.right(10)
  shelly.pendown()
shelly.hideturtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="400.0" y1="150.0" x2="313.397" y2="100.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="313.397" y1="100.0" x2="226.794" y2="150.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="226.794" y1="150.0" x2="226.794" y2="250.0" stroke-linecap="round" style="stroke:yellow;stroke-width:4"/><line x1="226.794" y1="250.0" x2="313.397" y2="300.0" stroke-linecap="round" style="stroke:orange;stroke-width:4"/><line x1="313.397" y1="300.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="400.0" y1="30.0" x2="400.0" y2="25.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="25.0" x2="397.061" y2="20.955" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="397.061" y1="20.955" x2="392.306" y2="19.41" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="392.306" y1="19.41" x2="387.551" y2="20.955" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="387.551" y1="20.955" x2="384.612" y2="25.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="384.612" y1="25.0" x2="384.612" y2="30.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="384.612" y1="30.0" x2="387.551" y2="34.045" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="387.551" y1="34.045" x2="392.306" y2="35.59" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="392.306" y1="35.59" x2="397.061" y2="34.045" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="397.061" y1="34.045" x2="400.0" y2="30.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="250.0" x2="417.365" y2="151.519" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="417.365" y1="151.519" x2="340.761" y2="87.24" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="340.761" y1="87.24" x2="246.792" y2="121.442" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="246.792" y1="121.442" x2="229.427" y2="219.923" stroke-linecap="round" style="stroke:yellow;stroke-width:4"/><line x1="229.427" y1="219.923" x2="306.031" y2="284.202" stroke-linecap="round" style="stroke:orange;stroke-width:4"/><line x1="306.031" y1="284.202" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="438.203" y1="33.342" x2="439.071" y2="28.418" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="439.071" y1="28.418" x2="436.879" y2="23.924" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="436.879" y1="23.924" x2="432.464" y2="21.577" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="432.464" y1="21.577" x2="427.513" y2="22.273" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="427.513" y1="22.273" x2="423.916" y2="25.746" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="423.916" y1="25.746" x2="423.048" y2="30.67" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="423.048" y1="30.67" x2="425.24" y2="35.164" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="425.24" y1="35.164" x2="429.655" y2="37.511" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="429.655" y1="37.511" x2="434.606" y2="36.815" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="434.606" y1="36.815" x2="438.203" y2="33.342" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="250.0" x2="434.202" y2="156.031" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="434.202" y1="156.031" x2="369.923" y2="79.427" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="369.923" y1="79.427" x2="271.442" y2="96.792" stroke-linecap="round" style="stroke:blue; ...

# %% [markdown]
# # Lab Day 2: Create your own art masterpieces
#
# Hello Students now that you created your own art. You will be tasked
# with expanding that knowledge and practicing the skills you have
# learned from it.  This isn’t free time. You are required to complete at
# least one of these for your class participation and at least one for
# your homework most likely as part of your second HW You may also spend the time working
# on other homeworks or asking questions. However I think it is best
# that you ask these questions to, and teach your classmates. The true
# mark of whether you understand something is whether or not you can
# get someone else to understand it as well. That being said, good luck.
# I hope you enjoy it.
#
# -- Kevin

# %% [markdown]
# # Experiment 1:
# Start with this pseudocode to try creating a row of colored squares:
#
#
# ```
# Pseudocode
# Repeat 6 times the following:
#   Set color from list
#   Repeat 4 times the following:
#     Move forward 20
#     Turn left 90
#   Put pen up
#   Move forward 30
#   Put pen down
# Hide turtle
#
# ```

# %%
colors = ["purple","green","blue","yellow","orange","purple"]
shelly.clear()
shelly.penup()
shelly.home()
shelly.pendown()
for i in range(6):
  shelly.color(colors[i])
  for x in range(4):
    shelly.forward(20)
    shelly.left(90)
  shelly.penup()
  shelly.forward(30)
  shelly.pendown()
shelly.hideturtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="230.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="400.0" y1="230.0" x2="380.0" y2="230.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="380.0" y1="230.0" x2="380.0" y2="250.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="380.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="400.0" y1="220.0" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="400.0" y1="200.0" x2="380.0" y2="200.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="380.0" y1="200.0" x2="380.0" y2="220.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="380.0" y1="220.0" x2="400.0" y2="220.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="400.0" y1="190.0" x2="400.0" y2="170.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="400.0" y1="170.0" x2="380.0" y2="170.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="380.0" y1="170.0" x2="380.0" y2="190.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="380.0" y1="190.0" x2="400.0" y2="190.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="400.0" y1="160.0" x2="400.0" y2="140.0" stroke-linecap="round" style="stroke:yellow;stroke-width:4"/><line x1="400.0" y1="140.0" x2="380.0" y2="140.0" stroke-linecap="round" style="stroke:yellow;stroke-width:4"/><line x1="380.0" y1="140.0" x2="380.0" y2="160.0" stroke-linecap="round" style="stroke:yellow;stroke-width:4"/><line x1="380.0" y1="160.0" x2="400.0" y2="160.0" stroke-linecap="round" style="stroke:yellow;stroke-width:4"/><line x1="400.0" y1="130.0" x2="400.0" y2="110.0" stroke-linecap="round" style="stroke:orange;stroke-width:4"/><line x1="400.0" y1="110.0" x2="380.0" y2="110.0" stroke-linecap="round" style="stroke:orange;stroke-width:4"/><line x1="380.0" y1="110.0" x2="380.0" y2="130.0" stroke-linecap="round" style="stroke:orange;stroke-width:4"/><line x1="380.0" y1="130.0" x2="400.0" y2="130.0" stroke-linecap="round" style="stroke:orange;stroke-width:4"/><line x1="400.0" y1="100.0" x2="400.0" y2="80.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="400.0" y1="80.0" x2="380.0" y2="80.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="380.0" y1="80.0" x2="380.0" y2="100.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="380.0" y1="100.0" x2="400.0" y2="100.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/>
#         <g visibility=hidden transform="rotate(360,400.0,70.0) translate(382.0, 52.0)">
# <path style=" stroke:none;fill-rule:evenodd;fill:purple;fill-opacity:1;" d="M 18.214844 0.632812 C 16.109375 1.800781 15.011719 4.074219 15.074219 7.132812 L 15.085938 7.652344 L 14.785156 7.496094 C 13.476562 6.824219 11.957031 6.671875 10.40625 7.066406 C 8.46875 7.550781 6.515625 9.15625 4.394531 11.992188 C 3.0625 13.777344 2.679688 14.636719 3.042969 15.027344 L 3.15625 15.152344 L 3.519531 15.152344 C 4.238281 15.152344 4.828125 14.886719 8.1875 13.039062 C 9.386719 12.378906 10.371094 11.839844 10.378906 11.839844 C 10.386719 11.839844 10.355469 11.929688 10.304688 12.035156 C 9.832031 13.09375 9.257812 14.820312 8.96875 16.078125 C 7.914062 20.652344 8.617188 24.53125 11.070312 27.660156 C 11.351562 28.015625 11.363281 27.914062 10.972656 28.382812 C 8.925781 30.84375 7.945312 33.28125 8.238281 35.1875 C 8.289062 35.527344 8.28125 35.523438 8.917969 35.523438 C 10.941406 35.523438 13.074219 34.207031 15.136719 31.6875 C 15.359375 31.417969 15.328125 31.425781 15.5625 31.574219 C 16.292969 32.042969 18.023438 32.964844 18.175781 32.964844 C 18.335938 32.964844 19.941406 32.210938 20.828125 31.71875 C 20.996094 31.625 21.136719 31.554688 21.136719 31.558594 C 21.203125 31.664062 21.898438 32.414062 22.222656 32.730469 C 23.835938 34.300781 25.5625 35.132812 27.582031 35.300781 C 27.90625 35.328125 27.9375 35.308594 28.007812 34.984375 C 28.382812 33.242188 27.625 30.925781 25.863281 28.425781 L 25.542969 27.96875 L 25.699219 27.785156 C 28.945312 23.960938 29.132812 18.699219 26.257812 11.96875 L 26.207031 11.84375 L 27.945312 12.703125 C 31.53125 14.476562 32.316406 14.800781 33.03125 14.800781 C 33.976562 14.800781 33.78125 13.9375 32.472656 12.292969 C 28.519531 7.355469 25.394531 5.925781 21.921875 7.472656 L 21.558594 7.636719 L 21.578125 7.542969 C 21.699219 6.992188 21.761719 5.742188 21.699219 5.164062 C 21.496094 3.296875 20.664062 1.964844 19.003906 0.855469 C 18.480469 0.503906 18.457031 0.5 18.214844 0.632812"/>
# </g>
#       </svg>

# %% [markdown]
# # Experiment 2:
# Make a House with Starter Code
# Start with the following coder which creates one filled gray square and one filled red triangle:
#
#
#
# ```
# # make a house
# import turtle
# turtle.bgcolor(' blue )
# shelly = turtle.Turtle()
#
# # make the first big square for house
# Shelly.begin_fill() # start fill of color
# shelly.color('gray')
# for i in range(4):
#   shelly.forward(100)
#   shelly.left(90)
# shelly.end_fill() # end fill of color
# shelly.penup()
# shelly.goto(-20,100) # move turtle to next area
# shelly.pendown()
#
# ```
#
# ```
# # make a red triangle roof
# shelly.begin_fill () # start fill for roof
# shelly.color('red')
# shelly.left(60)
# shelly.forward(140)
# shelly.right(120)
# shelly.forward(140)
# shelly.right(120)
# shelly.forward(140)
# Shelly.end_fill() # end fill of color for roof
#
# ```
#
# ```
# # make a window
# shelly .penup()
# shelly.goto(25,80) # move to window position
# shelIy.pendown()
# shelly.begin_fill() # start filling window color
# shelly.color(‘yellow')
# for i in range(4):
#   shelly.forward(20)
#   shelly.left(90)
# shelly.end_fiII() # end filling window color
#
# # hide the turtle when done
# shelly.hideturtle()
#
# ```

# %% [markdown]
# # Experiment 3:
# Can you make this green face using a series of circles? To help get you started here’s the code
# for making one eye:
#
#
# ```
# shelly.goto(-30,100)
# shelly.begin_fill()
# shelly.color(‘white’)
# shelly.circle(30)
# shelly.end_fill()
# shelly.begin_fill()
# shelly.color(‘black’)
# shelly.circle(20)
# shelly.end_fill()
#
# ```

# %% [markdown]
# # Experiment 4:
# Change the code at the end of Step 2 of your ​Create Geometric Art Project​ code to create a
# different image. Use the following:
#
#
#
#
# ```
#
# Pseudocode
# Repeat 36 times the following:
#     Make a circle of size 100
#     Turn 10 degrees to the right
#
# ```

# %%
shelly.clear()
shelly.penup()
shelly.home()
shelly.pendown()
for x in range(36):
  circle(100,9)
  shelly.right(10)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="335.721" y2="73.396" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="335.721" y1="73.396" x2="237.24" y2="56.031" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="237.24" y1="56.031" x2="150.637" y2="106.031" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="150.637" y1="106.031" x2="116.435" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="116.435" y1="200.0" x2="150.637" y2="293.969" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="150.637" y1="293.969" x2="237.24" y2="343.969" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="237.24" y1="343.969" x2="335.721" y2="326.604" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="335.721" y1="326.604" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="250.0" x2="417.365" y2="151.519" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="417.365" y1="151.519" x2="367.365" y2="64.916" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="367.365" y1="64.916" x2="273.396" y2="30.714" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="273.396" y1="30.714" x2="179.427" y2="64.916" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="179.427" y1="64.916" x2="129.427" y2="151.519" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="129.427" y1="151.519" x2="146.792" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="146.792" y1="250.0" x2="223.396" y2="314.279" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="223.396" y1="314.279" x2="323.396" y2="314.279" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="323.396" y1="314.279" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="250.0" x2="434.202" y2="156.031" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="434.202" y1="156.031" x2="400.0" y2="62.062" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="62.062" x2="313.397" y2="12.062" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="313.397" y1="12.062" x2="214.916" y2="29.427" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="214.916" y1="29.427" x2="150.637" y2="106.031" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="150.637" y1="106.031" x2="150.637" y2="206.031" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="150.637" y1="206.031" x2="214.916" y2="282.635" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="214.916" y1="282.635" x2="313.397" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="313.397" y1="300.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="250.0" x2="450.0" y2="163.397" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="450.0" y1="163.397" x2="432.635" y2="64.916" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="432.635" y1="64.916" x2="356.031" y2="0.637" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="356.031" y1="0.637" x2="256.031" y2="0.637" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="256.031" y1="0.637" x2="179.427" y2="64.916" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="179.427" y1="64.916" x2="162.062" y2="163.397" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="162.062" y1="163.397" x2="212.062" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="212.062" y1="250.0" x2="306.031" y2="284.202" stroke-linecap="ro ...

# %% [markdown]
# # Experiment 5:
# Change the code at the end of Step 4 in your ​Create Geometric Art Project​ code to make
# multiple circles coming back. Use the following:
#
#
#
# ```
# Pseudocode
# Repeat 36 times the following
#     Lift pen
#     Move forward 200
#     Repeat 6 times
#         Put pen down
#         Make a circle of size 5
#         Put pen up
#         Move back 20
#     Move back to center 80
#     Turn 10 degrees to the right
# Hide Turtle
#
# ```

# %%
shelly.clear()
shelly.penup()
shelly.home()
shelly.pendown()
for x in range(36):
  shelly.penup()
  shelly.forward(200)
  for y in range(6):
    shelly.pendown()
    circle(5,10)
    shelly.penup()
    shelly.backward(20)
  shelly.backward(80)
  shelly.right(10)
shelly.hideturtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400.0" y1="50.0" x2="400.0" y2="45.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="45.0" x2="397.061" y2="40.955" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="397.061" y1="40.955" x2="392.306" y2="39.41" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="392.306" y1="39.41" x2="387.551" y2="40.955" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="387.551" y1="40.955" x2="384.612" y2="45.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="384.612" y1="45.0" x2="384.612" y2="50.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="384.612" y1="50.0" x2="387.551" y2="54.045" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="387.551" y1="54.045" x2="392.306" y2="55.59" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="392.306" y1="55.59" x2="397.061" y2="54.045" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="397.061" y1="54.045" x2="400.0" y2="50.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="70.0" x2="400.0" y2="65.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="65.0" x2="397.061" y2="60.955" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="397.061" y1="60.955" x2="392.306" y2="59.41" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="392.306" y1="59.41" x2="387.551" y2="60.955" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="387.551" y1="60.955" x2="384.612" y2="65.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="384.612" y1="65.0" x2="384.612" y2="70.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="384.612" y1="70.0" x2="387.551" y2="74.045" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="387.551" y1="74.045" x2="392.306" y2="75.59" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="392.306" y1="75.59" x2="397.061" y2="74.045" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="397.061" y1="74.045" x2="400.0" y2="70.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="90.0" x2="400.0" y2="85.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="85.0" x2="397.061" y2="80.955" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="397.061" y1="80.955" x2="392.306" y2="79.41" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="392.306" y1="79.41" x2="387.551" y2="80.955" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="387.551" y1="80.955" x2="384.612" y2="85.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="384.612" y1="85.0" x2="384.612" y2="90.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="384.612" y1="90.0" x2="387.551" y2="94.045" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="387.551" y1="94.045" x2="392.306" y2="95.59" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="392.306" y1="95.59" x2="397.061" y2="94.045" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="397.061" y1="94.045" x2="400.0" y2="90.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="110.0" x2="400.0" y2="105.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="105.0" x2="397.061" y2="100.955" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="397.061" y1="100.955" x2="392.306" y2="99.41" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="392.306" y1="99.41" x2="387.551" y2="100.955" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="387.551" y1="100.955" x2="384.612" y2="105.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="384.612" y1="1 ...
