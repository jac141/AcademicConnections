# %% [markdown]
# Name: Laxya Kumar
# Also I did the extra credit where I have to incorporate 2 experiments from the hard creating adeventure game lab.  In this case I did a password checker and a quiz game.

# %%
import random 

##############################################
def flashlight():
  yesOrNo = input("""You enter the cave and turn on your flashlight...
You decide to go more deeper into the cave and you slip on a rock and fall into a underground pool! 
All of a sudden the flashlight turns off because it got waterlogged.....
Could this day be anyworse? 
Do you still want to continue exploring the cave?: yes(y) or no(n)""")
  if yesOrNo == "n":
    yOrN = input("""Smart idea, let's get out of here...
You climbed out of the pool drenched and are running in the direction of the light where the cave entrance is....WHEN SUDDENLY...
AN UNKOWN ENTITY CAUSES THE CAVE ENTRANCE TO COME CRASHING DOWN...
Now the entrance of the cave is closed and you only have 10 minutes left before you die of oxygen deficiency.... 
What do you do now? Give Up(y) or Gain Superhuman Strength and break down the walls!(n) """)
    if yOrN == "n":
      color = input("""Congrats! You have escaped the treachorous cave. Good Job! 
""")
     
    else: 
        print("""You die of suffocation.
You lost the game. Better luck next time!""")
  else:
    print("""Determined aren't you! 
You swim deeper throughout the cave....AND THEN SUDDENLY..
A CROCODILE COMES OUT OF NOWHERE AND BRUTALLY DEVOURS YOU!!
You lost the game. Better luck next time! """)
    
###################################################

def password():
  words  = ['tree','sun','ball','moon','earth','grass','world', 'python','dog','snake','newton','geography'] 
  x = random.choice(words)
  return x

y = password() 
  

####################################################


def quizGame():
  score = 0
  intro = (" You must answer all 4 of the questions correctly/get a score of 4 or else your fate lies in the Hunter's hand....")
  questionOne = input("""Question (1) 
What year was the Declaration of Independence signed?""")
  if questionOne == "1776":
    score = score + 1
  else:
    score = 0

  questionTwo = input("""Question (2)
What is the capital of Hawaii?""")
  if questionTwo == "honolulu" or "Honolulu":
    score = score + 1
  else:
    score = score-1
  
  questionThree = input("""Question (3)
What is 30 % 5? """)
  if questionThree == "0":
    score = score + 1  
  else:
    score = score -1 

  questionFour = input("""Question (4)
What is the best coding language? (This one should be very obvious)""")
  if questionFour == "python" or "Python":
    score = score + 1
  else:
    score = score - 1

  score = str(score)
  
  print("Your score is a total of " + score + " points. " )
 
  if score == "4":
   color2 = input("Congratulations! You got a full score of 4. You won.")
  else:
    print("Welp, seems like you did not get a full score of 4 and get killed by the hunter. You lost.")


    
####################################
    
def saladBowl():
   print("""You absolutely DEVOURED the tasty Salad  Bowl...
Now you find yourself feeling tired after eating and you decide to return back home...
ALL OF A SUDDEN...A hunter has came upon you and wants you to solve a life or death quiz""")
   quizGame()

####################################


def orangeLight():
  # if orangeLight == "r":
      print("""You proceed your trek towards the orange light for another 5 minutes and right when you enter the room you see...
TEN TREASURE CHESTS THAT ARE FILLED WITH MONEY TO THE BRIM!!!""")
      x = input("""Remember the password that was mentioned at the start? 
Please enter the password""")

      if x == y: 
        color1 = input("""The password is correct!
Congratulations, you won the game!""")
        
      else:
        print("""The password in incorrect.
Sucks to suck, you lost the game.""") 
#   else:
#       print("""You decide to walk back and after 45 minutes you exit cave and it is raining...
# Not only do you have to walk back home in the rain but you also missed the oppurtunity to go the glowing orange light where there was a pile of millions of dollars!
# You lost.""")
      

####################################


def cavingGear():
  leftOrRight= input(""" Smart choice! Never want to enter the cave without the gear!
You are slowly walking into the cave and barely avoid a huge drop into a pool of water because of your sensing gear.....
You pick up the pace for another 30 minutes before you come across a y section....with a tunnel leading in the rightwards direction and a tunnel leading in the leftwards direction..
Which direction do you pick? right(r) or left(l)?""")
  
  if leftOrRight == "r":
    return orangeLight()
  else:
    print("""You walk into the tunnel for a solid 30-40 meters before you hear a growling in the distance and freeze right in  your tracks.... 
Was that the sound of a bear?
Suddenly a 8 foot black bear comes out of no where and chops your head off! 
Seems like taking the leftwards tunnel wasn't the brightest of ideas after all. You lost and your dead.  """)
  
############################################










item1 = input("""You have decided to go on a evening walk to a trail in the woods near your house.
It has been a few hours and you randomly have stumbled upon a HUGE cave that you want to explore!.
You can pick one item to take with you into the cave- 
Flashlight(f),Salad Bowl(s), or Caving Gear(g):What do you choose?
Make sure to remember your PASSWORD: """ + y)

if item1 == "f":
  flashlight()
elif item1 == "s":
  saladBowl()
elif item1 == "g":
  cavingGear()
# Out:
# You have decided to go on a evening walk to a trail in the woods near your house.
# It has been a few hours and you randomly have stumbled upon a HUGE cave that you want to explore!.
# You can pick one item to take with you into the cave-
# Flashlight(f),Salad Bowl(s), or Caving Gear(g):What do you choose?
# Make sure to remember your PASSWORD: grassg
#  Smart choice! Never want to enter the cave without the gear!
# You are slowly walking into the cave and barely avoid a huge drop into a pool of water because of your sensing gear.....
# You pick up the pace for another 30 minutes before you come across a y section....with a tunnel leading in the rightwards direction and a tunnel leading in the leftwards direction..
# Which direction do you pick? right(r) or left(l)?r
# You proceed your trek towards the orange light for another 5 minutes and right when you enter the room you see...
# TEN TREASURE CHESTS THAT ARE FILLED WITH MONEY TO THE BRIM!!!
# ...
