# %%
import time

print("Welcome to generic adventure game")

item = input("take a item with you chocolate (C), Tarp(T), Flare gun (G), First aid kit (F), Map (A) or latern (L): ")
print("You are out hiking in the mountains.")
time.sleep(2.5)
print("You hear footsteps slowly approaching your location")
choice1 = input("Do you follow the sound (Y) or (N): ")
if choice1.upper() == "Y":
  print("You follow the sound")
  time.sleep(2.5)
  print("The sound suddenly stops.") 
  time.sleep(2.5)
  print("You are now LOST! ....") 
  time.sleep(2.5)
  print("You try to call on your phone, but there is no signal!") 
  time.sleep(2.5)
  direction = input("You meet an intersection do you want to go left (l) or right (r): ")
  if direction.upper() == "R":
    time.sleep(2.5)
    print("You reach an abandoned cabin.")
    if item.upper() == "A":
      time.sleep(2.5)
      print("You find your way back using the map. You won!")
    else:
      time.sleep(2.5)
      print("If you brough a map you could find your way back but you didn't. You lose!")
  elif direction.upper() == "L":
    time.sleep(2.5)
    direction1 = input("You find another path divergence do you go left (l) or right (r): ")
    
    if direction1.upper() == "L":
      time.sleep(2.5)
      print("You reach a river with a broken bridge")
      if item.upper() == "T":
        time.sleep(2.5)
        print("you patch up the river and find a way home. You won!")
      else:
        time.sleep(2.5)
        print("If you had tarp you could've patched up the bridge. You are still lost. You lost!")
    else:
      time.sleep(2.5)
      move_choice = input("Do you trot carefully (t) or walk normally across this rough terrian (w)?: ")
      if move_choice.upper() == "W":
        time.sleep(2.5)
        if item.upper() == "F":
          print("You tripped on a log and injured your foot but you patched up your wound.")
          time.sleep(2.5)
          print("You reach a highway.")
          time.sleep(2.5)
          print("You can't signal for help because you don't have a ligt source. You lost!")
        else:
          print("you trip and hurt your foot. If you had medical supplies you could've patched the wound. You lost!")
      if move_choice.upper() == "T":
        time.sleep(2.5)
        print("You avoid a log and reach a highway.")
        if item.upper() == "G":
          time.sleep(2.5)
          print("You signal with the flare gun! A car picks you up and gives you a ride home. You won!")
        elif item.upper() == "L":
          time.sleep(2.5)
          print("You signal with the lantern! A car picks you up and gives you a ride home. You won!")
        else:
          time.sleep(2.5)
          print("If you had a light source to signal with you could've signaled for help. You lost!")

elif choice1.upper() == "N":
  print("Good idea. You are not taking risks.") 
  time.sleep(2.5)
  print("You start walking back to the starting point.") 
  time.sleep(2.5)
  print("You realize you are LOST!") 
  time.sleep(2.5)
  print("The sound is behind you and is getting louder. You panic!") 
  time.sleep(2.5)
  call_or_run = input("Do you run or make a call? (r) or (c): ")
  time.sleep(2.5)
  if call_or_run.upper() == "C":
    for call_or_run in "C":
      time.sleep(2.5)
      print("You make a call but it fails. The sound gets slightly louder!")
      time.sleep(2.5)
  call_or_run = input("Do you run or make another call? (r) or (c): ")
  time.sleep(2.5)
  print("You are running fast. The sound gets really loud!")
  time.sleep(2.5)
  print("A person on a electric scooter is approaching. You can't tell who they are due to their hood.")
  time.sleep(2.5)
  ques = input("What's the best emoji")
  if ques.upper() == "MOYAI":
    print("Ok that's correct.")
    time.sleep(2.5)
    print("If you have choclate I can help you")
    if item == "choclate":
      time.sleep(2.5)
      print("The person picks you up since you gave him choclate and returns you home. You won!")
  else:
    time.sleep(2.5)
    print("The person dosen't like your answer and leaves. You lost!")
# Out:
# Welcome to generic adventure game
# take a item with you chocolate (C), Tarp(T), Flare gun (G), First aid kit (F), Map (A) or latern (L): L
# You are out hiking in the mountains.
# You hear footsteps slowly approaching your location
# Do you follow the sound (Y) or (N): y
# You follow the sound
# The sound suddenly stops.
# You are now LOST! ....
# You try to call on your phone, but there is no signal!
# You meet an intersection do you want to go left (l) or right (r): r
# You reach an abandoned cabin.
# If you brough a map you could find your way back but you didn't. You lose!
