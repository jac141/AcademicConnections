# %% [markdown]
# ## Adventure Game Attempt #1
# # Jamie Figueroa Weston, I implemented two extensions into my adventure game, enjoy!!

# %%
import time
def game():
  print("You've crash landed on an island and are trying to survive, and get back home")
  print("You're exploring around your crash site for some tools")
  print("You grab your phone and get a notification from an unknown number")
  password1 = input("The message says: Set a password ")
  print("You move on and find some stuff, but are very weak, and can only carry one item")
  firstchoice = input("Do you choose to get the snickers bar(s), the bat(b), or the cardboard box(c")

  print("You get tired of waiting around and decide to explore the area")
  time.sleep(1)
  print("You hear noises and realize there may be people living here")
  time.sleep(2)
  print("you hope they have cell service")
  time.sleep(1)
  print("You come across a crossroads and must decide how to proceed")
  time.sleep(1)
  direction = input("Which direction do you go in? Forward over the bridge (f), left to towards the river(l), or right into the woods(r)? ")

  if direction == "f" or direction == "Forward" or direction == "forward":
    print("You decide to go over the bridge, eventually coming across an area guarded by a dog.")
    time.sleep(2)
    if firstchoice == "s":
      print("You feed the dog your snickers bar")
      time.sleep(1)
      print("The dog let's you walk by the door it was guarding")
      time.sleep(1)
      print("when you enter the building you see it's actually a strabucks coffee!!")
      time.sleep(1)
      print("you realize all strabucks have wifi, but you have to put in the password")
      #insert of extension #1
      time.sleep(1)
      print('What is the password? ')
      password = input()
      while password.lower() != password1:
        print("Guess Again ")
        print('What is the password?')
        name = input()
        if name.lower() == password1 :
         print("Got it!")
         break
      print("You have won!")
    else:
      print("Since you don't want to hurt the dog you decide to try and pet it")
      time.sleep(2)
      print("as you reach your hand to pet it, it bites your hand, and begins chasing you around the island")
      time.sleep(1)
      print("You have lost the game.")
  elif direction == "l":
    print("Heading dwon towards the river you feel refreshed by the smell")
    time.sleep(1)
    print("You begin hearing the noises again and notice loud sounds coming from across the river")
    time.sleep(2)
    print("you wonder what to do...")
    if firstchoice == "c":
      time.sleep(1)
      print("Luckily, you remember you have a cardboard box, which you can use as a boat!!")
      time.sleep(1)
      print("You use the cardboard box to make it safely across the river")
      time.sleep(2)
      print("You head towards the noises")
      time.sleep(1)
      print("AND see it's a city! You ask for the fastest trip back home")
      time.sleep(2)
      print("You head back home on a first class seat.")
      time.sleep(2)
      print("You have won the game :>")
    else:
      print("You decide to try and swim across, BUT a shark eats you.")
      time.sleep(1)
      print("You have lost the game.")
  else:
    print("Heading into the forest you find a witches hut and decide, heck why not lets go into it")
    time.sleep(1)
    print("Opening the door, you feel a bit scared, but  find a staircase that leads downwards.")
    time.sleep(1)
    print("At the bottom of the staircase, you find THE WITCH!")
    Choice = input("Do you decide to talk to the witch (s), orrrr attack it!!!!!! (a)? ")
    if Choice == "s":
      print("You try and talk to the witch, but she ignores you and casts a spellll")
      print("you turn into a frog")
      print("you lost the game try again.")
    else:
      if firstchoice == "b":
        time.sleep(1)
        print("With a weapon to kill the witch, you hit the witch with your bat!")
        print("You use her phone to call the police and get you home")
        print("YOU WON")
      else:
        time.sleep(1)
        print("You decide to punch the witch, which only irritated it.")
        time.sleep(1)
        print("She tells you 'now you must endure the most painful game ever, guessng US capitals, OR DIE")
        time.sleep(2)
        #extension #3 implemented
        num_correct = 0
        answer = input("What is the capital of California ")
        if answer == "Sacramento":
         print("Correct!")
         num_correct += 1
        else:
           print(f"The answer is 'Sacramento', not {answer!r}")
        answer2 = input("What is the capital of Florida!")
        if answer2 == "Tallahasse":
         print("Correct!")
         num_correct += 1
        else:
           print(f"The answer is 'Tallahasse', not {answer2!r}")
        answer3 = input("Ok, last one, what's the capital of New York")
        if answer3 == "Albany":
          print("Correct!")
          num_correct += 1
        else:
          print(f"The answer is 'Albany', not {answer3!r}")
      print("You got", num_correct , "right.")
      if num_correct == 3:
        print("Since you got them all right, the witch let you go home!")
        print("You won the game")
      else:
          print("The witch killed you because you failed.")
          print("You lost the game")

    

  time.sleep(2)
  print("Thank you for playing.")

game()

# %%
#Extensions
#extension #1
password1 = input("Set a password ")
 
print('What is the password? ')
password = input()
while password.lower() != password1:
     print("Guess Again ")
     print('What is the password?')
     name = input()
     if name.lower() == password1 :
      print("Got it!")
      break
# Out:
# Set a passwordred
# What is the password?
# me
# Guess Again
# What is the password?
# red
# Got it!

# %%
#Extension #3
num_correct = 0
answer = input("What is the capital of California ")
if answer == "Sacramento":
    print("Correct!")
    num_correct += 1
else:
    print(f"The answer is 'Sacramento', not {answer!r}")
answer2 = input("What is the capital of Florida!")
if answer2 == "Tallahasse":
    print("Correct!")
    num_correct += 1
else:
    print(f"The answer is 'Tallahasse', not {answer2!r}")
answer3 = input("Ok, last one, what's the capital of New York")
if answer3 == "Albany":
    print("Correct!")
    num_correct += 1
else:
    print(f"The answer is 'Albany', not {answer3!r}")
print("You got", num_correct , "right.")
